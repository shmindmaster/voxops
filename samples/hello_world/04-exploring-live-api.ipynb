# %% [markdown]
# # **Azure Voice Live API: Real-Time Voice Agents**
#
# This notebook demonstrates enterprise-grade real-time voice conversation implementation using Azure Voice Live API with Azure AI Agent Service integration.
#
# ### **Notebook Architecture Overview**
# ```
# ┌─────────────────┐    ┌──────────────────┐    ┌─────────────────────┐
# │   Audio I/O     │◄──►│  WebSocket Client │◄──►│ Azure AI Agent      │
# │  (sounddevice)  │    │  (Threading)     │    │ Service + Voice API │
# └─────────────────┘    └──────────────────┘    └─────────────────────┘
# ```
#
# ### **Implementation Progression**
# 1. **Core Infrastructure** - WebSocket connection & audio processing
# 2. **Authentication & Configuration** - Entra ID + API key fallback
# 3. **Direct Model Integration** - Basic voice live API connection
# 4. **Azure AI Agent Service** - Production agent-based architecture
# 5. **Production Deployment** - Complete application with proper cleanup
#
# ### **Key Features**
# - **Low-latency audio streaming** (24kHz, 20ms chunks)
# - **Semantic VAD** with Azure deep noise suppression
# - **Thread-safe audio processing** with graceful shutdown
# - **Dual authentication** (Entra ID + API key)
# - **Agent-based architecture** for enterprise scalability

# %% [markdown]
# ## **1. Dependencies & Core Imports**

# %%
# Core Python libraries
import os
import uuid
import json
import time
import base64
import logging
import threading
import queue
import signal
import sys
from collections import deque
from datetime import datetime

# Audio processing
import numpy as np
import sounddevice as sd

# Azure SDK and authentication
from dotenv import load_dotenv
from azure.core.credentials import TokenCredential
from azure.identity import DefaultAzureCredential

# Type hints
from typing import Dict, Union, Literal, Set
from typing_extensions import Iterator, TypedDict, Required

# WebSocket communication
import websocket
from websocket import WebSocketApp

print("✅ All dependencies imported successfully!")
# Out:
# ✅ All dependencies imported successfully!

# %% [markdown]
# ## **2. Configuration & Environment**

# %%
# Load environment variables
load_dotenv("./.env", override=True)

# Global variables for thread coordination
stop_event = threading.Event()
connection_queue = queue.Queue()

# Audio configuration
AUDIO_SAMPLE_RATE = 24000

# Logger setup
logger = logging.getLogger(__name__)

# Voice Live API configuration
AZURE_VOICE_LIVE_ENDPOINT = os.environ.get("AZURE_VOICE_LIVE_ENDPOINT") or "https://aifoundry825233136833-resource.services.ai.azure.com"
AZURE_VOICE_LIVE_MODEL = os.environ.get("AZURE_VOICE_LIVE_MODEL") or "gpt-4o"
AZURE_VOICE_LIVE_API_VERSION = os.environ.get("AZURE_VOICE_LIVE_API_VERSION") or "2025-05-01-preview"
AZURE_VOICE_LIVE_API_KEY = os.environ.get("AZURE_VOICE_LIVE_API_KEY")

# Azure AI Agent Service configuration
AI_FOUNDRY_PROJECT_NAME = os.environ.get("AI_FOUNDRY_PROJECT_NAME")
AI_FOUNDRY_AGENT_ID = os.environ.get("AI_FOUNDRY_AGENT_ID")
AI_FOUNDRY_AGENT_CONNECTION_STRING = os.environ.get("AI_FOUNDRY_AGENT_CONNECTION_STRING")

print("📋 Voice Live API Configuration:")
print(f"  - Endpoint: {AZURE_VOICE_LIVE_ENDPOINT}")
print(f"  - Model: {AZURE_VOICE_LIVE_MODEL}")
print(f"  - API Version: {AZURE_VOICE_LIVE_API_VERSION}")
print(f"  - API Key: {'✅ Configured' if AZURE_VOICE_LIVE_API_KEY else '❌ Not set'}")

print("\n🤖 Azure AI Agent Service Configuration:")
print(f"  - Project Name: {AI_FOUNDRY_PROJECT_NAME or '❌ Not set'}")
print(f"  - Agent ID: {AI_FOUNDRY_AGENT_ID or '❌ Not set'}")
print(f"  - Connection String: {'✅ Configured' if AI_FOUNDRY_AGENT_CONNECTION_STRING else '❌ Not set (hub-based only)'}")

print(f"\n🎛️  Audio Sample Rate: {AUDIO_SAMPLE_RATE} Hz")
# Out:
# 📋 Voice Live API Configuration:
#   - Endpoint: https://poc-ai-agents-voice-resource.cognitiveservices.azure.com/
#   - Model: gpt-4o
#   - API Version: 2025-05-01-preview
#   - API Key: ✅ Configured
#
# 🤖 Azure AI Agent Service Configuration:
#   - Project Name: poc-ai-agents-voice
#   - Agent ID: asst_Kp4exd80NINFuraHyWOftsuR
#   - Connection String: ❌ Not set (hub-based only)
#
# 🎛️  Audio Sample Rate: 24000 Hz

# %% [markdown]
# ## **3. WebSocket Connection Management**
#
# Thread-safe WebSocket client with message queuing and connection state management.

# %%
class VoiceLiveConnection:
    """
    Manages WebSocket connection to Azure Voice Live API.
    
    Features:
    - Asynchronous message handling
    - Thread-safe message queue
    - Connection state management
    - Error handling and logging
    """
    
    def __init__(self, url: str, headers: dict) -> None:
        self._url = url
        self._headers = headers
        self._ws = None
        self._message_queue = queue.Queue()
        self._connected = False
        self._connection_id = str(uuid.uuid4())[:8]
        self._message_count = 0

    def connect(self) -> None:
        """Establish WebSocket connection with event handlers."""
        
        if self._connected:
            logger.warning("Connection already established")
            return
            
        print(f"🔌 Establishing WebSocket connection (ID: {self._connection_id})...")
        
        def on_message(ws, message):
            """Handle incoming messages by adding them to the queue."""
            self._message_count += 1
            self._message_queue.put(message)
            logger.debug(f"Connection {self._connection_id}: Message #{self._message_count} queued")
        
        def on_error(ws, error):
            """Handle WebSocket errors."""
            print(f"❌ WebSocket error (ID: {self._connection_id}): {error}")
            logger.error(f"Connection {self._connection_id}: WebSocket error: {error}")
        
        def on_close(ws, close_status_code, close_msg):
            """Handle connection closure."""
            print(f"🔌 WebSocket connection closed (ID: {self._connection_id})")
            print(f"   Status: {close_status_code}, Message: {close_msg}")
            logger.info(f"Connection {self._connection_id}: WebSocket closed - {close_status_code}: {close_msg}")
            self._connected = False
        
        def on_open(ws):
            """Handle successful connection."""
            print(f"✅ WebSocket connection opened (ID: {self._connection_id})")
            logger.info(f"Connection {self._connection_id}: WebSocket opened")
            self._connected = True

        # Create WebSocket app with event handlers
        self._ws = websocket.WebSocketApp(
            self._url,
            header=self._headers,
            on_message=on_message,
            on_error=on_error,
            on_close=on_close,
            on_open=on_open
        )
        
        # Start WebSocket in a separate thread
        self._ws_thread = threading.Thread(
            target=self._ws.run_forever, 
            name=f"WebSocket-{self._connection_id}"
        )
        self._ws_thread.daemon = True
        self._ws_thread.start()
        
        # Wait for connection to be established
        timeout = 10  # seconds
        start_time = time.time()
        while not self._connected and time.time() - start_time < timeout:
            time.sleep(0.1)
        
        if not self._connected:
            raise ConnectionError(f"Failed to establish WebSocket connection (ID: {self._connection_id}) within {timeout} seconds")
        
        print(f"✅ Connection established successfully (ID: {self._connection_id})")

    def recv(self) -> str:
        """Receive a message from the queue (non-blocking with timeout)."""
        try:
            message = self._message_queue.get(timeout=1)
            logger.debug(f"Connection {self._connection_id}: Message received from queue")
            return message
        except queue.Empty:
            return None

    def send(self, message: str) -> None:
        """Send a message through the WebSocket."""
        if self._ws and self._connected:
            self._ws.send(message)
            logger.debug(f"Connection {self._connection_id}: Message sent")
        else:
            logger.warning(f"Connection {self._connection_id}: Cannot send - not connected")
            print(f"⚠️  Cannot send message - connection not established (ID: {self._connection_id})")

    def close(self) -> None:
        """Close the WebSocket connection."""
        if self._ws:
            print(f"🔌 Closing WebSocket connection (ID: {self._connection_id})...")
            logger.info(f"Connection {self._connection_id}: Closing connection")
            self._ws.close()
            self._connected = False
            
            # Wait for thread to finish
            if hasattr(self, '_ws_thread') and self._ws_thread.is_alive():
                self._ws_thread.join(timeout=3)
                if self._ws_thread.is_alive():
                    print(f"⚠️  WebSocket thread did not stop gracefully (ID: {self._connection_id})")
                else:
                    print(f"✅ WebSocket thread stopped (ID: {self._connection_id})")
            
            print(f"✅ Connection closed (ID: {self._connection_id}, {self._message_count} messages processed)")
        else:
            print(f"ℹ️  No connection to close (ID: {self._connection_id})")

    @property
    def connection_id(self) -> str:
        """Get the connection ID for debugging."""
        return self._connection_id
    
    @property
    def is_connected(self) -> bool:
        """Check if the connection is active."""
        return self._connected
    
    @property
    def message_count(self) -> int:
        """Get the number of messages processed."""
        return self._message_count

print("✅ Enhanced VoiceLiveConnection class with connection state management")
# Out:
# ✅ Enhanced VoiceLiveConnection class with connection state management

# %% [markdown]
# ## **4. Azure Voice Live Client**
#
# Main client supporting both direct model and agent connections.

# %%
class AzureVoiceLive:
    """
    Main client for Azure Voice Live API.
    
    Handles:
    - Authentication (API key or token-based)
    - Connection management
    - URL construction for WebSocket endpoint
    """
    
    def __init__(
        self,
        *,
        azure_endpoint: str | None = None,
        api_version: str | None = None,
        token: str | None = None,
        api_key: str | None = None,
    ) -> None:
        self._azure_endpoint = azure_endpoint
        self._api_version = api_version
        self._token = token
        self._api_key = api_key
        self._connection = None

    def connect(self, model: str) -> VoiceLiveConnection:
        """
        Create a connection to the Voice Live API.
        
        Args:
            model: The AI model to use (e.g., 'gpt-4o')
            
        Returns:
            VoiceLiveConnection: Ready-to-use connection object
        """
        # if self._connection is not None:
        #     raise ValueError("Already connected to the Voice Live API.")
        if not model:
            raise ValueError("Model name is required.")

        # Convert HTTPS endpoint to WSS for WebSocket
        azure_ws_endpoint = self._azure_endpoint.rstrip('/').replace("https://", "wss://")

        # Construct WebSocket URL
        url = f"{azure_ws_endpoint}/voice-live/realtime?api-version={self._api_version}&model={model}"

        # Setup authentication headers
        auth_header = {"Authorization": f"Bearer {self._token}"} if self._token else {"api-key": self._api_key}
        request_id = uuid.uuid4()
        headers = {"x-ms-client-request-id": str(request_id), **auth_header}

        # Create and connect
        self._connection = VoiceLiveConnection(url, headers)
        self._connection.connect()
        return self._connection

print("✅ AzureVoiceLive client class defined")
# Out:
# ✅ AzureVoiceLive client class defined

# %% [markdown]
# ## **5. Real-Time Audio Processing**
#
# Low-latency audio player with deque-based buffering for real-time streaming.

# %%
class AudioPlayerAsync:
    """
    Asynchronous audio player with buffering for real-time playback.
    
    Features:
    - Thread-safe audio queue
    - Real-time streaming playback
    - Automatic start/stop management
    - Low-latency audio processing
    """
    
    def __init__(self):
        self.queue = deque()
        self.lock = threading.Lock()
        self.stream = sd.OutputStream(
            callback=self.callback,
            samplerate=AUDIO_SAMPLE_RATE,
            channels=1,
            dtype=np.int16,
            blocksize=2400,  # ~100ms at 24kHz
        )
        self.playing = False

    def callback(self, outdata, frames, time, status):
        """
        Audio callback function called by sounddevice.
        
        This function is called in real-time by the audio system
        and must be very efficient to avoid dropouts.
        """
        if status:
            logger.warning(f"Stream status: {status}")
            
        with self.lock:
            data = np.empty(0, dtype=np.int16)
            
            # Fill the output buffer from our queue
            while len(data) < frames and len(self.queue) > 0:
                item = self.queue.popleft()
                frames_needed = frames - len(data)
                data = np.concatenate((data, item[:frames_needed]))
                
                # If we have leftover data, put it back
                if len(item) > frames_needed:
                    self.queue.appendleft(item[frames_needed:])
            
            # Pad with silence if we don't have enough data
            if len(data) < frames:
                data = np.concatenate((data, np.zeros(frames - len(data), dtype=np.int16)))
                
        outdata[:] = data.reshape(-1, 1)

    def add_data(self, data: bytes):
        """Add audio data to the playback queue."""
        with self.lock:
            np_data = np.frombuffer(data, dtype=np.int16)
            self.queue.append(np_data)
            
            # Auto-start playback if we have data
            if not self.playing and len(self.queue) > 0:
                self.start()

    def start(self):
        """Start audio playback."""
        if not self.playing:
            self.playing = True
            self.stream.start()

    def stop(self):
        """Stop audio playback and clear buffer."""
        with self.lock:
            self.queue.clear()
        self.playing = False
        self.stream.stop()

    def terminate(self):
        """Terminate the audio player and release resources."""
        with self.lock:
            self.queue.clear()
        self.stream.stop()
        self.stream.close()

print("✅ AudioPlayerAsync class defined")
# Out:
# ✅ AudioPlayerAsync class defined

# %% [markdown]
# ## **6. Audio Input Capture**
#
# Microphone capture with base64 encoding for WebSocket transmission.

# %%
def listen_and_send_audio(connection: VoiceLiveConnection) -> None:
    """
    Capture audio from microphone and send to Voice Live API.
    
    This function runs in a separate thread and continuously:
    1. Reads audio from the microphone
    2. Encodes it as base64
    3. Sends it to the API via WebSocket
    
    Args:
        connection: Active VoiceLiveConnection instance
    """
    logger.info("Starting audio stream ...")

    # Create audio input stream
    stream = sd.InputStream(
        channels=1, 
        samplerate=AUDIO_SAMPLE_RATE, 
        dtype="int16"
    )
    
    try:
        stream.start()
        
        # Read audio in 20ms chunks (480 samples at 24kHz)
        read_size = int(AUDIO_SAMPLE_RATE * 0.02)
        
        while not stop_event.is_set():
            if stream.read_available >= read_size:
                # Read audio data
                data, _ = stream.read(read_size)
                
                # Encode as base64
                audio = base64.b64encode(data).decode("utf-8")
                
                # Create API message
                param = {
                    "type": "input_audio_buffer.append", 
                    "audio": audio, 
                    "event_id": ""
                }
                
                # Send to API
                data_json = json.dumps(param)
                connection.send(data_json)
            else:
                time.sleep(0.001)  # Small sleep to prevent busy waiting
                
    except Exception as e:
        logger.error(f"Audio stream interrupted. {e}")
    finally:
        stream.stop()
        stream.close()
        logger.info("Audio stream closed.")

print("✅ Audio input function defined")
# Out:
# ✅ Audio input function defined

# %% [markdown]
# ## **7. Audio Output & Event Processing**
#
# WebSocket event handler with audio playback and conversation state management.

# %%
def receive_audio_and_playback(connection: VoiceLiveConnection) -> None:
    """
    Receive messages from Voice Live API and handle audio playback.
    
    This function runs in a separate thread and handles:
    1. Receiving WebSocket messages from the API
    2. Processing different event types
    3. Playing back audio responses
    4. Managing conversation state
    
    Args:
        connection: Active VoiceLiveConnection instance
    """
    last_audio_item_id = None
    audio_player = AudioPlayerAsync()
    event_count = 0
    session_id = None

    logger.info("Starting audio playback thread...")
    print("🎧 Audio playback thread started - monitoring events...")
    
    try:
        while not stop_event.is_set():
            # Receive message from API
            raw_event = connection.recv()
            if raw_event is None:
                continue
                
            try:
                event = json.loads(raw_event)
                event_type = event.get("type")
                event_count += 1
                
                # Log every event with timestamp
                timestamp = datetime.now().strftime("%H:%M:%S.%f")[:-3]
                print(f"📨 [{timestamp}] Event #{event_count}: {event_type}")
                logger.info(f"Event #{event_count}: {event_type} - {event}")

                # Handle different event types with detailed logging
                if event_type == "session.created":
                    session = event.get("session", {})
                    session_id = session.get('id', 'unknown')
                    print(f"✅ Session created: {session_id}")
                    print(f"   Instructions: {session.get('instructions', 'Not set')[:100]}...")
                    print(f"   Voice: {session.get('voice', {}).get('name', 'Not set')}")
                    logger.info(f"Session created: {session_id}")

                elif event_type == "session.updated":
                    session = event.get("session", {})
                    print(f"🔄 Session updated")
                    print(f"   Voice: {session.get('voice', {}).get('name', 'Not set')}")
                    print(f"   VAD: {session.get('turn_detection', {}).get('type', 'Not set')}")

                elif event_type == "input_audio_buffer.committed":
                    item_id = event.get("item_id", "unknown")
                    print(f"🎤 Audio buffer committed: {item_id}")

                elif event_type == "input_audio_buffer.speech_started":
                    # User started speaking - stop AI playback
                    print(f"🗣️  Speech started - stopping AI playback")
                    audio_player.stop()

                elif event_type == "input_audio_buffer.speech_stopped":
                    print(f"🤐 Speech stopped - processing...")

                elif event_type == "conversation.item.created":
                    item = event.get("item", {})
                    item_type = item.get("type", "unknown")
                    item_id = item.get("id", "unknown")
                    print(f"📝 Item created: {item_type} ({item_id})")
                    if item_type == "message":
                        role = item.get("role", "unknown")
                        print(f"   Role: {role}")

                elif event_type == "response.created":
                    response = event.get("response", {})
                    response_id = response.get("id", "unknown")
                    print(f"🤖 Response created: {response_id}")

                elif event_type == "response.output_item.added":
                    item = event.get("item", {})
                    item_type = item.get("type", "unknown")
                    item_id = item.get("id", "unknown")
                    print(f"➕ Output item added: {item_type} ({item_id})")

                elif event_type == "response.content_part.added":
                    part = event.get("part", {})
                    part_type = part.get("type", "unknown")
                    print(f"🧩 Content part added: {part_type}")

                elif event_type == "response.audio_transcript.delta":
                    delta = event.get("delta", "")
                    item_id = event.get("item_id", "unknown")
                    print(f"📝 Transcript delta: '{delta}' (item: {item_id})")

                elif event_type == "response.audio.delta":
                    # New audio data from AI response
                    item_id = event.get("item_id", "unknown")
                    delta_length = len(event.get("delta", ""))
                    
                    if item_id != last_audio_item_id:
                        last_audio_item_id = item_id
                        print(f"🎵 New audio item: {item_id}")

                    # Decode and play audio
                    bytes_data = base64.b64decode(event.get("delta", ""))
                    if bytes_data:
                        print(f"🔊 Playing audio chunk: {len(bytes_data)} bytes")
                        logger.debug(f"Audio data length: {len(bytes_data)} bytes")   
                        audio_player.add_data(bytes_data)

                elif event_type == "response.audio.done":
                    item_id = event.get("item_id", "unknown")
                    print(f"✅ Audio complete: {item_id}")

                elif event_type == "response.content_part.done":
                    part = event.get("part", {})
                    part_type = part.get("type", "unknown")
                    print(f"✅ Content part done: {part_type}")

                elif event_type == "response.output_item.done":
                    item = event.get("item", {})
                    item_type = item.get("type", "unknown")
                    item_id = item.get("id", "unknown")
                    print(f"✅ Output item done: {item_type} ({item_id})")

                elif event_type == "response.done":
                    response = event.get("response", {})
                    response_id = response.get("id", "unknown")
                    status = response.get("status", "unknown")
                    print(f"✅ Response complete: {response_id} (status: {status})")

                elif event_type == "rate_limits.updated":
                    limits = event.get("rate_limits", [])
                    print(f"📊 Rate limits updated: {len(limits)} limits")
                    for limit in limits:
                        name = limit.get("name", "unknown")
                        remaining = limit.get("remaining", 0)
                        print(f"   {name}: {remaining} remaining")

                elif event_type == "error":
                    # Handle API errors
                    error_details = event.get("error", {})
                    error_type = error_details.get("type", "Unknown")
                    error_code = error_details.get("code", "Unknown")
                    error_message = error_details.get("message", "No message provided")
                    print(f"❌ ERROR: {error_type} ({error_code})")
                    print(f"   Message: {error_message}")
                    logger.error(f"API Error: {error_type} - {error_code} - {error_message}")
                    raise ValueError(f"API Error: {error_type} ({error_code}) - {error_message}")
                
                else:
                    # Log any unknown event types
                    print(f"❓ Unknown event: {event_type}")
                    logger.warning(f"Unknown event type: {event_type} - {event}")
                    
            except json.JSONDecodeError as e:
                logger.error(f"Failed to parse JSON event: {e}")
                print(f"❌ JSON Parse Error: {e}")
                continue

    except Exception as e:
        logger.error(f"Error in audio playback: {e}")
        print(f"❌ Audio playback error: {e}")
        import traceback
        traceback.print_exc()
    finally:
        audio_player.terminate()
        print(f"✅ Audio playback thread completed ({event_count} events processed)")
        logger.info(f"Audio playback done. Processed {event_count} events.")

print("✅ Enhanced audio output function with comprehensive event logging")
# Out:
# ✅ Enhanced audio output function with comprehensive event logging

# %% [markdown]
# ## **8. Graceful Shutdown Handler**

# %%
def read_keyboard_and_quit() -> None:
    """
    Monitor keyboard input for quit command.
    
    This function runs in a separate thread and waits for the user
    to type 'q' to gracefully shutdown the application.
    """
    print("Press 'q' and Enter to quit the chat.")
    
    while not stop_event.is_set():
        try:
            user_input = input()
            if user_input.strip().lower() == 'q':
                print("Quitting the chat...")
                stop_event.set()
                break
        except EOFError:
            # Handle case where input is interrupted
            break

print("✅ User input function defined")
# Out:
# ✅ User input function defined

# %% [markdown]
# ## **9. Session Configuration**
#
# Production-grade session settings with semantic VAD and audio preprocessing.

# %%
# Session configuration for the Voice Live API
session_config = {
    "type": "session.update",
    "session": {
        # Basic AI behavior
        "instructions": "You are a helpful AI assistant responding in natural, engaging language.",
        
        # Voice Activity Detection (VAD) settings
        "turn_detection": {
            "type": "azure_semantic_vad",
            "threshold": 0.3,  # Sensitivity for detecting speech
            "prefix_padding_ms": 200,  # Keep audio before speech starts
            "silence_duration_ms": 200,  # How long to wait for silence
            "remove_filler_words": False,  # Keep "um", "uh", etc.
            "end_of_utterance_detection": {
                "model": "semantic_detection_v1",
                "threshold": 0.01,  # When to consider speech finished
                "timeout": 2,  # Max time to wait for continuation
            },
        },
        
        # Audio preprocessing
        "input_audio_noise_reduction": {
            "type": "azure_deep_noise_suppression"  # Remove background noise
        },
        "input_audio_echo_cancellation": {
            "type": "server_echo_cancellation"  # Prevent feedback loops
        },
        
        # AI voice settings
        "voice": {
            "name": "en-US-Ava:DragonHDLatestNeural",  # High-quality neural voice
            "type": "azure-standard",
            "temperature": 0.8,  # Controls response creativity/randomness
        },
    },
    "event_id": ""
}

print("✅ Session configuration created")
print(f"   - Voice: {session_config['session']['voice']['name']}")
print(f"   - VAD Type: {session_config['session']['turn_detection']['type']}")
print(f"   - Noise Reduction: {session_config['session']['input_audio_noise_reduction']['type']}")
print(f"   - Echo Cancellation: {session_config['session']['input_audio_echo_cancellation']['type']}")
# Out:
# ✅ Session configuration created
#    - Voice: en-US-Ava:DragonHDLatestNeural
#    - VAD Type: azure_semantic_vad
#    - Noise Reduction: azure_deep_noise_suppression
#    - Echo Cancellation: server_echo_cancellation

# %% [markdown]
# ## **10. Authentication & Client Setup**
#
# Dual authentication strategy: Entra ID (preferred) with API key fallback.

# %%
# Setup logging for this session
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Create logs directory if it doesn't exist
import os
if not os.path.exists('logs'):
    os.makedirs('logs')

# Configure logging
logging.basicConfig(
    filename=f'logs/{timestamp}_voicelive_notebook.log',
    filemode="w",
    level=logging.DEBUG,
    format='%(asctime)s:%(name)s:%(levelname)s:%(message)s'
)

# Setup authentication - prefer token-based auth
credential = DefaultAzureCredential()
scopes = "https://ai.azure.com/.default"

try:
    token = credential.get_token(scopes)
    auth_method = "token"
    print("✅ Using token-based authentication")
except Exception as e:
    print(f"⚠️  Token auth failed: {e}")
    print("🔑 Falling back to API key authentication")
    auth_method = "api_key"

# Create the client
client_kwargs = {
    "azure_endpoint": AZURE_VOICE_LIVE_ENDPOINT,
    "api_version": AZURE_VOICE_LIVE_API_VERSION,
}

if auth_method == "token":
    client_kwargs["token"] = token.token
else:
    client_kwargs["api_key"] = AZURE_VOICE_LIVE_API_KEY

client = AzureVoiceLive(**client_kwargs)

print(f"✅ Azure Voice Live client created successfully")
print(f"   - Authentication: {auth_method}")
print(f"   - Endpoint: {AZURE_VOICE_LIVE_ENDPOINT}")
print(f"   - Model: {AZURE_VOICE_LIVE_MODEL}")
# Out:
# ✅ Using token-based authentication
# ✅ Azure Voice Live client created successfully
#    - Authentication: token
#    - Endpoint: https://poc-ai-agents-voice-resource.cognitiveservices.azure.com/
#    - Model: gpt-4o

# %% [markdown]
# ## **11. Connection Validation**

# %%
# Test connection (optional - uncomment to run)
# This will establish a connection and immediately close it

try:
    print("🔌 Testing connection...")
    test_connection = client.connect(model=AZURE_VOICE_LIVE_MODEL)
    print("✅ Connection test successful!")
    test_connection.close()
    print("🔌 Test connection closed")
except Exception as e:
    print(f"❌ Connection test failed: {e}")

# print("ℹ️  Connection test code ready (uncomment to run)")
# Out:
# 🔌 Testing connection...
# 🔌 Establishing WebSocket connection (ID: 9d8f24c6)...
# ✅ WebSocket connection opened (ID: 9d8f24c6)
# ✅ Connection established successfully (ID: 9d8f24c6)
# ✅ Connection test successful!
# 🔌 Closing WebSocket connection (ID: 9d8f24c6)...
# 🔌 WebSocket connection closed (ID: 9d8f24c6)
#    Status: None, Message: None
# ✅ Connection closed (ID: 9d8f24c6, 1 messages processed)
# 🔌 Test connection closed

# %% [markdown]
# ## **Development Utilities & Diagnostics**

# %%
# Development and testing utilities

def check_audio_devices():
    """Check available audio input and output devices."""
    print("🎤 Available Audio Input Devices:")
    for i, device in enumerate(sd.query_devices()):
        if device['max_input_channels'] > 0:
            print(f"  {i}: {device['name']} (inputs: {device['max_input_channels']})")
    
    print("\n🔊 Available Audio Output Devices:")
    for i, device in enumerate(sd.query_devices()):
        if device['max_output_channels'] > 0:
            print(f"  {i}: {device['name']} (outputs: {device['max_output_channels']})")
    
    print(f"\n🎛️  Default Input Device: {sd.query_devices(sd.default.device[0])['name']}")
    print(f"🎛️  Default Output Device: {sd.query_devices(sd.default.device[1])['name']}")

def test_microphone(duration=3):
    """Test microphone input for a few seconds."""
    print(f"🎤 Testing microphone for {duration} seconds...")
    print("💬 Please speak into your microphone...")
    
    def callback(indata, frames, time, status):
        volume_norm = np.linalg.norm(indata) * 10
        print(f"📊 Volume level: {'█' * int(volume_norm)}")
    
    with sd.InputStream(callback=callback, channels=1, samplerate=AUDIO_SAMPLE_RATE):
        sd.sleep(duration * 1000)
    
    print("✅ Microphone test complete")

def create_custom_session_config(
    instructions="You are a helpful AI assistant.",
    voice_name="en-US-Ava:DragonHDLatestNeural",
    temperature=0.8,
    vad_threshold=0.3
):
    """Create a custom session configuration."""
    return {
        "type": "session.update",
        "session": {
            "instructions": instructions,
            "turn_detection": {
                "type": "azure_semantic_vad",
                "threshold": vad_threshold,
                "prefix_padding_ms": 200,
                "silence_duration_ms": 200,
                "remove_filler_words": False,
                "end_of_utterance_detection": {
                    "model": "semantic_detection_v1",
                    "threshold": 0.01,
                    "timeout": 2,
                },
            },
            "input_audio_noise_reduction": {
                "type": "azure_deep_noise_suppression"
            },
            "input_audio_echo_cancellation": {
                "type": "server_echo_cancellation"
            },
            "voice": {
                "name": voice_name,
                "type": "azure-standard",
                "temperature": temperature,
            },
        },
        "event_id": ""
    }

def view_logs():
    """View the most recent log file."""
    import glob
    log_files = glob.glob("logs/*.log")
    if log_files:
        latest_log = max(log_files, key=os.path.getctime)
        print(f"📝 Latest log file: {latest_log}")
        with open(latest_log, 'r') as f:
            lines = f.readlines()
            print("📄 Last 20 lines:")
            for line in lines[-20:]:
                print(line.strip())
    else:
        print("📝 No log files found")

print("✅ Development utilities loaded:")
print("  - check_audio_devices(): Check available audio devices")
print("  - test_microphone(duration=3): Test microphone input")
print("  - create_custom_session_config(): Create custom configurations")
print("  - view_logs(): View recent log entries")
# Out:
# ✅ Development utilities loaded:
#   - check_audio_devices(): Check available audio devices
#   - test_microphone(duration=3): Test microphone input
#   - create_custom_session_config(): Create custom configurations
#   - view_logs(): View recent log entries

# %% [markdown]
# ## **Troubleshooting & Best Practices**
#
# ### **Common Issues**
# - **401/403**: Verify Entra ID permissions and endpoint URL
# - **404/409**: Check agent ID and API version
# - **Audio latency**: Optimize buffer sizes and sample rates
# - **Connection hangs**: Implement proper timeout and cleanup
#
# ### **Production Considerations**
# - **Authentication**: Use Entra ID in production, API keys for development
# - **Audio Quality**: 24kHz sample rate with noise suppression enabled
# - **Error Handling**: Implement circuit breakers and retry logic
# - **Monitoring**: Add Application Insights telemetry
# - **Scaling**: Use connection pooling for high-volume scenarios

# %% [markdown]
# ## **Audio Diagnostics**

# %%
# First, let's check your audio devices
print("🔍 Checking audio device configuration...")
check_audio_devices()

print("\n" + "="*60)
print("🎤 Testing microphone for 3 seconds...")
print("Please speak into your microphone!")
test_microphone(duration=3)
# Out:
# 🔍 Checking audio device configuration...
# 🎤 Available Audio Input Devices:
#   0: Microsoft Sound Mapper - Input (inputs: 2)
#   1: Surface Stereo Microphones (Sur (inputs: 2)
#   2: Microphone (Lumina Camera - Raw (inputs: 2)
#   6: Primary Sound Capture Driver (inputs: 2)
#   7: Surface Stereo Microphones (Surface High Definition Audio) (inputs: 2)
#   8: Microphone (Lumina Camera - Raw) (inputs: 2)
#   14: Surface Stereo Microphones (Surface High Definition Audio) (inputs: 2)
#   15: Microphone (Lumina Camera - Raw) (inputs: 2)
#   17: Microphone (Microsoft Surface Thunderbolt(TM) 4 Dock Audio) (inputs: 1)
#   20: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Shiva’s AirPods Pro #2)) (inputs: 1)
#   22: Microphone (Dell USB Audio) (inputs: 2)
#   24: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Shiva’s AirPods Pro #2 - Find My)) (inputs: 1)
#   27: PC Speaker (Realtek HD Audio 2nd output with SST) (inputs: 2)
#   30: PC Speaker (Realtek HD Audio output with SST) (inputs: 2)
#   31: Microphone Array (Realtek HD Audio Mic input) (inputs: 2)
#   32: Headset Microphone (Headset Microphone) (inputs: 2)
#   34: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Pablo’s AirPods #3)) (inputs: 1)
#   35: Input () (inputs: 2)
#   37: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Pablo’s AirPods #4)) (inputs: 1)
#   40: Input (@System32\drivers\bthhfenum.sys,#4;%1 Hands-Free HF Audio%0
# ;(iPhone de Pablo)) (inputs: 1)
#   42: Microphone (Lumina Camera - Raw) (inputs: 2)
#   45: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Pablo’s AirPods Pro - Find My)) (inputs: 1)
#
# 🔊 Available Audio Output Devices:
#   3: Microsoft Sound Mapper - Output (outputs: 2)
#   4: Surface Omnisonic Speakers (Sur (outputs: 2)
#   5: Speakers (Dell USB Audio) (outputs: 6)
#   9: Primary Sound Driver (outputs: 2)
#   10: Surface Omnisonic Speakers (Surface High Definition Audio) (outputs: 2)
#   11: Speakers (Dell USB Audio) (outputs: 6)
#   12: Speakers (Dell USB Audio) (outputs: 2)
#   13: Surface Omnisonic Speakers (Surface High Definition Audio) (outputs: 2)
#   16: Headphones () (outputs: 2)
#   18: Output (Microsoft Surface Thunderbolt(TM) 4 Dock Audio) (outputs: 2)
#   19: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Shiva’s AirPods Pro #2)) (outputs: 1)
#   21: Speakers (Dell USB Audio) (outputs: 6)
#   23: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Shiva’s AirPods Pro #2 - Find My)) (outputs: 1)
#   25: Headphones 1 (Realtek HD Audio 2nd output with SST) (outputs: 2)
#   26: Headphones 2 (Realtek HD Audio 2nd output with SST) (outputs: 2)
#   28: Speakers 1 (Realtek HD Audio output with SST) (outputs: 2)
#   29: Speakers 2 (Realtek HD Audio output with SST) (outputs: 2)
#   33: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Pablo’s AirPods #3)) (outputs: 1)
#   36: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Pablo’s AirPods #4)) (outputs: 1)
#   38: Headphones () (outputs: 2)
#   39: Output (@System32\drivers\bthhfenum.sys,#4;%1 Hands-Free HF Audio%0
# ;(iPhone de Pablo)) (outputs: 1)
#   41: Headphones () (outputs: 2)
#   43: Headphones () (outputs: 2)
#   44: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Pablo’s AirPods Pro - Find My)) (outputs: 1)
#   46: Headphones () (outputs: 2)
#
# 🎛️  Default Input Device: Surface Stereo Microphones (Sur
# 🎛️  Default Output Device: Surface Omnisonic Speakers (Sur
#
# ============================================================
# 🎤 Testing microphone for 3 seconds...
# Please speak into your microphone!
# 🎤 Testing microphone for 3 seconds...
# 💬 Please speak into your microphone...
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level:
# 📊 Volume level: █
# 📊 Volume level: ██
# 📊 Volume level: ██
# 📊 Volume level: ███
# 📊 Volume level: ███
# 📊 Volume level: █████
# 📊 Volume level: █████
# 📊 Volume level: ████
# 📊 Volume level:
# 📊 Volume level: █
# 📊 Volume level: ██
# 📊 Volume level: ██
# 📊 Volume level: ███
# 📊 Volume level: ███
# 📊 Volume level: █████
# 📊 Volume level: █████
# 📊 Volume level: ████
# 📊 Volume level: ███
# 📊 Volume level: ███
# ✅ Microphone test complete
# 📊 Volume level: ███
# 📊 Volume level: ███
# ✅ Microphone test complete

# %%
def run_voice_chat_debug():
    """
    Enhanced voice chat function with better debugging and error handling.
    """
    global stop_event
    connection = None  # Initialize connection variable
    
    try:
        # Reset the stop event for a fresh start
        stop_event.clear()
        
        print("🚀 Starting Voice Live chat application (DEBUG MODE)...")
        
        # 1. Connect to the API
        connection = client.connect(model=AZURE_VOICE_LIVE_MODEL)
        print("✅ Connected to Voice Live API")
        
        # 2. Send session configuration
        connection.send(json.dumps(session_config))
        print("✅ Session configuration sent")
        print(f"   Instructions: {session_config['session']['instructions'][:50]}...")
        print(f"   Voice: {session_config['session']['voice']['name']}")
        
        # 3. Wait a moment to receive session.created event
        print("⏳ Waiting for session creation...")
        time.sleep(2)
        
        # Check for any immediate messages
        for i in range(5):
            msg = connection.recv()
            if msg:
                try:
                    event = json.loads(msg)
                    print(f"📨 Received: {event.get('type', 'unknown')}")
                    if event.get('type') == 'session.created':
                        print(f"   Session ID: {event.get('session', {}).get('id', 'unknown')}")
                    elif event.get('type') == 'error':
                        print(f"❌ Error: {event.get('error', {})}")
                except:
                    print(f"📨 Raw message: {msg[:100]}...")
            else:
                break
        
        # 4. Create and start threads with better error handling
        print("🧵 Starting threads...")
        
        def safe_listen_and_send_audio(connection):
            try:
                listen_and_send_audio(connection)
            except Exception as e:
                print(f"❌ Audio input error: {e}")
                stop_event.set()
        
        def safe_receive_audio_and_playback(connection):
            try:
                receive_audio_and_playback(connection)
            except Exception as e:
                print(f"❌ Audio output error: {e}")
                stop_event.set()
        
        send_thread = threading.Thread(
            target=safe_listen_and_send_audio, 
            args=(connection,),
            name="AudioInput"
        )
        receive_thread = threading.Thread(
            target=safe_receive_audio_and_playback, 
            args=(connection,),
            name="AudioOutput"
        )
        
        # Start audio threads
        send_thread.start()
        receive_thread.start()
        
        print("🎙️  Voice chat is now active!")
        print("💬 You can start speaking...")
        print("📊 Monitoring audio threads...")
        
        # Monitor threads instead of waiting for keyboard input
        start_time = time.time()
        max_runtime = 60  # Maximum runtime in seconds before auto-shutdown
        
        while not stop_event.is_set():
            # Check if threads are still alive
            if not send_thread.is_alive():
                print("⚠️  Audio input thread died")
                stop_event.set()
                break
            if not receive_thread.is_alive():
                print("⚠️  Audio output thread died")
                stop_event.set()
                break
            
            # Auto-shutdown after max runtime to prevent hanging
            if time.time() - start_time > max_runtime:
                print(f"⏰ Auto-shutdown after {max_runtime} seconds")
                stop_event.set()
                break
            
            # Print status every 10 seconds
            if (time.time() - start_time) % 10 < 1:
                elapsed = int(time.time() - start_time)
                remaining = max_runtime - elapsed
                print(f"📊 Running {elapsed}s... Threads alive. {remaining}s remaining. Speak into your microphone!")
            
            time.sleep(1)
        
    except Exception as e:
        print(f"❌ Error in voice chat: {e}")
        import traceback
        traceback.print_exc()
        stop_event.set()
    
    finally:
        # ALWAYS ensure cleanup happens
        print("🛑 Shutting down...")
        stop_event.set()
        
        # Wait for threads to finish (with timeout)
        if 'send_thread' in locals() and send_thread.is_alive():
            send_thread.join(timeout=3)
            if send_thread.is_alive():
                print("⚠️  Audio input thread did not stop gracefully")
        
        if 'receive_thread' in locals() and receive_thread.is_alive():
            receive_thread.join(timeout=3)
            if receive_thread.is_alive():
                print("⚠️  Audio output thread did not stop gracefully")
        
        # Close connection - this is the critical fix
        if connection is not None:
            try:
                connection.close()
                print("✅ WebSocket connection closed properly")
            except Exception as e:
                print(f"⚠️  Error closing connection: {e}")
        else:
            print("ℹ️  No connection to close")
        
        print("✅ Voice chat cleanup completed")

print("✅ Debug voice chat function created with proper connection cleanup")
# Out:
# ✅ Debug voice chat function created with proper connection cleanup

# %%
# Run the debug version of voice chat
# This will show more detailed information about what's happening

# First check if we can see logs
print("📝 Checking recent logs:")
view_logs()

print("\n" + "="*60)
print("🚀 Starting DEBUG voice chat...")
print("This version will run for a while and show more status information")
print("Watch for error messages and connection status")

# Uncomment the line below to run debug version:
run_voice_chat_debug()

print("💡 Uncomment the line above to run the debug version")
# Out:
# 📝 Checking recent logs:
# 📝 Latest log file: logs\2025-09-03_08-36-51_voicelive_notebook.log
# 📄 Last 20 lines:
# File "c:\Users\pablosal\AppData\Local\anaconda3\envs\audioagent\Lib\site-packages\azure\identity\_credentials\shared_cache.py", line 152, in get_token
# token_info = self._get_token_base(*scopes, options=options, base_method_name="get_token", **kwargs)
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# File "c:\Users\pablosal\AppData\Local\anaconda3\envs\audioagent\Lib\site-packages\azure\identity\_credentials\shared_cache.py", line 186, in _get_token_base
# account = self._get_account(self._username, self._tenant_id, is_cae=is_cae)
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# File "c:\Users\pablosal\AppData\Local\anaconda3\envs\audioagent\Lib\site-packages\azure\identity\_internal\decorators.py", line 67, in wrapper
# return fn(*args, **kwargs)
# ^^^^^^^^^^^^^^^^^^^
# File "c:\Users\pablosal\AppData\Local\anaconda3\envs\audioagent\Lib\site-packages\azure\identity\_internal\shared_token_cache.py", line 209, in _get_account
# raise CredentialUnavailableError(message=NO_ACCOUNTS)
# azure.identity._exceptions.CredentialUnavailableError: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 2025-09-03 08:36:56,348:azure.identity._internal.decorators:DEBUG:AzureCliCredential.get_token succeeded
# 2025-09-03 08:36:56,350:azure.identity._internal.decorators:DEBUG:[Authenticated account] Client ID: 04b07795-8ddb-461a-bbee-02f9e1bf7b46. Tenant ID: 16b3c013-d300-468d-ac64-7eda0820b6d3. User Principal Name: unavailableUpn. Object ID (user): 9d5a93c3-a26f-4a69-b0a1-fc8b5c37b216
# 2025-09-03 08:36:56,350:azure.identity._credentials.chained:INFO:DefaultAzureCredential acquired a token from AzureCliCredential
# 2025-09-03 08:37:10,182:websocket:INFO:Websocket connected
# 2025-09-03 08:37:10,186:__main__:INFO:Connection 9d8f24c6: WebSocket opened
# 2025-09-03 08:37:10,187:__main__:DEBUG:Connection 9d8f24c6: Message #1 queued
# 2025-09-03 08:37:10,189:__main__:INFO:Connection 9d8f24c6: Closing connection
# 2025-09-03 08:37:11,232:__main__:INFO:Connection 9d8f24c6: WebSocket closed - None: None
#
# ============================================================
# 🚀 Starting DEBUG voice chat...
# This version will run for a while and show more status information
# Watch for error messages and connection status
# 🚀 Starting Voice Live chat application (DEBUG MODE)...
# 🔌 Establishing WebSocket connection (ID: 7761d417)...
# ✅ WebSocket connection opened (ID: 7761d417)
# ✅ Connection established successfully (ID: 7761d417)
# ✅ Connected to Voice Live API
# ✅ Session configuration sent
#    Instructions: You are a helpful AI assistant responding in natur...
#    Voice: en-US-Ava:DragonHDLatestNeural
# ⏳ Waiting for session creation...
# 📨 Received: session.created
#    Session ID: sess_DZ8HPdDk5zNCsudVulihN
# 📨 Received: session.updated
# 🧵 Starting threads...
# 🎙️  Voice chat is now active!
# 💬 You can start speaking...
# 📊 Monitoring audio threads...
# 📊 Running 0s... Threads alive. 60s remaining. Speak into your microphone!
# 🎧 Audio playback thread started - monitoring events...
# 📨 [08:37:35.885] Event #1: input_audio_buffer.speech_started
# 🗣️  Speech started - stopping AI playback
# 📨 [08:37:37.134] Event #2: input_audio_buffer.speech_stopped
# 🤐 Speech stopped - processing...
# 📨 [08:37:37.134] Event #3: input_audio_buffer.committed
# 🎤 Audio buffer committed: item_3cAWa8JjPTUDPkUF2QdY2e
# 📨 [08:37:37.326] Event #4: conversation.item.input_audio_transcription.completed
# ❓ Unknown event: conversation.item.input_audio_transcription.completed
# 📨 [08:37:37.326] Event #5: conversation.item.created
# 📝 Item created: message (item_3cAWa8JjPTUDPkUF2QdY2e)
#    Role: user
# 📨 [08:37:37.327] Event #6: response.created
# 🤖 Response created: resp_6PNQOSgx32Zfwkh238KrtR
# 📊 Running 10s... Threads alive. 50s remaining. Speak into your microphone!
# 📨 [08:37:37.515] Event #7: response.output_item.added
# ➕ Output item added: message (item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.517] Event #8: conversation.item.created
# 📝 Item created: message (item_2o82e0hgcKAQHDi5eIical)
#    Role: assistant
# 📨 [08:37:37.517] Event #9: response.content_part.added
# 🧩 Content part added: audio
# 📨 [08:37:37.517] Event #10: response.audio_transcript.delta
# 📝 Transcript delta: 'Hi' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.517] Event #11: response.audio_transcript.delta
# 📝 Transcript delta: ' there' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.527] Event #12: response.audio_transcript.delta
# 📝 Transcript delta: '!' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.538] Event #13: response.audio_transcript.delta
# 📝 Transcript delta: ' I'm' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.552] Event #14: response.audio_transcript.delta
# 📝 Transcript delta: ' just' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.559] Event #15: response.audio_transcript.delta
# 📝 Transcript delta: ' a' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.574] Event #16: response.audio_transcript.delta
# 📝 Transcript delta: ' bunch' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.588] Event #17: response.audio_transcript.delta
# 📝 Transcript delta: ' of' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.596] Event #18: response.audio_transcript.delta
# 📝 Transcript delta: ' ones' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.610] Event #19: response.audio_transcript.delta
# 📝 Transcript delta: ' and' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.616] Event #20: response.audio_transcript.delta
# 📝 Transcript delta: ' zeros' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.630] Event #21: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.641] Event #22: response.audio_transcript.delta
# 📝 Transcript delta: ' so' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.650] Event #23: response.audio_transcript.delta
# 📝 Transcript delta: ' I' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.759] Event #24: response.audio_transcript.delta
# 📝 Transcript delta: ' don't' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.761] Event #25: response.audio_transcript.delta
# 📝 Transcript delta: ' technically' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.761] Event #26: response.audio_transcript.delta
# 📝 Transcript delta: ' have' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.762] Event #27: response.audio_transcript.delta
# 📝 Transcript delta: ' feelings' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.764] Event #28: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.765] Event #29: response.audio_transcript.delta
# 📝 Transcript delta: ' but' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.766] Event #30: response.audio_transcript.delta
# 📝 Transcript delta: ' if' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.767] Event #31: response.audio_transcript.delta
# 📝 Transcript delta: ' I' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.768] Event #32: response.audio_transcript.delta
# 📝 Transcript delta: ' did' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.769] Event #33: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.771] Event #34: response.audio_transcript.delta
# 📝 Transcript delta: ' I'd' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.783] Event #35: response.audio_transcript.delta
# 📝 Transcript delta: ' say' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.794] Event #36: response.audio_transcript.delta
# 📝 Transcript delta: ' I'm' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.804] Event #37: response.audio_transcript.delta
# 📝 Transcript delta: ' doing' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.814] Event #38: response.audio_transcript.delta
# 📝 Transcript delta: ' great' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.828] Event #39: response.audio_transcript.delta
# 📝 Transcript delta: ' and' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.840] Event #40: response.audio_transcript.delta
# 📝 Transcript delta: ' ready' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.850] Event #41: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.861] Event #42: response.audio_transcript.delta
# 📝 Transcript delta: ' help' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.871] Event #43: response.audio_transcript.delta
# 📝 Transcript delta: '!' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.883] Event #44: response.audio_transcript.delta
# 📝 Transcript delta: ' How' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.893] Event #45: response.audio_transcript.delta
# 📝 Transcript delta: ' about' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.906] Event #46: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.914] Event #47: response.audio_transcript.delta
# 📝 Transcript delta: '?' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.924] Event #48: response.audio.delta
# 🎵 New audio item: item_2o82e0hgcKAQHDi5eIical
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:37.929] Event #49: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:37.930] Event #50: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:37:37.932] Event #51: response.audio_transcript.delta
# 📝 Transcript delta: ' How' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.939] Event #52: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:37.941] Event #53: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:37.942] Event #54: response.audio_transcript.delta
# 📝 Transcript delta: ''s' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.948] Event #55: response.audio_transcript.delta
# 📝 Transcript delta: ' your' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.954] Event #56: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:37.956] Event #57: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:37.962] Event #58: response.audio_transcript.delta
# 📝 Transcript delta: ' day' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.971] Event #59: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:37.973] Event #60: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:37.974] Event #61: response.audio_transcript.delta
# 📝 Transcript delta: ' going' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.980] Event #62: response.audio_transcript.delta
# 📝 Transcript delta: ' so' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:37.986] Event #63: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:37.989] Event #64: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:37.992] Event #65: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:37:37.992] Event #66: response.audio_transcript.delta
# 📝 Transcript delta: ' far' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:38.001] Event #67: response.audio_transcript.delta
# 📝 Transcript delta: '?' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:38.013] Event #68: response.audio_transcript.delta
# 📝 Transcript delta: ' 😊' (item: item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:38.303] Event #69: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.306] Event #70: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.306] Event #71: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:37:38.319] Event #72: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.319] Event #73: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:38.334] Event #74: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.335] Event #75: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:38.350] Event #76: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.351] Event #77: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:38.365] Event #78: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.366] Event #79: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:38.388] Event #80: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.390] Event #81: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:38.410] Event #82: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.411] Event #83: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:38.433] Event #84: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.434] Event #85: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:38.455] Event #86: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.457] Event #87: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:38.485] Event #88: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.488] Event #89: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.488] Event #90: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:37:38.515] Event #91: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.518] Event #92: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.519] Event #93: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:37:38.551] Event #94: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.554] Event #95: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.557] Event #96: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:37:38.587] Event #97: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.590] Event #98: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.591] Event #99: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:37:38.631] Event #100: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.636] Event #101: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.636] Event #102: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.636] Event #103: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [08:37:38.674] Event #104: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.677] Event #105: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.680] Event #106: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.681] Event #107: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [08:37:38.727] Event #108: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.729] Event #109: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.732] Event #110: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.733] Event #111: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.733] Event #112: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [08:37:38.786] Event #113: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.788] Event #114: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.791] Event #115: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.794] Event #116: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.795] Event #117: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [08:37:38.832] Event #118: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.836] Event #119: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.839] Event #120: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.843] Event #121: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.844] Event #122: response.audio.delta
# 🔊 Playing audio chunk: 2822 bytes
# 📨 [08:37:38.900] Event #123: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.903] Event #124: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.903] Event #125: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.904] Event #126: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.906] Event #127: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.906] Event #128: response.audio.delta
# 🔊 Playing audio chunk: 1126 bytes
# 📨 [08:37:38.968] Event #129: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:38.970] Event #130: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.973] Event #131: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.977] Event #132: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.977] Event #133: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:38.980] Event #134: response.audio.delta
# 🔊 Playing audio chunk: 3526 bytes
# 📨 [08:37:39.044] Event #135: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:39.048] Event #136: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.050] Event #137: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.053] Event #138: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.053] Event #139: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.056] Event #140: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.056] Event #141: response.audio.delta
# 🔊 Playing audio chunk: 588 bytes
# 📨 [08:37:39.058] Event #142: response.audio.delta
# 🔊 Playing audio chunk: 1242 bytes
# 📨 [08:37:39.129] Event #143: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:39.133] Event #144: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.135] Event #145: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.138] Event #146: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.140] Event #147: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.143] Event #148: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.143] Event #149: response.audio.delta
# 🔊 Playing audio chunk: 1986 bytes
# 📨 [08:37:39.144] Event #150: response.audio.delta
# 🔊 Playing audio chunk: 2244 bytes
# 📨 [08:37:39.225] Event #151: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:39.227] Event #152: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.230] Event #153: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.230] Event #154: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.234] Event #155: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.234] Event #156: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.237] Event #157: response.audio.delta
# 🔊 Playing audio chunk: 3384 bytes
# 📨 [08:37:39.240] Event #158: response.audio.delta
# 🔊 Playing audio chunk: 3246 bytes
# 📨 [08:37:39.321] Event #159: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:39.326] Event #160: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.329] Event #161: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.331] Event #162: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.336] Event #163: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.336] Event #164: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.340] Event #165: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.343] Event #166: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.343] Event #167: response.audio.delta
# 🔊 Playing audio chunk: 838 bytes
# 📨 [08:37:39.436] Event #168: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:39.440] Event #169: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.442] Event #170: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.444] Event #171: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.449] Event #172: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.451] Event #173: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.455] Event #174: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.456] Event #175: response.audio.delta
# 🔊 Playing audio chunk: 3482 bytes
# 📨 [08:37:39.456] Event #176: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.459] Event #177: response.audio.delta
# 🔊 Playing audio chunk: 2156 bytes
# 📨 [08:37:39.497] Event #178: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:39.500] Event #179: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.529] Event #180: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.557] Event #181: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.584] Event #182: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.615] Event #183: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.642] Event #184: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.669] Event #185: response.audio.delta
# 🔊 Playing audio chunk: 134 bytes
# 📨 [08:37:39.801] Event #186: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:39.804] Event #187: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.804] Event #188: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:37:39.815] Event #189: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:39.817] Event #190: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:39.832] Event #191: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:39.833] Event #192: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:39.848] Event #193: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:39.849] Event #194: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:39.864] Event #195: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:39.883] Event #196: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:39.886] Event #197: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:39.915] Event #198: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:39.943] Event #199: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:37:40.189] Event #200: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:40.193] Event #201: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:40.197] Event #202: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:37:40.206] Event #203: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:40.208] Event #204: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:40.216] Event #205: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:40.217] Event #206: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:40.232] Event #207: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:40.233] Event #208: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:40.250] Event #209: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:40.252] Event #210: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:40.274] Event #211: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:40.274] Event #212: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:40.294] Event #213: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:40.296] Event #214: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:40.316] Event #215: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:40.319] Event #216: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:40.338] Event #217: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:40.361] Event #218: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:40.383] Event #219: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:40.412] Event #220: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:40.450] Event #221: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:37:40.467] Event #222: response.audio.done
# ✅ Audio complete: item_2o82e0hgcKAQHDi5eIical
# 📨 [08:37:40.468] Event #223: response.audio_transcript.done
# ❓ Unknown event: response.audio_transcript.done
# 📨 [08:37:40.469] Event #224: response.content_part.done
# ✅ Content part done: audio
# 📨 [08:37:40.470] Event #225: response.output_item.done
# ✅ Output item done: message (item_2o82e0hgcKAQHDi5eIical)
# 📨 [08:37:40.470] Event #226: response.done
# ✅ Response complete: resp_6PNQOSgx32Zfwkh238KrtR (status: completed)
# 📨 [08:37:45.976] Event #227: input_audio_buffer.speech_started
# 🗣️  Speech started - stopping AI playback
# 📊 Running 20s... Threads alive. 40s remaining. Speak into your microphone!
# 📨 [08:37:50.709] Event #228: input_audio_buffer.speech_stopped
# 🤐 Speech stopped - processing...
# 📨 [08:37:50.710] Event #229: input_audio_buffer.committed
# 🎤 Audio buffer committed: item_39Ebw3DEp2ElTnd3Tgtxtt
# 📨 [08:37:51.126] Event #230: conversation.item.input_audio_transcription.completed
# ❓ Unknown event: conversation.item.input_audio_transcription.completed
# 📨 [08:37:51.126] Event #231: conversation.item.created
# 📝 Item created: message (item_39Ebw3DEp2ElTnd3Tgtxtt)
#    Role: user
# 📨 [08:37:51.127] Event #232: response.created
# 🤖 Response created: resp_eIzZJQKu2y8WSEQunqvGG
# 📨 [08:37:51.254] Event #233: response.output_item.added
# ➕ Output item added: message (item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.256] Event #234: conversation.item.created
# 📝 Item created: message (item_1oiDAdusUxsghG8kM92fZZ)
#    Role: assistant
# 📨 [08:37:51.256] Event #235: response.content_part.added
# 🧩 Content part added: audio
# 📨 [08:37:51.257] Event #236: response.audio_transcript.delta
# 📝 Transcript delta: 'Ah' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.257] Event #237: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.257] Event #238: response.audio_transcript.delta
# 📝 Transcript delta: ' I' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.258] Event #239: response.audio_transcript.delta
# 📝 Transcript delta: ' see' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.268] Event #240: response.audio_transcript.delta
# 📝 Transcript delta: ' you're' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.284] Event #241: response.audio_transcript.delta
# 📝 Transcript delta: ' curious' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.296] Event #242: response.audio_transcript.delta
# 📝 Transcript delta: '—' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.299] Event #243: response.audio_transcript.delta
# 📝 Transcript delta: 'awesome' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.304] Event #244: response.audio_transcript.delta
# 📝 Transcript delta: '!' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.316] Event #245: response.audio_transcript.delta
# 📝 Transcript delta: ' Think' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.321] Event #246: response.audio_transcript.delta
# 📝 Transcript delta: ' of' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.329] Event #247: response.audio_transcript.delta
# 📝 Transcript delta: ' me' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.339] Event #248: response.audio_transcript.delta
# 📝 Transcript delta: ' as' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.350] Event #249: response.audio_transcript.delta
# 📝 Transcript delta: ' your' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.360] Event #250: response.audio_transcript.delta
# 📝 Transcript delta: ' super' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.365] Event #251: response.audio_transcript.delta
# 📝 Transcript delta: '-smart' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.374] Event #252: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.382] Event #253: response.audio_transcript.delta
# 📝 Transcript delta: ' always' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.391] Event #254: response.audio_transcript.delta
# 📝 Transcript delta: '-h' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.400] Event #255: response.audio_transcript.delta
# 📝 Transcript delta: 'ere' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.407] Event #256: response.audio_transcript.delta
# 📝 Transcript delta: ' buddy' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.418] Event #257: response.audio_transcript.delta
# 📝 Transcript delta: '.' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.426] Event #258: response.audio_transcript.delta
# 📝 Transcript delta: ' I' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.450] Event #259: response.audio_transcript.delta
# 📝 Transcript delta: ' can' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.455] Event #260: response.audio_transcript.delta
# 📝 Transcript delta: ' help' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.473] Event #261: response.audio_transcript.delta
# 📝 Transcript delta: ' with' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.475] Event #262: response.audio_transcript.delta
# 📝 Transcript delta: ' all' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.475] Event #263: response.audio_transcript.delta
# 📝 Transcript delta: ' kinds' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.482] Event #264: response.audio_transcript.delta
# 📝 Transcript delta: ' of' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.490] Event #265: response.audio_transcript.delta
# 📝 Transcript delta: ' stuff' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.496] Event #266: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.510] Event #267: response.audio_transcript.delta
# 📝 Transcript delta: ' like' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.516] Event #268: response.audio_transcript.delta
# 📝 Transcript delta: ':
#
# ' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.523] Event #269: response.audio_transcript.delta
# 📝 Transcript delta: '-' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.532] Event #270: response.audio_transcript.delta
# 📝 Transcript delta: ' **' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.540] Event #271: response.audio_transcript.delta
# 📝 Transcript delta: 'Answer' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.553] Event #272: response.audio_transcript.delta
# 📝 Transcript delta: 'ing' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.559] Event #273: response.audio_transcript.delta
# 📝 Transcript delta: ' questions' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.567] Event #274: response.audio_transcript.delta
# 📝 Transcript delta: '**' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.591] Event #275: response.audio_transcript.delta
# 📝 Transcript delta: ':' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.593] Event #276: response.audio_transcript.delta
# 📝 Transcript delta: ' Need' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.607] Event #277: response.audio_transcript.delta
# 📝 Transcript delta: ' info' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.612] Event #278: response.audio_transcript.delta
# 📝 Transcript delta: ' on' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.624] Event #279: response.audio_transcript.delta
# 📝 Transcript delta: ' a' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.638] Event #280: response.audio_transcript.delta
# 📝 Transcript delta: ' topic' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.642] Event #281: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.654] Event #282: response.audio.delta
# 🎵 New audio item: item_1oiDAdusUxsghG8kM92fZZ
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:51.659] Event #283: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:51.659] Event #284: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:37:51.659] Event #285: response.audio_transcript.delta
# 📝 Transcript delta: ' historical' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.670] Event #286: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:51.671] Event #287: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:51.684] Event #288: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:51.686] Event #289: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:51.701] Event #290: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:51.701] Event #291: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:51.710] Event #292: response.audio_transcript.delta
# 📝 Transcript delta: ' fact' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.718] Event #293: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:51.719] Event #294: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:51.739] Event #295: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:51.741] Event #296: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:51.758] Event #297: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.763] Event #298: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:51.763] Event #299: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:51.768] Event #300: response.audio_transcript.delta
# 📝 Transcript delta: ' or' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.774] Event #301: response.audio_transcript.delta
# 📝 Transcript delta: ' how' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.788] Event #302: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:51.790] Event #303: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:51.790] Event #304: response.audio_transcript.delta
# 📝 Transcript delta: ' something' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.794] Event #305: response.audio_transcript.delta
# 📝 Transcript delta: ' works' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.804] Event #306: response.audio_transcript.delta
# 📝 Transcript delta: '?' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.810] Event #307: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:51.811] Event #308: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:51.813] Event #309: response.audio_transcript.delta
# 📝 Transcript delta: ' I'm' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.821] Event #310: response.audio_transcript.delta
# 📝 Transcript delta: ' your' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.838] Event #311: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:51.842] Event #312: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:51.842] Event #313: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:37:51.862] Event #314: response.audio_transcript.delta
# 📝 Transcript delta: ' go' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.863] Event #315: response.audio_transcript.delta
# 📝 Transcript delta: '-to' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.870] Event #316: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:51.871] Event #317: response.audio_transcript.delta
# 📝 Transcript delta: '!
# ' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.873] Event #318: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:51.874] Event #319: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:37:51.875] Event #320: response.audio_transcript.delta
# 📝 Transcript delta: '-' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.885] Event #321: response.audio_transcript.delta
# 📝 Transcript delta: ' **' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.896] Event #322: response.audio_transcript.delta
# 📝 Transcript delta: 'Problem' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.904] Event #323: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:51.906] Event #324: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:51.908] Event #325: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:37:51.908] Event #326: response.audio_transcript.delta
# 📝 Transcript delta: '-solving' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.916] Event #327: response.audio_transcript.delta
# 📝 Transcript delta: '**' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.924] Event #328: response.audio_transcript.delta
# 📝 Transcript delta: ':' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.938] Event #329: response.audio_transcript.delta
# 📝 Transcript delta: ' Math' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.940] Event #330: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:51.941] Event #331: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:51.942] Event #332: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:37:51.949] Event #333: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.953] Event #334: response.audio_transcript.delta
# 📝 Transcript delta: ' science' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.963] Event #335: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.976] Event #336: response.audio_transcript.delta
# 📝 Transcript delta: ' logic' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.989] Event #337: response.audio_transcript.delta
# 📝 Transcript delta: ' puzzles' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:51.989] Event #338: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:51.992] Event #339: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:51.995] Event #340: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:51.996] Event #341: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [08:37:51.998] Event #342: response.audio_transcript.delta
# 📝 Transcript delta: '—' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.001] Event #343: response.audio_transcript.delta
# 📝 Transcript delta: 'bring' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.006] Event #344: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:52.008] Event #345: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:52.011] Event #346: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:52.012] Event #347: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [08:37:52.016] Event #348: response.audio_transcript.delta
# 📝 Transcript delta: ' it' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.024] Event #349: response.audio_transcript.delta
# 📝 Transcript delta: ' on' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.033] Event #350: response.audio_transcript.delta
# 📝 Transcript delta: '!
# ' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.043] Event #351: response.audio_transcript.delta
# 📝 Transcript delta: '-' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.053] Event #352: response.audio_transcript.delta
# 📝 Transcript delta: ' **' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.064] Event #353: response.audio_transcript.delta
# 📝 Transcript delta: 'Writing' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.076] Event #354: response.audio_transcript.delta
# 📝 Transcript delta: ' help' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.084] Event #355: response.audio_transcript.delta
# 📝 Transcript delta: '**' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.094] Event #356: response.audio_transcript.delta
# 📝 Transcript delta: ':' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.132] Event #357: response.audio_transcript.delta
# 📝 Transcript delta: ' St' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.138] Event #358: response.audio_transcript.delta
# 📝 Transcript delta: 'uck' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.149] Event #359: response.audio_transcript.delta
# 📝 Transcript delta: ' on' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.166] Event #360: response.audio_transcript.delta
# 📝 Transcript delta: ' an' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.172] Event #361: response.audio_transcript.delta
# 📝 Transcript delta: ' essay' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.181] Event #362: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.198] Event #363: response.audio_transcript.delta
# 📝 Transcript delta: ' email' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.203] Event #364: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.210] Event #365: response.audio_transcript.delta
# 📝 Transcript delta: ' or' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.222] Event #366: response.audio_transcript.delta
# 📝 Transcript delta: ' creative' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.230] Event #367: response.audio_transcript.delta
# 📝 Transcript delta: ' piece' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.241] Event #368: response.audio_transcript.delta
# 📝 Transcript delta: '?' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.257] Event #369: response.audio_transcript.delta
# 📝 Transcript delta: ' I' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.260] Event #370: response.audio_transcript.delta
# 📝 Transcript delta: ' can' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.275] Event #371: response.audio_transcript.delta
# 📝 Transcript delta: ' help' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.282] Event #372: response.audio_transcript.delta
# 📝 Transcript delta: ' brainstorm' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.291] Event #373: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.300] Event #374: response.audio_transcript.delta
# 📝 Transcript delta: ' edit' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.313] Event #375: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:52.319] Event #376: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:52.319] Event #377: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.320] Event #378: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:37:52.320] Event #379: response.audio_transcript.delta
# 📝 Transcript delta: ' or' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.328] Event #380: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:52.328] Event #381: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:52.329] Event #382: response.audio_transcript.delta
# 📝 Transcript delta: ' polish' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.339] Event #383: response.audio_transcript.delta
# 📝 Transcript delta: ' it' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.344] Event #384: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:52.345] Event #385: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:52.349] Event #386: response.audio_transcript.delta
# 📝 Transcript delta: ' up' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.360] Event #387: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:52.361] Event #388: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:52.365] Event #389: response.audio_transcript.delta
# 📝 Transcript delta: '.
# ' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.370] Event #390: response.audio_transcript.delta
# 📝 Transcript delta: '-' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.376] Event #391: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:52.378] Event #392: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:52.378] Event #393: response.audio_transcript.delta
# 📝 Transcript delta: ' **' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.399] Event #394: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:52.401] Event #395: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:52.413] Event #396: response.audio_transcript.delta
# 📝 Transcript delta: 'Learning' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.422] Event #397: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:52.424] Event #398: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:52.424] Event #399: response.audio_transcript.delta
# 📝 Transcript delta: ' new' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.433] Event #400: response.audio_transcript.delta
# 📝 Transcript delta: ' things' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.442] Event #401: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:52.445] Event #402: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:52.445] Event #403: response.audio_transcript.delta
# 📝 Transcript delta: '**' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.459] Event #404: response.audio_transcript.delta
# 📝 Transcript delta: ':' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.467] Event #405: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:52.468] Event #406: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:52.469] Event #407: response.audio_transcript.delta
# 📝 Transcript delta: ' Want' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.476] Event #408: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.483] Event #409: response.audio_transcript.delta
# 📝 Transcript delta: ' pick' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.496] Event #410: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:52.500] Event #411: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:52.502] Event #412: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:37:52.502] Event #413: response.audio_transcript.delta
# 📝 Transcript delta: ' up' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.504] Event #414: response.audio_transcript.delta
# 📝 Transcript delta: ' a' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.521] Event #415: response.audio_transcript.delta
# 📝 Transcript delta: ' skill' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.525] Event #416: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:52.528] Event #417: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:52.529] Event #418: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:37:52.548] Event #419: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.557] Event #420: response.audio_transcript.delta
# 📝 Transcript delta: ' like' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.564] Event #421: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:52.565] Event #422: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:52.567] Event #423: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:37:52.568] Event #424: response.audio_transcript.delta
# 📝 Transcript delta: ' cooking' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.576] Event #425: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.590] Event #426: response.audio_transcript.delta
# 📝 Transcript delta: ' coding' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.598] Event #427: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:52.601] Event #428: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:52.601] Event #429: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.605] Event #430: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:37:52.608] Event #431: response.audio_transcript.delta
# 📝 Transcript delta: ' or' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.618] Event #432: response.audio_transcript.delta
# 📝 Transcript delta: ' anything' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.628] Event #433: response.audio_transcript.delta
# 📝 Transcript delta: ' else' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.638] Event #434: response.audio_transcript.delta
# 📝 Transcript delta: '?' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.640] Event #435: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:52.643] Event #436: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:52.645] Event #437: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:52.645] Event #438: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [08:37:52.648] Event #439: response.audio_transcript.delta
# 📝 Transcript delta: ' I' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.658] Event #440: response.audio_transcript.delta
# 📝 Transcript delta: ' can' (item: item_1oiDAdusUxsghG8kM92fZZ)
# 📨 [08:37:52.671] Event #441: response.audio_transcript.delta
# ...
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:59.156] Event #830: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:59.183] Event #831: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [08:37:59.200] Event #832: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:59.230] Event #833: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:59.262] Event #834: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:59.282] Event #835: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [08:37:59.298] Event #836: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:59.327] Event #837: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:59.353] Event #838: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:59.386] Event #839: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:59.410] Event #840: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [08:37:59.413] Event #841: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:59.442] Event #842: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:59.470] Event #843: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:37:59.497] Event #844: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:59.527] Event #845: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:59.553] Event #846: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:37:59.581] Event #847: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:59.608] Event #848: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:59.617] Event #849: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:59.644] Event #850: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:59.647] Event #851: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:59.672] Event #852: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:59.678] Event #853: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:59.704] Event #854: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:37:59.712] Event #855: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:59.808] Event #856: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:59.811] Event #857: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:59.815] Event #858: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:59.819] Event #859: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:59.841] Event #860: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:59.861] Event #861: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:59.889] Event #862: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:37:59.910] Event #863: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:37:59.939] Event #864: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:37:59.966] Event #865: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:37:59.977] Event #866: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:00.007] Event #867: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.033] Event #868: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:38:00.045] Event #869: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:00.079] Event #870: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.101] Event #871: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:38:00.127] Event #872: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:00.161] Event #873: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.189] Event #874: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:38:00.209] Event #875: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:00.240] Event #876: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.266] Event #877: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.295] Event #878: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [08:38:00.309] Event #879: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:00.338] Event #880: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.366] Event #881: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.394] Event #882: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [08:38:00.411] Event #883: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:00.441] Event #884: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.467] Event #885: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.497] Event #886: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.520] Event #887: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [08:38:00.526] Event #888: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:00.558] Event #889: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.581] Event #890: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.618] Event #891: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.638] Event #892: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [08:38:00.644] Event #893: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:00.671] Event #894: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.713] Event #895: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.726] Event #896: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.753] Event #897: response.audio.delta
# 🔊 Playing audio chunk: 2822 bytes
# 📨 [08:38:00.774] Event #898: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:00.802] Event #899: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.832] Event #900: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.859] Event #901: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.889] Event #902: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.916] Event #903: response.audio.delta
# 🔊 Playing audio chunk: 1126 bytes
# 📨 [08:38:00.923] Event #904: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:00.954] Event #905: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:00.980] Event #906: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:01.014] Event #907: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:01.041] Event #908: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:01.065] Event #909: response.audio.delta
# 🔊 Playing audio chunk: 3526 bytes
# 📨 [08:38:01.088] Event #910: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:01.120] Event #911: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:01.146] Event #912: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:01.185] Event #913: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:01.203] Event #914: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:01.238] Event #915: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:01.256] Event #916: response.audio.delta
# 🔊 Playing audio chunk: 588 bytes
# 📨 [08:38:01.261] Event #917: response.audio.delta
# 🔊 Playing audio chunk: 1242 bytes
# 📨 [08:38:01.272] Event #918: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:01.301] Event #919: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:01.327] Event #920: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:38:01.357] Event #921: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:01.383] Event #922: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:01.411] Event #923: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:38:01.439] Event #924: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:01.465] Event #925: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:01.470] Event #926: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:01.497] Event #927: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:01.504] Event #928: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:01.530] Event #929: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:01.536] Event #930: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:01.563] Event #931: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:01.570] Event #932: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:01.598] Event #933: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:38:01.618] Event #934: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:01.648] Event #935: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:38:01.668] Event #936: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:01.696] Event #937: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:01.725] Event #938: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:38:01.759] Event #939: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:01.780] Event #940: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:01.808] Event #941: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:38:01.837] Event #942: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:01.862] Event #943: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:01.867] Event #944: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:01.895] Event #945: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:01.906] Event #946: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:01.927] Event #947: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:01.932] Event #948: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:01.972] Event #949: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:01.973] Event #950: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:02.011] Event #951: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:38:02.018] Event #952: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:02.048] Event #953: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:38:02.066] Event #954: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:02.096] Event #955: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:38:02.140] Event #956: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:02.150] Event #957: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:38:02.165] Event #958: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:02.197] Event #959: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:02.220] Event #960: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:38:02.231] Event #961: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:02.260] Event #962: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:02.291] Event #963: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:38:02.310] Event #964: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:02.326] Event #965: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:02.354] Event #966: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:38:02.382] Event #967: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:02.408] Event #968: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:02.437] Event #969: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:38:02.465] Event #970: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:02.499] Event #971: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:02.522] Event #972: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:02.547] Event #973: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [08:38:02.563] Event #974: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:02.592] Event #975: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:02.621] Event #976: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:02.648] Event #977: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [08:38:02.663] Event #978: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:02.690] Event #979: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:02.722] Event #980: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:02.749] Event #981: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:02.775] Event #982: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [08:38:02.778] Event #983: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:02.817] Event #984: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:02.836] Event #985: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:02.865] Event #986: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:02.890] Event #987: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [08:38:02.894] Event #988: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:02.923] Event #989: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:02.952] Event #990: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:02.979] Event #991: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:03.007] Event #992: response.audio.delta
# 🔊 Playing audio chunk: 2822 bytes
# 📨 [08:38:03.029] Event #993: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:03.056] Event #994: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:03.083] Event #995: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:03.116] Event #996: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:03.143] Event #997: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:03.171] Event #998: response.audio.delta
# 🔊 Playing audio chunk: 1126 bytes
# 📨 [08:38:03.179] Event #999: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:03.205] Event #1000: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:03.233] Event #1001: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:03.262] Event #1002: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:03.290] Event #1003: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:03.318] Event #1004: response.audio.delta
# 🔊 Playing audio chunk: 3526 bytes
# 📨 [08:38:03.342] Event #1005: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 🛑 Shutting down...
# 📨 [08:38:03.372] Event #1006: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# ✅ Audio playback thread completed (1006 events processed)
# 🔌 Closing WebSocket connection (ID: 7761d417)...
# 🔌 WebSocket connection closed (ID: 7761d417)
#    Status: None, Message: None
# ✅ Connection closed (ID: 7761d417, 1017 messages processed)
# ✅ WebSocket connection closed properly
# ✅ Voice chat cleanup completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 14
#      11 print("Watch for error messages and connection status")
#      13 # Uncomment the line below to run debug version:
# ---> 14 run_voice_chat_debug()
#      16 print("💡 Uncomment the line above to run the debug version")
#
# Cell In[13], line 107, in run_voice_chat_debug()
#     104             remaining = max_runtime - elapsed
#     105             print(f"📊 Running {elapsed}s... Threads alive. {remaining}s remaining. Speak into your microphone!")
# --> 107         time.sleep(1)
#     109 except Exception as e:
#     110     print(f"❌ Error in voice chat: {e}")
#
# KeyboardInterrupt:

# %% [markdown]
# ## **12. Azure AI Agent Service Integration**
#
# Azure AI Agent Service provides enterprise-grade conversational AI with:
# - **Centralized prompt management** in Azure AI Foundry portal
# - **Version-controlled agent configurations**
# - **Multi-tenant agent deployment**
# - **Business logic separation** from client code
#
# ### **Agent vs Direct Model Comparison**
#
# | Aspect | Direct Model | Azure AI Agent Service |
# |--------|--------------|-------------------------|
# | **Instructions** | Client-side code | Azure portal managed |
# | **Updates** | Code deployment | Portal configuration |
# | **Scalability** | Manual management | Enterprise multi-tenant |
# | **Governance** | Developer-controlled | Business-user accessible |
#
# ### **Environment Configuration**
#
# **Standard AI Foundry Projects (Recommended):**
# ```env
# # Required for AI Foundry Projects
# AI_FOUNDRY_PROJECT_NAME=your-project-name
# AI_FOUNDRY_AGENT_ID=asst_xxxxxxxxxxxxx
#
# # Standard Voice Live API
# AZURE_VOICE_LIVE_ENDPOINT=https://your-resource.cognitiveservices.azure.com
# AZURE_VOICE_LIVE_API_VERSION=2025-05-01-preview
# ```
#
# **Hub-based Projects (Legacy):**
# ```env
# # Required for Hub-based Projects
# AI_FOUNDRY_AGENT_ID=asst_xxxxxxxxxxxxx
# AI_FOUNDRY_AGENT_CONNECTION_STRING=your-connection-string
#
# # Standard Voice Live API
# AZURE_VOICE_LIVE_ENDPOINT=https://your-resource.cognitiveservices.azure.com
# AZURE_VOICE_LIVE_API_VERSION=2025-05-01-preview
# ```
#
# **Note:** Most users should use the standard AI Foundry project approach with `PROJECT_NAME` + `AGENT_ID`. The connection string is only needed for legacy hub-based deployments.

# %%
class AzureVoiceLiveAgent:
    """
    Enterprise Azure Voice Live client with Agent Service integration.
    
    Supports both AI Foundry project-based (recommended) and hub-based deployments.
    """
    
    def __init__(self, azure_endpoint: str, api_version: str = "2025-05-01-preview"):
        self._azure_endpoint = azure_endpoint
        self._api_version = api_version
        self._credential = DefaultAzureCredential()
        self._connection = None
    
    def connect_agent(self, project_name: str = None, agent_id: str = None, 
                     connection_string: str = None) -> VoiceLiveConnection:
        """
        Connect to Azure AI Agent Service.
        
        Standard AI Foundry Projects (Recommended):
            project_name: AI Foundry project name
            agent_id: Agent ID from Azure portal
            
        Hub-based Projects (Legacy):
            agent_id: Agent ID from Azure portal  
            connection_string: Connection string from Azure portal
        """
        if not agent_id:
            raise ValueError("Agent ID is required")
            
        # Get authentication tokens
        voice_token = self._credential.get_token("https://ai.azure.com/.default")
        
        # Build WebSocket URL
        ws_endpoint = self._azure_endpoint.replace("https://", "wss://")
        
        if project_name:
            # Standard AI Foundry project-based deployment (recommended)
            agent_token = voice_token  # Use same token for project-based
            url = (f"{ws_endpoint}/voice-live/realtime?"
                   f"api-version={self._api_version}&"
                   f"agent-project-name={project_name}&"
                   f"agent-id={agent_id}&"
                   f"agent-access-token={agent_token.token}")
            print(f"✅ Using AI Foundry project: {project_name}")
            
        elif connection_string:
            # Hub-based deployment (legacy)
            agent_token = self._credential.get_token("https://ml.azure.com/.default")
            url = (f"{ws_endpoint}/voice-live/realtime?"
                   f"api-version={self._api_version}&"
                   f"agent-connection-string={connection_string}&"
                   f"agent-id={agent_id}&"
                   f"agent-access-token={agent_token.token}")
            print(f"✅ Using hub-based connection (legacy)")
            
        else:
            raise ValueError("Either project_name (recommended) or connection_string (legacy) is required")
        
        # Setup headers
        headers = {
            "Authorization": f"Bearer {voice_token.token}",
            "x-ms-client-request-id": str(uuid.uuid4())
        }
        
        # Create and connect
        self._connection = VoiceLiveConnection(url, headers)
        self._connection.connect()
        return self._connection
    
    def create_agent_session_config(self, voice_name: str = "en-US-Ava:DragonHDLatestNeural") -> dict:
        """Create optimized session configuration for agent deployment."""
        return {
            "type": "session.update",
            "session": {
                "turn_detection": {
                    "type": "azure_semantic_vad",
                    "threshold": 0.3,
                    "prefix_padding_ms": 200,
                    "silence_duration_ms": 200,
                    "remove_filler_words": False,
                    "end_of_utterance_detection": {
                        "model": "semantic_detection_v1",
                        "threshold": 0.01,
                        "timeout": 2,
                    },
                },
                "input_audio_noise_reduction": {"type": "azure_deep_noise_suppression"},
                "input_audio_echo_cancellation": {"type": "server_echo_cancellation"},
                "voice": {
                    "name": voice_name,
                    "type": "azure-standard", 
                    "temperature": 0.8,
                },
            },
            "event_id": ""
        }

# Initialize enterprise agent client
agent_client = AzureVoiceLiveAgent(
    azure_endpoint=AZURE_VOICE_LIVE_ENDPOINT,
    api_version=AZURE_VOICE_LIVE_API_VERSION
)

print("✅ Enterprise Azure Voice Live Agent client initialized")
print(f"   Endpoint: {AZURE_VOICE_LIVE_ENDPOINT}")
print(f"   API Version: {AZURE_VOICE_LIVE_API_VERSION}")
print("   Deployment: Standard AI Foundry project (recommended) or hub-based (legacy)")
# Out:
# ✅ Enterprise Azure Voice Live Agent client initialized
#    Endpoint: https://poc-ai-agents-voice-resource.cognitiveservices.azure.com/
#    API Version: 2025-05-01-preview
#    Deployment: Standard AI Foundry project (recommended) or hub-based (legacy)

# %%
def run_agent_voice_application():
    """
    Run Azure AI Agent Service voice application with comprehensive event logging.
    
    Enterprise-grade implementation with proper error handling,
    logging, and graceful shutdown.
    """
    global stop_event
    connection = None
    threads = []
    
    # Check if already running
    if not stop_event.is_set():
        print("⚠️  Stopping any previous instance...")
        stop_event.set()
        time.sleep(2)
    
    try:
        stop_event.clear()
        
        print("🚀 Starting Azure AI Agent Service voice application")
        print(f"   Timestamp: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
        
        # Load agent configuration from environment
        project_name = os.environ.get("AI_FOUNDRY_PROJECT_NAME")
        agent_id = os.environ.get("AI_FOUNDRY_AGENT_ID") 
        connection_string = os.environ.get("AI_FOUNDRY_AGENT_CONNECTION_STRING")
        
        print(f"📋 Configuration Check:")
        print(f"   Project Name: {project_name or '❌ Not set'}")
        print(f"   Agent ID: {agent_id or '❌ Not set'}")
        print(f"   Connection String: {'✅ Set' if connection_string else '❌ Not set (hub-based only)'}")
        
        if not agent_id:
            raise ValueError("AI_FOUNDRY_AGENT_ID environment variable required")
        
        # Determine deployment type and connect
        if project_name:
            deployment_type = "AI Foundry Project (Recommended)"
            print(f"✅ Using deployment type: {deployment_type}")
            print(f"   Agent ID: {agent_id}")
            print(f"   Project: {project_name}")
            
            # Connect using project name (recommended)
            print("🔌 Connecting to Azure AI Agent Service...")
            connection = agent_client.connect_agent(
                project_name=project_name,
                agent_id=agent_id
            )
            
        elif connection_string:
            deployment_type = "Hub-based (Legacy)"
            print(f"✅ Using deployment type: {deployment_type}")
            print(f"   Agent ID: {agent_id}")
            
            # Connect using connection string (legacy)
            print("🔌 Connecting to Azure AI Agent Service...")
            connection = agent_client.connect_agent(
                agent_id=agent_id,
                connection_string=connection_string
            )
            
        else:
            raise ValueError(
                "Either AI_FOUNDRY_PROJECT_NAME (recommended) or "
                "AI_FOUNDRY_AGENT_CONNECTION_STRING (legacy) is required"
            )
        
        print("✅ Connected to Azure AI Agent Service")
        
        # Configure session
        print("⚙️  Configuring agent session...")
        session_config = agent_client.create_agent_session_config()
        connection.send(json.dumps(session_config))
        print("✅ Agent session configuration sent")
        
        # Wait a moment for session to be established
        print("⏳ Waiting for session establishment...")
        time.sleep(2)
        
        # Start audio processing threads
        print("🧵 Starting audio processing threads...")
        
        def safe_listen_and_send_audio(connection):
            try:
                listen_and_send_audio(connection)
            except Exception as e:
                print(f"❌ Audio input thread error: {e}")
                logger.error(f"Audio input error: {e}")
                stop_event.set()
        
        def safe_receive_audio_and_playback(connection):
            try:
                receive_audio_and_playback(connection)
            except Exception as e:
                print(f"❌ Audio output thread error: {e}")
                logger.error(f"Audio output error: {e}")
                stop_event.set()
        
        def safe_read_keyboard_and_quit():
            try:
                read_keyboard_and_quit()
            except Exception as e:
                print(f"❌ Keyboard input thread error: {e}")
                logger.error(f"Keyboard input error: {e}")
                stop_event.set()
        
        audio_threads = [
            threading.Thread(target=safe_listen_and_send_audio, args=(connection,), name="AudioInput"),
            threading.Thread(target=safe_receive_audio_and_playback, args=(connection,), name="AudioOutput"),
            threading.Thread(target=safe_read_keyboard_and_quit, name="UserInput")
        ]
        
        for i, thread in enumerate(audio_threads):
            thread.start()
            threads.append(thread)
            print(f"   ✅ Thread {i+1} started: {thread.name}")
        
        print("=" * 60)
        print("🎙️  Agent voice application is now ACTIVE!")
        print("💬 Start speaking - your conversation is managed by the Azure AI agent")
        print("📊 All events will be logged below")
        print("⌨️  Press 'q' + Enter to quit")
        print("=" * 60)
        
        # Wait for user to quit or error
        threads[2].join()  # Wait for keyboard thread
        
    except Exception as e:
        print(f"❌ Application error: {e}")
        logger.error(f"Agent application error: {e}")
        import traceback
        traceback.print_exc()
        
    finally:
        print("\n" + "=" * 60)
        print("🛑 Shutting down agent application...")
        stop_event.set()
        
        # Wait for threads with timeout
        print("⏳ Waiting for threads to complete...")
        for i, thread in enumerate(threads):
            if thread.is_alive():
                print(f"   Stopping thread {i+1}: {thread.name}")
                thread.join(timeout=5)
                if thread.is_alive():
                    print(f"   ⚠️  Thread {i+1} ({thread.name}) did not stop gracefully")
                else:
                    print(f"   ✅ Thread {i+1} ({thread.name}) stopped")
        
        # Close connection
        if connection:
            try:
                print("🔌 Closing agent connection...")
                connection.close()
                print("✅ Agent connection closed successfully")
            except Exception as e:
                print(f"⚠️  Connection cleanup error: {e}")
                logger.error(f"Connection cleanup error: {e}")
        else:
            print("ℹ️  No connection to close")
        
        print("✅ Azure AI Agent Service application shutdown complete")
        print("=" * 60)

print("✅ Azure AI Agent Service voice application function ready")
print("   This provides comprehensive event logging for debugging and monitoring")
# Out:
# ✅ Azure AI Agent Service voice application function ready
#    This provides comprehensive event logging for debugging and monitoring

# %% [markdown]
# ## **13. Run Azure AI Agent Service Application**
#
# ### **Production Voice Application**
#
# Execute the enterprise-grade voice application with comprehensive event logging and Azure AI Agent Service integration.
#
# **Prerequisites:**
# - Azure AI Foundry resource with Voice Live API enabled
# - Created agent in Azure AI Foundry portal
# - Environment variables configured (see below)
# - Audio devices (headset recommended for production)
#
# **Required Environment Variables:**
# - `AI_FOUNDRY_AGENT_ID` - Your agent ID from Azure AI Foundry portal
# - `AI_FOUNDRY_PROJECT_NAME` - Your project name (recommended for standard projects)
#
# **Optional (Legacy Hub-based Projects):**
# - `AI_FOUNDRY_AGENT_CONNECTION_STRING` - Only needed for hub-based deployments

# %%
run_agent_voice_application()
# Out:
# 🚀 Starting Azure AI Agent Service voice application
#    Timestamp: 2025-09-03 08:38:33
# 📋 Configuration Check:
#    Project Name: poc-ai-agents-voice
#    Agent ID: asst_Kp4exd80NINFuraHyWOftsuR
#    Connection String: ❌ Not set (hub-based only)
# ✅ Using deployment type: AI Foundry Project (Recommended)
#    Agent ID: asst_Kp4exd80NINFuraHyWOftsuR
#    Project: poc-ai-agents-voice
# 🔌 Connecting to Azure AI Agent Service...
# ✅ Using AI Foundry project: poc-ai-agents-voice
# 🔌 Establishing WebSocket connection (ID: 1bff6c8d)...
# ✅ WebSocket connection opened (ID: 1bff6c8d)
# ✅ Connection established successfully (ID: 1bff6c8d)
# ✅ Connected to Azure AI Agent Service
# ⚙️  Configuring agent session...
# ✅ Agent session configuration sent
# ⏳ Waiting for session establishment...
# 🧵 Starting audio processing threads...
#    ✅ Thread 1 started: AudioInput
#    ✅ Thread 2 started: AudioOutput
# Press 'q' and Enter to quit the chat.
#    ✅ Thread 3 started: UserInput
# ============================================================
# 🎙️  Agent voice application is now ACTIVE!
# 💬 Start speaking - your conversation is managed by the Azure AI agent
# 📊 All events will be logged below
# ⌨️  Press 'q' + Enter to quit
# ============================================================
# 🎧 Audio playback thread started - monitoring events...
# 📨 [08:38:38.951] Event #1: session.created
# ✅ Session created: sess_1SQELucVsMWiBHXHlofDE6
#    Instructions: You are a professional customer service agent for an e-commerce company. Your primary objective is t...
#    Voice: en-US-AvaNeural
# 📨 [08:38:38.951] Event #2: session.updated
# 🔄 Session updated
#    Voice: en-US-Ava:DragonHDLatestNeural
#    VAD: azure_semantic_vad
# 📨 [08:38:41.706] Event #3: input_audio_buffer.speech_started
# 🗣️  Speech started - stopping AI playback
# 📨 [08:38:43.604] Event #4: input_audio_buffer.speech_stopped
# 🤐 Speech stopped - processing...
# 📨 [08:38:43.605] Event #5: input_audio_buffer.committed
# 🎤 Audio buffer committed: item_b1zFXcpFLRuqMUG2QltL9
# 📨 [08:38:43.883] Event #6: conversation.item.input_audio_transcription.completed
# ❓ Unknown event: conversation.item.input_audio_transcription.completed
# 📨 [08:38:43.884] Event #7: conversation.item.created
# 📝 Item created: message (item_b1zFXcpFLRuqMUG2QltL9)
#    Role: user
# 📨 [08:38:43.884] Event #8: response.created
# 🤖 Response created: resp_3PZlRcicabtnIneIG0gL3Z
# 📨 [08:38:45.771] Event #9: response.output_item.added
# ➕ Output item added: message (item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.773] Event #10: conversation.item.created
# 📝 Item created: message (item_V0nwnLEUmTYXHwdgifGHd)
#    Role: assistant
# 📨 [08:38:45.773] Event #11: response.content_part.added
# 🧩 Content part added: audio
# 📨 [08:38:45.773] Event #12: response.audio_transcript.delta
# 📝 Transcript delta: 'Hi' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.780] Event #13: response.audio_transcript.delta
# 📝 Transcript delta: ' there' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.785] Event #14: response.audio_transcript.delta
# 📝 Transcript delta: '!' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.785] Event #15: response.audio_transcript.delta
# 📝 Transcript delta: ' I'm' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.794] Event #16: response.audio_transcript.delta
# 📝 Transcript delta: ' here' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.800] Event #17: response.audio_transcript.delta
# 📝 Transcript delta: ' and' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.807] Event #18: response.audio_transcript.delta
# 📝 Transcript delta: ' happy' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.813] Event #19: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.818] Event #20: response.audio_transcript.delta
# 📝 Transcript delta: ' help' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.840] Event #21: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.840] Event #22: response.audio_transcript.delta
# 📝 Transcript delta: '.' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.841] Event #23: response.audio_transcript.delta
# 📝 Transcript delta: ' How' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.847] Event #24: response.audio_transcript.delta
# 📝 Transcript delta: ' can' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.851] Event #25: response.audio_transcript.delta
# 📝 Transcript delta: ' I' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.856] Event #26: response.audio_transcript.delta
# 📝 Transcript delta: ' assist' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.861] Event #27: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.866] Event #28: response.audio_transcript.delta
# 📝 Transcript delta: ' today' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:45.870] Event #29: response.audio_transcript.delta
# 📝 Transcript delta: '?' (item: item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:46.184] Event #30: response.audio.delta
# 🎵 New audio item: item_V0nwnLEUmTYXHwdgifGHd
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.185] Event #31: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:46.187] Event #32: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:38:46.199] Event #33: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.199] Event #34: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:46.212] Event #35: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.213] Event #36: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:46.227] Event #37: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.229] Event #38: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:46.232] Event #39: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:38:46.534] Event #40: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.537] Event #41: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:46.539] Event #42: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:38:46.549] Event #43: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.550] Event #44: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:46.566] Event #45: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.567] Event #46: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:46.583] Event #47: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.583] Event #48: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:46.597] Event #49: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.599] Event #50: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:46.619] Event #51: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.622] Event #52: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:38:46.644] Event #53: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.644] Event #54: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:38:46.667] Event #55: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.669] Event #56: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:38:46.690] Event #57: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.692] Event #58: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:38:46.724] Event #59: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.726] Event #60: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:46.728] Event #61: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:38:46.752] Event #62: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.756] Event #63: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:46.757] Event #64: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:38:46.779] Event #65: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.781] Event #66: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:46.786] Event #67: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:46.787] Event #68: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:46.787] Event #69: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [08:38:46.882] Event #70: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.885] Event #71: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:46.886] Event #72: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:38:46.897] Event #73: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.899] Event #74: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:46.911] Event #75: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.914] Event #76: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:46.928] Event #77: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.929] Event #78: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:46.944] Event #79: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.944] Event #80: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:46.969] Event #81: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.969] Event #82: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:38:46.990] Event #83: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:46.991] Event #84: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:38:47.038] Event #85: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:47.040] Event #86: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:38:47.042] Event #87: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:47.042] Event #88: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:47.044] Event #89: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:38:47.044] Event #90: response.audio.done
# ✅ Audio complete: item_V0nwnLEUmTYXHwdgifGHd
# 📨 [08:38:47.044] Event #91: response.audio_transcript.done
# ❓ Unknown event: response.audio_transcript.done
# 📨 [08:38:47.046] Event #92: response.content_part.done
# ✅ Content part done: audio
# 📨 [08:38:47.046] Event #93: response.output_item.done
# ✅ Output item done: message (item_V0nwnLEUmTYXHwdgifGHd)
# 📨 [08:38:47.046] Event #94: response.done
# ✅ Response complete: resp_3PZlRcicabtnIneIG0gL3Z (status: cancelled)
# 📨 [08:38:51.587] Event #95: input_audio_buffer.speech_started
# 🗣️  Speech started - stopping AI playback
# 📨 [08:38:53.952] Event #96: input_audio_buffer.speech_stopped
# 🤐 Speech stopped - processing...
# 📨 [08:38:53.953] Event #97: input_audio_buffer.committed
# 🎤 Audio buffer committed: item_74umu8jwm4f8GrV5PD5QWp
# 📨 [08:38:54.142] Event #98: conversation.item.input_audio_transcription.completed
# ❓ Unknown event: conversation.item.input_audio_transcription.completed
# 📨 [08:38:54.144] Event #99: conversation.item.created
# 📝 Item created: message (item_74umu8jwm4f8GrV5PD5QWp)
#    Role: user
# 📨 [08:38:54.144] Event #100: response.created
# 🤖 Response created: resp_35dH3T5VTdUQ0TJtE9hB93
# 📨 [08:38:54.837] Event #101: input_audio_buffer.speech_started
# 🗣️  Speech started - stopping AI playback
# 📨 [08:38:55.229] Event #102: response.done
# ✅ Response complete: resp_35dH3T5VTdUQ0TJtE9hB93 (status: cancelled)
# 📨 [08:38:55.819] Event #103: input_audio_buffer.speech_stopped
# 🤐 Speech stopped - processing...
# 📨 [08:38:55.820] Event #104: input_audio_buffer.committed
# 🎤 Audio buffer committed: item_1jxTRc5CzjztgPd2bOrRmJ
# 📨 [08:38:55.984] Event #105: conversation.item.input_audio_transcription.completed
# ❓ Unknown event: conversation.item.input_audio_transcription.completed
# 📨 [08:38:55.985] Event #106: conversation.item.created
# 📝 Item created: message (item_1jxTRc5CzjztgPd2bOrRmJ)
#    Role: user
# 📨 [08:38:55.985] Event #107: response.created
# 🤖 Response created: resp_2rgoYQdvvqxn0R19mOgbnP
# 📨 [08:38:58.180] Event #108: response.output_item.added
# ➕ Output item added: message (item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.181] Event #109: conversation.item.created
# 📝 Item created: message (item_3Vv5E8ji2q5NDGJ4NjyM94)
#    Role: assistant
# 📨 [08:38:58.181] Event #110: response.content_part.added
# 🧩 Content part added: audio
# 📨 [08:38:58.182] Event #111: response.audio_transcript.delta
# 📝 Transcript delta: 'I' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.182] Event #112: response.audio_transcript.delta
# 📝 Transcript delta: ' can' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.189] Event #113: response.audio_transcript.delta
# 📝 Transcript delta: ' assist' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.194] Event #114: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.202] Event #115: response.audio_transcript.delta
# 📝 Transcript delta: ' with' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.209] Event #116: response.audio_transcript.delta
# 📝 Transcript delta: ' various' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.214] Event #117: response.audio_transcript.delta
# 📝 Transcript delta: ' inquiries' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.220] Event #118: response.audio_transcript.delta
# 📝 Transcript delta: ' and' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.226] Event #119: response.audio_transcript.delta
# 📝 Transcript delta: ' concerns' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.236] Event #120: response.audio_transcript.delta
# 📝 Transcript delta: ' related' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.238] Event #121: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.243] Event #122: response.audio_transcript.delta
# 📝 Transcript delta: ' your' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.250] Event #123: response.audio_transcript.delta
# 📝 Transcript delta: ' orders' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.256] Event #124: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.260] Event #125: response.audio_transcript.delta
# 📝 Transcript delta: ' our' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.270] Event #126: response.audio_transcript.delta
# 📝 Transcript delta: ' company' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.273] Event #127: response.audio_transcript.delta
# 📝 Transcript delta: ' policies' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.278] Event #128: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.287] Event #129: response.audio_transcript.delta
# 📝 Transcript delta: ' or' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.292] Event #130: response.audio_transcript.delta
# 📝 Transcript delta: ' any' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.297] Event #131: response.audio_transcript.delta
# 📝 Transcript delta: ' issues' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.302] Event #132: response.audio_transcript.delta
# 📝 Transcript delta: ' you're' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.308] Event #133: response.audio_transcript.delta
# 📝 Transcript delta: ' experiencing' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.313] Event #134: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.320] Event #135: response.audio_transcript.delta
# 📝 Transcript delta: ' such' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.326] Event #136: response.audio_transcript.delta
# 📝 Transcript delta: ' as' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.331] Event #137: response.audio_transcript.delta
# 📝 Transcript delta: ':
#
# ' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.337] Event #138: response.audio_transcript.delta
# 📝 Transcript delta: '-' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.341] Event #139: response.audio_transcript.delta
# 📝 Transcript delta: ' **' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.347] Event #140: response.audio_transcript.delta
# 📝 Transcript delta: 'Order' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.354] Event #141: response.audio_transcript.delta
# 📝 Transcript delta: ' Assistance' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.357] Event #142: response.audio_transcript.delta
# 📝 Transcript delta: '**' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.368] Event #143: response.audio_transcript.delta
# 📝 Transcript delta: ':' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.391] Event #144: response.audio_transcript.delta
# 📝 Transcript delta: ' Check' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.397] Event #145: response.audio_transcript.delta
# 📝 Transcript delta: ' the' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.402] Event #146: response.audio_transcript.delta
# 📝 Transcript delta: ' status' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.408] Event #147: response.audio_transcript.delta
# 📝 Transcript delta: ' of' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.416] Event #148: response.audio_transcript.delta
# 📝 Transcript delta: ' your' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.420] Event #149: response.audio_transcript.delta
# 📝 Transcript delta: ' order' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.423] Event #150: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.429] Event #151: response.audio_transcript.delta
# 📝 Transcript delta: ' provide' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.439] Event #152: response.audio_transcript.delta
# 📝 Transcript delta: ' tracking' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.447] Event #153: response.audio_transcript.delta
# 📝 Transcript delta: ' details' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.452] Event #154: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.470] Event #155: response.audio_transcript.delta
# 📝 Transcript delta: ' or' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.470] Event #156: response.audio_transcript.delta
# 📝 Transcript delta: ' confirm' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.475] Event #157: response.audio_transcript.delta
# 📝 Transcript delta: ' delivery' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.537] Event #158: response.audio_transcript.delta
# 📝 Transcript delta: ' dates' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.541] Event #159: response.audio_transcript.delta
# 📝 Transcript delta: '.
# ' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.646] Event #160: response.audio_transcript.delta
# 📝 Transcript delta: '-' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.651] Event #161: response.audio_transcript.delta
# 📝 Transcript delta: ' **' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.672] Event #162: response.audio_transcript.delta
# 📝 Transcript delta: 'Company' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.698] Event #163: response.audio.delta
# 🎵 New audio item: item_3Vv5E8ji2q5NDGJ4NjyM94
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:58.702] Event #164: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:58.702] Event #165: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:38:58.711] Event #166: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:58.712] Event #167: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:58.717] Event #168: response.audio_transcript.delta
# 📝 Transcript delta: ' Info' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.728] Event #169: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:58.728] Event #170: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:58.743] Event #171: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:58.745] Event #172: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:58.759] Event #173: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:58.759] Event #174: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:38:58.768] Event #175: response.audio_transcript.delta
# 📝 Transcript delta: '**' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.787] Event #176: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:58.789] Event #177: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:38:58.909] Event #178: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:58.910] Event #179: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:38:58.912] Event #180: response.audio_transcript.delta
# 📝 Transcript delta: ':' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.915] Event #181: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:58.918] Event #182: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:38:58.923] Event #183: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:58.924] Event #184: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:38:58.926] Event #185: response.audio_transcript.delta
# 📝 Transcript delta: ' Provide' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.926] Event #186: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:58.928] Event #187: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:58.928] Event #188: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:38:58.928] Event #189: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:58.929] Event #190: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:58.929] Event #191: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:38:58.929] Event #192: response.audio_transcript.delta
# 📝 Transcript delta: ' information' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.946] Event #193: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:58.949] Event #194: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:58.952] Event #195: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:38:58.968] Event #196: response.audio_transcript.delta
# 📝 Transcript delta: ' on' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:58.982] Event #197: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:58.985] Event #198: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:58.985] Event #199: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:38:59.023] Event #200: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:59.025] Event #201: response.audio_transcript.delta
# 📝 Transcript delta: ' policies' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:59.028] Event #202: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.030] Event #203: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.031] Event #204: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [08:38:59.069] Event #205: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:59.071] Event #206: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.073] Event #207: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.074] Event #208: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [08:38:59.084] Event #209: response.audio_transcript.delta
# 📝 Transcript delta: ' such' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:59.119] Event #210: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:59.121] Event #211: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.123] Event #212: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.125] Event #213: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.126] Event #214: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [08:38:59.147] Event #215: response.audio_transcript.delta
# 📝 Transcript delta: ' as' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:59.170] Event #216: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:59.173] Event #217: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.174] Event #218: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.177] Event #219: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.178] Event #220: response.audio.delta
# 🔊 Playing audio chunk: 422 bytes
# 📨 [08:38:59.208] Event #221: response.audio_transcript.delta
# 📝 Transcript delta: ' returns' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:59.228] Event #222: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:59.230] Event #223: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.232] Event #224: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.236] Event #225: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.236] Event #226: response.audio.delta
# 🔊 Playing audio chunk: 2822 bytes
# 📨 [08:38:59.274] Event #227: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:59.292] Event #228: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:59.295] Event #229: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.296] Event #230: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.298] Event #231: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.298] Event #232: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.298] Event #233: response.audio.delta
# 🔊 Playing audio chunk: 1126 bytes
# 📨 [08:38:59.339] Event #234: response.audio_transcript.delta
# 📝 Transcript delta: ' shipping' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:59.365] Event #235: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:59.366] Event #236: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.366] Event #237: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.368] Event #238: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.371] Event #239: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.372] Event #240: response.audio.delta
# 🔊 Playing audio chunk: 3526 bytes
# 📨 [08:38:59.406] Event #241: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:59.440] Event #242: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:59.443] Event #243: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.444] Event #244: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.446] Event #245: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.448] Event #246: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.450] Event #247: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.450] Event #248: response.audio.delta
# 🔊 Playing audio chunk: 588 bytes
# 📨 [08:38:59.451] Event #249: response.audio.delta
# 🔊 Playing audio chunk: 1242 bytes
# 📨 [08:38:59.512] Event #250: response.audio_transcript.delta
# 📝 Transcript delta: ' payments' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:59.524] Event #251: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:59.526] Event #252: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.528] Event #253: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.530] Event #254: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.533] Event #255: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.536] Event #256: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.538] Event #257: response.audio.delta
# 🔊 Playing audio chunk: 3384 bytes
# 📨 [08:38:59.538] Event #258: response.audio.delta
# 🔊 Playing audio chunk: 846 bytes
# 📨 [08:38:59.561] Event #259: response.audio_transcript.delta
# 📝 Transcript delta: ',' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:59.618] Event #260: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:59.620] Event #261: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.622] Event #262: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.624] Event #263: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.628] Event #264: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.630] Event #265: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.632] Event #266: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.632] Event #267: response.audio.delta
# 🔊 Playing audio chunk: 686 bytes
# 📨 [08:38:59.632] Event #268: response.audio.delta
# 🔊 Playing audio chunk: 1848 bytes
# 📨 [08:38:59.632] Event #269: response.audio_transcript.delta
# 📝 Transcript delta: ' or' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:59.693] Event #270: response.audio_transcript.delta
# 📝 Transcript delta: ' warranties' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:59.699] Event #271: response.audio_transcript.delta
# 📝 Transcript delta: '.
# ' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:59.719] Event #272: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:59.720] Event #273: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.725] Event #274: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.726] Event #275: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.730] Event #276: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.733] Event #277: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.734] Event #278: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.736] Event #279: response.audio.delta
# 🔊 Playing audio chunk: 2084 bytes
# 📨 [08:38:59.739] Event #280: response.audio.delta
# 🔊 Playing audio chunk: 2850 bytes
# 📨 [08:38:59.739] Event #281: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:38:59.740] Event #282: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:38:59.740] Event #283: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:38:59.741] Event #284: response.audio_transcript.delta
# 📝 Transcript delta: '-' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:59.741] Event #285: response.audio_transcript.delta
# 📝 Transcript delta: ' **' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:59.758] Event #286: response.audio_transcript.delta
# 📝 Transcript delta: 'Resolve' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:59.772] Event #287: response.audio_transcript.delta
# 📝 Transcript delta: ' Issues' (item: item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:38:59.793] Event #288: input_audio_buffer.speech_started
# 🗣️  Speech started - stopping AI playback
# 📨 [08:39:00.040] Event #289: response.audio.done
# ✅ Audio complete: item_3Vv5E8ji2q5NDGJ4NjyM94
# 📨 [08:39:00.040] Event #290: response.audio_transcript.done
# ❓ Unknown event: response.audio_transcript.done
# 📨 [08:39:00.040] Event #291: response.content_part.done
# ✅ Content part done: audio
# 📨 [08:39:00.040] Event #292: response.output_item.done
# ✅ Output item done: message (item_3Vv5E8ji2q5NDGJ4NjyM94)
# 📨 [08:39:00.349] Event #293: input_audio_buffer.speech_stopped
# 🤐 Speech stopped - processing...
# 📨 [08:39:00.349] Event #294: input_audio_buffer.committed
# 🎤 Audio buffer committed: item_DOdxkpbP9vCvzmJ8JHASd
# 📨 [08:39:00.730] Event #295: response.done
# ✅ Response complete: resp_2rgoYQdvvqxn0R19mOgbnP (status: cancelled)
# 📨 [08:39:02.477] Event #296: conversation.item.input_audio_transcription.completed
# ❓ Unknown event: conversation.item.input_audio_transcription.completed
# 📨 [08:39:02.478] Event #297: conversation.item.created
# 📝 Item created: message (item_DOdxkpbP9vCvzmJ8JHASd)
#    Role: user
# 📨 [08:39:02.478] Event #298: response.created
# 🤖 Response created: resp_13MkBcVusb7cNrUsumwq0l
# 📨 [08:39:04.163] Event #299: response.output_item.added
# ➕ Output item added: message (item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.164] Event #300: conversation.item.created
# 📝 Item created: message (item_7jXPEmt61bTSvxVXiv6zTf)
#    Role: assistant
# 📨 [08:39:04.165] Event #301: response.content_part.added
# 🧩 Content part added: audio
# 📨 [08:39:04.166] Event #302: response.audio_transcript.delta
# 📝 Transcript delta: 'It' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.171] Event #303: response.audio_transcript.delta
# 📝 Transcript delta: ' seems' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.174] Event #304: response.audio_transcript.delta
# 📝 Transcript delta: ' like' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.181] Event #305: response.audio_transcript.delta
# 📝 Transcript delta: ' your' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.188] Event #306: response.audio_transcript.delta
# 📝 Transcript delta: ' message' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.196] Event #307: response.audio_transcript.delta
# 📝 Transcript delta: ' was' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.211] Event #308: response.audio_transcript.delta
# 📝 Transcript delta: ' cut' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.232] Event #309: response.audio_transcript.delta
# 📝 Transcript delta: ' off' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.250] Event #310: response.audio_transcript.delta
# 📝 Transcript delta: ' again' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.268] Event #311: response.audio_transcript.delta
# 📝 Transcript delta: '.' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.292] Event #312: response.audio_transcript.delta
# 📝 Transcript delta: ' Could' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.305] Event #313: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.324] Event #314: response.audio_transcript.delta
# 📝 Transcript delta: ' let' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.369] Event #315: response.audio_transcript.delta
# 📝 Transcript delta: ' me' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.530] Event #316: response.audio_transcript.delta
# 📝 Transcript delta: ' know' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.537] Event #317: response.audio_transcript.delta
# 📝 Transcript delta: ' how' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.537] Event #318: response.audio_transcript.delta
# 📝 Transcript delta: ' I' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.538] Event #319: response.audio_transcript.delta
# 📝 Transcript delta: ' can' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.539] Event #320: response.audio_transcript.delta
# 📝 Transcript delta: ' assist' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.558] Event #321: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.567] Event #322: response.audio_transcript.delta
# 📝 Transcript delta: '?' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.587] Event #323: response.audio_transcript.delta
# 📝 Transcript delta: ' Feel' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.607] Event #324: response.audio_transcript.delta
# 📝 Transcript delta: ' free' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.625] Event #325: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:04.642] Event #326: input_audio_buffer.speech_started
# 🗣️  Speech started - stopping AI playback
# 📨 [08:39:04.646] Event #327: response.audio.done
# ✅ Audio complete: item_7jXPEmt61bTSvxVXiv6zTf
# 📨 [08:39:04.647] Event #328: response.audio_transcript.done
# ❓ Unknown event: response.audio_transcript.done
# 📨 [08:39:04.647] Event #329: response.content_part.done
# ✅ Content part done: audio
# 📨 [08:39:04.647] Event #330: response.output_item.done
# ✅ Output item done: message (item_7jXPEmt61bTSvxVXiv6zTf)
# 📨 [08:39:05.009] Event #331: response.done
# ✅ Response complete: resp_13MkBcVusb7cNrUsumwq0l (status: cancelled)
# 📨 [08:39:05.711] Event #332: input_audio_buffer.speech_stopped
# 🤐 Speech stopped - processing...
# 📨 [08:39:05.711] Event #333: input_audio_buffer.committed
# 🎤 Audio buffer committed: item_3GL1d4gLpeizs8IC0k3dvZ
# 📨 [08:39:05.976] Event #334: conversation.item.input_audio_transcription.completed
# ❓ Unknown event: conversation.item.input_audio_transcription.completed
# 📨 [08:39:05.978] Event #335: conversation.item.created
# 📝 Item created: message (item_3GL1d4gLpeizs8IC0k3dvZ)
#    Role: user
# 📨 [08:39:05.978] Event #336: response.created
# 🤖 Response created: resp_6J0B8xsv7aRhCful8GSNKM
# 📨 [08:39:08.290] Event #337: response.output_item.added
# ➕ Output item added: message (item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.292] Event #338: conversation.item.created
# 📝 Item created: message (item_DXxDIH9nXe23J7uApLINV)
#    Role: assistant
# 📨 [08:39:08.293] Event #339: response.content_part.added
# 🧩 Content part added: audio
# 📨 [08:39:08.293] Event #340: response.audio_transcript.delta
# 📝 Transcript delta: 'No' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.294] Event #341: response.audio_transcript.delta
# 📝 Transcript delta: ' worries' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.294] Event #342: response.audio_transcript.delta
# 📝 Transcript delta: ' at' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.316] Event #343: response.audio_transcript.delta
# 📝 Transcript delta: ' all' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.316] Event #344: response.audio_transcript.delta
# 📝 Transcript delta: '!' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.317] Event #345: response.audio_transcript.delta
# 📝 Transcript delta: ' Could' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.322] Event #346: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.339] Event #347: response.audio_transcript.delta
# 📝 Transcript delta: ' let' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.352] Event #348: response.audio_transcript.delta
# 📝 Transcript delta: ' me' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.374] Event #349: response.audio_transcript.delta
# 📝 Transcript delta: ' know' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.388] Event #350: response.audio_transcript.delta
# 📝 Transcript delta: ' what' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.402] Event #351: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.411] Event #352: response.audio_transcript.delta
# 📝 Transcript delta: ' need' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.428] Event #353: response.audio_transcript.delta
# 📝 Transcript delta: ' help' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.445] Event #354: response.audio_transcript.delta
# 📝 Transcript delta: ' with' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.457] Event #355: response.audio_transcript.delta
# 📝 Transcript delta: '?' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.475] Event #356: response.audio_transcript.delta
# 📝 Transcript delta: ' I' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.488] Event #357: response.audio_transcript.delta
# 📝 Transcript delta: '’m' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.506] Event #358: response.audio_transcript.delta
# 📝 Transcript delta: ' here' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.521] Event #359: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.536] Event #360: response.audio_transcript.delta
# 📝 Transcript delta: ' assist' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.546] Event #361: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.568] Event #362: response.audio_transcript.delta
# 📝 Transcript delta: '.' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.581] Event #363: response.audio_transcript.delta
# 📝 Transcript delta: ' Feel' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.597] Event #364: response.audio_transcript.delta
# 📝 Transcript delta: ' free' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.627] Event #365: response.audio_transcript.delta
# 📝 Transcript delta: ' to' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.627] Event #366: response.audio_transcript.delta
# 📝 Transcript delta: ' share' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.636] Event #367: response.audio_transcript.delta
# 📝 Transcript delta: ' any' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.668] Event #368: response.audio_transcript.delta
# 📝 Transcript delta: ' details' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.674] Event #369: response.audio_transcript.delta
# 📝 Transcript delta: ' about' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.694] Event #370: response.audio_transcript.delta
# 📝 Transcript delta: ' your' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.703] Event #371: response.audio.delta
# 🎵 New audio item: item_DXxDIH9nXe23J7uApLINV
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:08.704] Event #372: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:39:08.707] Event #373: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:39:08.707] Event #374: response.audio_transcript.delta
# 📝 Transcript delta: ' question' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.713] Event #375: response.audio_transcript.delta
# 📝 Transcript delta: ' or' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.717] Event #376: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:08.720] Event #377: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:39:08.735] Event #378: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:08.736] Event #379: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:39:08.736] Event #380: response.audio_transcript.delta
# 📝 Transcript delta: ' concern' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.744] Event #381: response.audio_transcript.delta
# 📝 Transcript delta: '!' (item: item_DXxDIH9nXe23J7uApLINV)
# 📨 [08:39:08.751] Event #382: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:08.751] Event #383: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:39:08.766] Event #384: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:08.767] Event #385: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:39:08.788] Event #386: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:08.790] Event #387: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:39:08.812] Event #388: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:08.813] Event #389: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:39:08.819] Event #390: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:08.821] Event #391: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:39:08.821] Event #392: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:39:09.031] Event #393: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.032] Event #394: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:39:09.034] Event #395: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:39:09.044] Event #396: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.045] Event #397: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:39:09.061] Event #398: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.062] Event #399: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:39:09.078] Event #400: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.078] Event #401: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:39:09.093] Event #402: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.093] Event #403: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:39:09.118] Event #404: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.119] Event #405: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:39:09.137] Event #406: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.140] Event #407: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:39:09.160] Event #408: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.162] Event #409: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:39:09.183] Event #410: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.185] Event #411: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:39:09.212] Event #412: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.215] Event #413: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:39:09.217] Event #414: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:39:09.243] Event #415: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.244] Event #416: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:39:09.245] Event #417: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:39:09.278] Event #418: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.281] Event #419: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:39:09.282] Event #420: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:39:09.315] Event #421: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.315] Event #422: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:39:09.319] Event #423: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:39:09.320] Event #424: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:39:09.322] Event #425: response.audio.delta
# 🔊 Playing audio chunk: 2822 bytes
# 📨 [08:39:09.617] Event #426: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.620] Event #427: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:39:09.622] Event #428: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:39:09.628] Event #429: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.630] Event #430: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:39:09.647] Event #431: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.648] Event #432: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:39:09.783] Event #433: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.784] Event #434: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:39:09.786] Event #435: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.790] Event #436: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:39:09.790] Event #437: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.791] Event #438: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:39:09.793] Event #439: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.798] Event #440: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:39:09.798] Event #441: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.800] Event #442: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:39:09.802] Event #443: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:39:09.802] Event #444: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [08:39:09.860] Event #445: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.863] Event #446: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:39:09.866] Event #447: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:39:09.875] Event #448: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.877] Event #449: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:39:09.891] Event #450: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.891] Event #451: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:39:09.910] Event #452: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.911] Event #453: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:39:09.921] Event #454: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.921] Event #455: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:39:09.943] Event #456: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.944] Event #457: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:39:09.968] Event #458: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.970] Event #459: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:39:09.989] Event #460: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:09.991] Event #461: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:39:10.012] Event #462: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:39:10.014] Event #463: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# ...
# 🗣️  Speech started - stopping AI playback
# 📨 [08:40:42.609] Event #992: input_audio_buffer.speech_stopped
# 🤐 Speech stopped - processing...
# 📨 [08:40:42.611] Event #993: input_audio_buffer.committed
# 🎤 Audio buffer committed: item_7YJVTibDlEOXdUccTpAnFi
# 📨 [08:40:42.867] Event #994: conversation.item.input_audio_transcription.completed
# ❓ Unknown event: conversation.item.input_audio_transcription.completed
# 📨 [08:40:42.868] Event #995: conversation.item.created
# 📝 Item created: message (item_7YJVTibDlEOXdUccTpAnFi)
#    Role: user
# 📨 [08:40:42.869] Event #996: response.created
# 🤖 Response created: resp_3DNh3jj8Ulj9fiDuj3jigB
# 📨 [08:40:44.290] Event #997: response.output_item.added
# ➕ Output item added: message (item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.291] Event #998: conversation.item.created
# 📝 Item created: message (item_3xf2ijvys95FM1nIvRcxa3)
#    Role: assistant
# 📨 [08:40:44.291] Event #999: response.content_part.added
# 🧩 Content part added: audio
# 📨 [08:40:44.291] Event #1000: response.audio_transcript.delta
# 📝 Transcript delta: 'I' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.297] Event #1001: response.audio_transcript.delta
# 📝 Transcript delta: ' apologize' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.301] Event #1002: response.audio_transcript.delta
# 📝 Transcript delta: ' for' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.407] Event #1003: response.audio_transcript.delta
# 📝 Transcript delta: ' the' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.407] Event #1004: response.audio_transcript.delta
# 📝 Transcript delta: ' delay' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.407] Event #1005: response.audio_transcript.delta
# 📝 Transcript delta: '.' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.409] Event #1006: response.audio_transcript.delta
# 📝 Transcript delta: ' I'm' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.410] Event #1007: response.audio_transcript.delta
# 📝 Transcript delta: ' still' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.410] Event #1008: response.audio_transcript.delta
# 📝 Transcript delta: ' retrieving' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.410] Event #1009: response.audio_transcript.delta
# 📝 Transcript delta: ' the' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.410] Event #1010: response.audio_transcript.delta
# 📝 Transcript delta: ' status' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.412] Event #1011: response.audio_transcript.delta
# 📝 Transcript delta: ' of' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.412] Event #1012: response.audio_transcript.delta
# 📝 Transcript delta: ' your' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.412] Event #1013: response.audio_transcript.delta
# 📝 Transcript delta: ' order' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.413] Event #1014: response.audio_transcript.delta
# 📝 Transcript delta: '.' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.413] Event #1015: response.audio_transcript.delta
# 📝 Transcript delta: ' Let' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.413] Event #1016: response.audio_transcript.delta
# 📝 Transcript delta: ' me' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.447] Event #1017: response.audio_transcript.delta
# 📝 Transcript delta: ' double' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.447] Event #1018: response.audio_transcript.delta
# 📝 Transcript delta: '-check' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.453] Event #1019: response.audio_transcript.delta
# 📝 Transcript delta: ' this' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.454] Event #1020: response.audio_transcript.delta
# 📝 Transcript delta: ' for' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.502] Event #1021: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.502] Event #1022: response.audio_transcript.delta
# 📝 Transcript delta: ' right' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.504] Event #1023: response.audio_transcript.delta
# 📝 Transcript delta: ' away' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.526] Event #1024: response.audio_transcript.delta
# 📝 Transcript delta: '.' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.532] Event #1025: response.audio_transcript.delta
# 📝 Transcript delta: ' Thank' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.555] Event #1026: response.audio_transcript.delta
# 📝 Transcript delta: ' you' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.557] Event #1027: response.audio_transcript.delta
# 📝 Transcript delta: ' for' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.575] Event #1028: response.audio_transcript.delta
# 📝 Transcript delta: ' your' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.586] Event #1029: response.audio_transcript.delta
# 📝 Transcript delta: ' patience' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.603] Event #1030: response.audio_transcript.delta
# 📝 Transcript delta: '!' (item: item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:44.899] Event #1031: response.audio.delta
# 🎵 New audio item: item_3xf2ijvys95FM1nIvRcxa3
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:44.903] Event #1032: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:40:44.906] Event #1033: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:40:44.908] Event #1034: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:44.909] Event #1035: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:40:44.912] Event #1036: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:44.915] Event #1037: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:40:44.915] Event #1038: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:44.918] Event #1039: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:40:44.920] Event #1040: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:44.920] Event #1041: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:40:44.920] Event #1042: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:44.922] Event #1043: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:40:44.923] Event #1044: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:44.923] Event #1045: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:40:44.951] Event #1046: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:44.953] Event #1047: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:40:44.966] Event #1048: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:44.969] Event #1049: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:40:44.982] Event #1050: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:44.985] Event #1051: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:40:44.988] Event #1052: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:40:45.284] Event #1053: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.288] Event #1054: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:40:45.288] Event #1055: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:40:45.300] Event #1056: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.301] Event #1057: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:40:45.316] Event #1058: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.318] Event #1059: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:40:45.332] Event #1060: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.332] Event #1061: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:40:45.349] Event #1062: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.350] Event #1063: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:40:45.371] Event #1064: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.374] Event #1065: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:40:45.394] Event #1066: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.396] Event #1067: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:40:45.415] Event #1068: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.418] Event #1069: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:40:45.454] Event #1070: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.455] Event #1071: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:40:45.477] Event #1072: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.479] Event #1073: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:40:45.479] Event #1074: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:40:45.499] Event #1075: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.502] Event #1076: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:40:45.502] Event #1077: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:40:45.523] Event #1078: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.527] Event #1079: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:40:45.527] Event #1080: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:40:45.527] Event #1081: response.audio.delta
# 🔊 Playing audio chunk: 2118 bytes
# 📨 [08:40:45.825] Event #1082: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.826] Event #1083: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:40:45.828] Event #1084: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:40:45.841] Event #1085: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.841] Event #1086: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:40:45.856] Event #1087: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.857] Event #1088: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:40:45.871] Event #1089: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.872] Event #1090: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:40:45.888] Event #1091: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.889] Event #1092: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:40:45.909] Event #1093: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.914] Event #1094: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:40:45.934] Event #1095: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.936] Event #1096: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:40:45.955] Event #1097: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.957] Event #1098: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:40:45.978] Event #1099: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:45.979] Event #1100: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:40:46.008] Event #1101: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:46.011] Event #1102: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:40:46.012] Event #1103: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:40:46.038] Event #1104: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:46.041] Event #1105: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:40:46.041] Event #1106: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:40:46.047] Event #1107: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:46.049] Event #1108: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:40:46.049] Event #1109: response.audio.delta
# 🔊 Playing audio chunk: 1414 bytes
# 📨 [08:40:46.350] Event #1110: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:46.353] Event #1111: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:40:46.355] Event #1112: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:40:46.363] Event #1113: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:46.365] Event #1114: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:40:46.378] Event #1115: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:46.380] Event #1116: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:40:46.394] Event #1117: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:46.395] Event #1118: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:40:46.410] Event #1119: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:46.411] Event #1120: response.audio.delta
# 🔊 Playing audio chunk: 710 bytes
# 📨 [08:40:46.433] Event #1121: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:46.435] Event #1122: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:40:46.458] Event #1123: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:46.459] Event #1124: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:40:46.483] Event #1125: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:46.485] Event #1126: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:40:46.506] Event #1127: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:46.507] Event #1128: response.audio.delta
# 🔊 Playing audio chunk: 3110 bytes
# 📨 [08:40:46.519] Event #1129: response.audio.delta
# 🔊 Playing audio chunk: 4090 bytes
# 📨 [08:40:46.523] Event #1130: response.audio.delta
# 🔊 Playing audio chunk: 4096 bytes
# 📨 [08:40:46.524] Event #1131: response.audio.delta
# 🔊 Playing audio chunk: 3814 bytes
# 📨 [08:40:46.525] Event #1132: response.audio.done
# ✅ Audio complete: item_3xf2ijvys95FM1nIvRcxa3
# 📨 [08:40:46.525] Event #1133: response.audio_transcript.done
# ❓ Unknown event: response.audio_transcript.done
# 📨 [08:40:46.525] Event #1134: response.content_part.done
# ✅ Content part done: audio
# 📨 [08:40:46.526] Event #1135: response.output_item.done
# ✅ Output item done: message (item_3xf2ijvys95FM1nIvRcxa3)
# 📨 [08:40:46.526] Event #1136: response.done
# ✅ Response complete: resp_3DNh3jj8Ulj9fiDuj3jigB (status: cancelled)
# Quitting the chat...
#
# ============================================================
# 🛑 Shutting down agent application...
# ⏳ Waiting for threads to complete...
#    Stopping thread 1: AudioInput
#    ✅ Thread 1 (AudioInput) stopped
#    Stopping thread 2: AudioOutput
# ✅ Audio playback thread completed (1136 events processed)
#    ✅ Thread 2 (AudioOutput) stopped
# 🔌 Closing agent connection...
# 🔌 Closing WebSocket connection (ID: 1bff6c8d)...
# 🔌 WebSocket connection closed (ID: 1bff6c8d)
#    Status: None, Message: None
# ✅ WebSocket thread stopped (ID: 1bff6c8d)
# ✅ Connection closed (ID: 1bff6c8d, 1136 messages processed)
# ✅ Agent connection closed successfully
# ✅ Azure AI Agent Service application shutdown complete
# ============================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 run_agent_voice_application()
#
# Cell In[17], line 127, in run_agent_voice_application()
#     124     print("=" * 60)
#     126     # Wait for user to quit or error
# --> 127     threads[2].join()  # Wait for keyboard thread
#     129 except Exception as e:
#     130     print(f"❌ Application error: {e}")
#
# File c:\Users\pablosal\AppData\Local\anaconda3\envs\audioagent\Lib\threading.py:1119, in Thread.join(self, timeout)
#    1116     raise RuntimeError("cannot join current thread")
#    1118 if timeout is None:
# -> 1119     self._wait_for_tstate_lock()
#    1120 else:
#    1121     # the behavior of a negative timeout isn't documented, but
#    1122     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1123     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File c:\Users\pablosal\AppData\Local\anaconda3\envs\audioagent\Lib\threading.py:1139, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1136     return
#    1138 try:
# -> 1139     if lock.acquire(block, timeout):
#    1140         lock.release()
#    1141         self._stop()
#
# KeyboardInterrupt:
