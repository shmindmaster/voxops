# %%
import logging
import os

# set the directory to the location of the script
try:
    os.chdir("../../..")
    target_directory = os.getenv(
        "TARGET_DIRECTORY", os.getcwd()
    )  # Use environment variable if available
    if os.path.exists(target_directory):
        os.chdir(target_directory)
        print(f"Changed directory to: {os.getcwd()}")
        logging.info(f"Successfully changed directory to: {os.getcwd()}")
    else:
        logging.error(f"Directory does not exist: {target_directory}")
except Exception as e:
    logging.exception(f"An error occurred while changing directory: {e}")
# Out:
# Changed directory to: c:\Users\pablosal\Desktop\gbb-ai-audio-agent

# %%
RUN_ID = "32005880-9dc1-408a-950c-e53ef24c648d"

# %% [markdown]
# ## Access Cache (redis)

# %%
from src.stateful.state_managment import (
    MemoManager,
)
from src.redis.manager import AzureRedisManager

REDIS_HOST=os.getenv("REDIS_HOST",)
REDIS_ACCESS_KEY=os.getenv("REDIS_ACCESS_KEY",)
REDIS_PORT=os.getenv("REDIS_PORT")

redis_manager = AzureRedisManager(access_key=REDIS_ACCESS_KEY, host=REDIS_HOST, port=REDIS_PORT)
# Out:
# [2025-08-26 09:56:33,878] INFO - src.redis.manager: Azure Redis connection initialized with access key.
# INFO:src.redis.manager:Azure Redis connection initialized with access key.

# %%
cm = MemoManager.from_redis(RUN_ID, redis_manager)

# %%
# per-run summary
from src.tools.latency_helpers import PersistentLatency
pl = PersistentLatency(cm)

# %%
# raw data (JSON) for export/dashboards
cm.get_context("latency")
# Out:
# {'runs': {'d6661666bdc1': {'run_id': 'd6661666bdc1',
#    'label': 'turn',
#    'created_at': 514771.2507663,
#    'samples': [{'stage': 'tts:synthesis',
#      'start': 514771.3433764,
#      'end': 514772.5951931,
#      'dur': 1.2518166999798268,
#      'meta': {'run_id': 'd6661666bdc1',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 188}},
#     {'stage': 'greeting_ttfb',
#      'start': 514771.2508285,
#      'end': 514772.6268811,
#      'dur': 1.3760525999823585,
#      'meta': {}},
#     {'stage': 'tts:send_frames',
#      'start': 514772.6268615,
#      'end': 514772.6639884,
#      'dur': 0.037126900046132505,
#      'meta': {'run_id': 'd6661666bdc1', 'mode': 'acs', 'frames': 188}},
#     {'stage': 'tts',
#      'start': 514771.3433726,
#      'end': 514774.4818586,
#      'dur': 3.1384860000107437,
#      'meta': {'run_id': 'd6661666bdc1',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}}]},
#   '627bf5aa19ab': {'run_id': '627bf5aa19ab',
#    'label': 'turn',
#    'created_at': 514780.5611783,
#    'samples': [{'stage': 'tts:synthesis',
#      'start': 514782.4973139,
#      'end': 514783.0769132,
#      'dur': 0.5795993000501767,
#      'meta': {'run_id': '627bf5aa19ab',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 52}},
#     {'stage': 'tts:send_frames',
#      'start': 514783.114172,
#      'end': 514783.1158764,
#      'dur': 0.0017044000560417771,
#      'meta': {'run_id': '627bf5aa19ab', 'mode': 'acs', 'frames': 52}},
#     {'stage': 'tts',
#      'start': 514782.4973104,
#      'end': 514783.1656713,
#      'dur': 0.6683609000174329,
#      'meta': {'run_id': '627bf5aa19ab',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514783.2055897,
#      'end': 514784.0915258,
#      'dur': 0.8859360999776982,
#      'meta': {'run_id': '627bf5aa19ab',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 116}},
#     {'stage': 'tts:send_frames',
#      'start': 514784.1315161,
#      'end': 514784.1471569,
#      'dur': 0.015640800003893673,
#      'meta': {'run_id': '627bf5aa19ab', 'mode': 'acs', 'frames': 116}},
#     {'stage': 'tts',
#      'start': 514783.2055861,
#      'end': 514784.1858195,
#      'dur': 0.9802334000123665,
#      'meta': {'run_id': '627bf5aa19ab',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514784.2288247,
#      'end': 514784.9959203,
#      'dur': 0.767095600022003,
#      'meta': {'run_id': '627bf5aa19ab',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 65}},
#     {'stage': 'tts:send_frames',
#      'start': 514785.0276246,
#      'end': 514785.0324141,
#      'dur': 0.004789500031620264,
#      'meta': {'run_id': '627bf5aa19ab', 'mode': 'acs', 'frames': 65}},
#     {'stage': 'tts',
#      'start': 514784.2288204,
#      'end': 514785.0660372,
#      'dur': 0.8372167999623343,
#      'meta': {'run_id': '627bf5aa19ab',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'auth_agent',
#      'start': 514780.5620817,
#      'end': 514785.1007776,
#      'dur': 4.5386959000024945,
#      'meta': {'agent': 'AutoAuth'}}]},
#   '12240627bf93': {'run_id': '12240627bf93',
#    'label': 'turn',
#    'created_at': 514793.664052,
#    'samples': [{'stage': 'tts:synthesis',
#      'start': 514794.8042193,
#      'end': 514795.6138137,
#      'dur': 0.8095943999942392,
#      'meta': {'run_id': '12240627bf93',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 82}},
#     {'stage': 'tts:send_frames',
#      'start': 514795.6426995,
#      'end': 514795.6465877,
#      'dur': 0.0038881999789737165,
#      'meta': {'run_id': '12240627bf93', 'mode': 'acs', 'frames': 82}},
#     {'stage': 'tts',
#      'start': 514794.8042162,
#      'end': 514795.6851219,
#      'dur': 0.8809056999743916,
#      'meta': {'run_id': '12240627bf93',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514795.7150147,
#      'end': 514796.5809175,
#      'dur': 0.8659027999965474,
#      'meta': {'run_id': '12240627bf93',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 60}},
#     {'stage': 'tts:send_frames',
#      'start': 514796.6095511,
#      'end': 514796.6181907,
#      'dur': 0.008639600011520088,
#      'meta': {'run_id': '12240627bf93', 'mode': 'acs', 'frames': 60}},
#     {'stage': 'tts',
#      'start': 514795.7150108,
#      'end': 514796.6480184,
#      'dur': 0.9330076000187546,
#      'meta': {'run_id': '12240627bf93',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514796.6808005,
#      'end': 514797.3696359,
#      'dur': 0.6888354000402614,
#      'meta': {'run_id': '12240627bf93',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 67}},
#     {'stage': 'tts:send_frames',
#      'start': 514797.3965823,
#      'end': 514797.4073334,
#      'dur': 0.010751099966000766,
#      'meta': {'run_id': '12240627bf93', 'mode': 'acs', 'frames': 67}},
#     {'stage': 'tts',
#      'start': 514796.6807972,
#      'end': 514797.4374184,
#      'dur': 0.7566212000092492,
#      'meta': {'run_id': '12240627bf93',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'auth_agent',
#      'start': 514793.6652909,
#      'end': 514797.4704046,
#      'dur': 3.8051137000438757,
#      'meta': {'agent': 'AutoAuth'}}]},
#   '0038837dc30d': {'run_id': '0038837dc30d',
#    'label': 'turn',
#    'created_at': 514803.7446325,
#    'samples': [{'stage': 'tts:synthesis',
#      'start': 514804.4773112,
#      'end': 514805.1994997,
#      'dur': 0.722188499988988,
#      'meta': {'run_id': '0038837dc30d',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 55}},
#     {'stage': 'tts:send_frames',
#      'start': 514805.2327294,
#      'end': 514805.2472198,
#      'dur': 0.014490400033537298,
#      'meta': {'run_id': '0038837dc30d', 'mode': 'acs', 'frames': 55}},
#     {'stage': 'tts',
#      'start': 514804.4772928,
#      'end': 514805.2810664,
#      'dur': 0.8037736000260338,
#      'meta': {'run_id': '0038837dc30d',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514805.316613,
#      'end': 514806.2165664,
#      'dur': 0.8999534000176936,
#      'meta': {'run_id': '0038837dc30d',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 94}},
#     {'stage': 'tts:send_frames',
#      'start': 514806.2493363,
#      'end': 514806.2762946,
#      'dur': 0.026958299975376576,
#      'meta': {'run_id': '0038837dc30d', 'mode': 'acs', 'frames': 94}},
#     {'stage': 'tts',
#      'start': 514805.3166042,
#      'end': 514806.3108599,
#      'dur': 0.9942557000322267,
#      'meta': {'run_id': '0038837dc30d',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'auth_agent',
#      'start': 514803.7461504,
#      'end': 514806.3591564,
#      'dur': 2.6130059999995865,
#      'meta': {'agent': 'AutoAuth'}}]},
#   '1931769bfaf1': {'run_id': '1931769bfaf1',
#    'label': 'turn',
#    'created_at': 514811.465381,
#    'samples': [{'stage': 'tts:synthesis',
#      'start': 514812.624116,
#      'end': 514813.230577,
#      'dur': 0.6064609999884851,
#      'meta': {'run_id': '1931769bfaf1',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 48}},
#     {'stage': 'tts:send_frames',
#      'start': 514813.2692522,
#      'end': 514813.2800161,
#      'dur': 0.010763899947050959,
#      'meta': {'run_id': '1931769bfaf1', 'mode': 'acs', 'frames': 48}},
#     {'stage': 'tts',
#      'start': 514812.6241071,
#      'end': 514813.3143169,
#      'dur': 0.6902097999700345,
#      'meta': {'run_id': '1931769bfaf1',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514813.3792814,
#      'end': 514815.1719658,
#      'dur': 1.7926843999885023,
#      'meta': {'run_id': '1931769bfaf1',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 232}},
#     {'stage': 'tts:send_frames',
#      'start': 514815.2079882,
#      'end': 514815.270388,
#      'dur': 0.062399799993727356,
#      'meta': {'run_id': '1931769bfaf1', 'mode': 'acs', 'frames': 232}},
#     {'stage': 'tts',
#      'start': 514813.3792726,
#      'end': 514815.324363,
#      'dur': 1.9450903999968432,
#      'meta': {'run_id': '1931769bfaf1',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514815.3737605,
#      'end': 514816.2631769,
#      'dur': 0.8894163999939337,
#      'meta': {'run_id': '1931769bfaf1',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 111}},
#     {'stage': 'tts:send_frames',
#      'start': 514816.2943071,
#      'end': 514816.3258789,
#      'dur': 0.03157180000562221,
#      'meta': {'run_id': '1931769bfaf1', 'mode': 'acs', 'frames': 111}},
#     {'stage': 'tts',
#      'start': 514815.3737515,
#      'end': 514816.3617164,
#      'dur': 0.9879649000358768,
#      'meta': {'run_id': '1931769bfaf1',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'auth_agent',
#      'start': 514811.4685184,
#      'end': 514816.402961,
#      'dur': 4.934442600002512,
#      'meta': {'agent': 'AutoAuth'}}]},
#   '0565d2a22d31': {'run_id': '0565d2a22d31',
#    'label': 'turn',
#    'created_at': 514827.690354,
#    'samples': [{'stage': 'tts:synthesis',
#      'start': 514828.8629627,
#      'end': 514829.8786918,
#      'dur': 1.0157290999777615,
#      'meta': {'run_id': '0565d2a22d31',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 133}},
#     {'stage': 'tts:send_frames',
#      'start': 514829.943167,
#      'end': 514829.9876812,
#      'dur': 0.04451419995166361,
#      'meta': {'run_id': '0565d2a22d31', 'mode': 'acs', 'frames': 133}},
#     {'stage': 'tts',
#      'start': 514828.8629529,
#      'end': 514830.0199708,
#      'dur': 1.1570178999681957,
#      'meta': {'run_id': '0565d2a22d31',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514830.0676891,
#      'end': 514830.9366984,
#      'dur': 0.8690093000186607,
#      'meta': {'run_id': '0565d2a22d31',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 111}},
#     {'stage': 'tts:send_frames',
#      'start': 514830.9676062,
#      'end': 514830.9928665,
#      'dur': 0.025260299968067557,
#      'meta': {'run_id': '0565d2a22d31', 'mode': 'acs', 'frames': 111}},
#     {'stage': 'tts',
#      'start': 514830.0676797,
#      'end': 514831.0228092,
#      'dur': 0.9551295000128448,
#      'meta': {'run_id': '0565d2a22d31',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'auth_agent',
#      'start': 514827.693431,
#      'end': 514831.0612715,
#      'dur': 3.367840500024613,
#      'meta': {'agent': 'AutoAuth'}}]},
#   '03228e259e44': {'run_id': '03228e259e44',
#    'label': 'turn',
#    'created_at': 514831.5051532,
#    'samples': [{'stage': 'tts:synthesis',
#      'start': 514832.2907057,
#      'end': 514833.3935855,
#      'dur': 1.1028798000188544,
#      'meta': {'run_id': '03228e259e44',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 164}},
#     {'stage': 'tts:send_frames',
#      'start': 514833.4255455,
#      'end': 514833.4671106,
#      'dur': 0.04156509996391833,
#      'meta': {'run_id': '03228e259e44', 'mode': 'acs', 'frames': 164}},
#     {'stage': 'tts',
#      'start': 514832.2906977,
#      'end': 514833.5004116,
#      'dur': 1.2097138999961317,
#      'meta': {'run_id': '03228e259e44',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514833.5422703,
#      'end': 514834.2491714,
#      'dur': 0.7069010999985039,
#      'meta': {'run_id': '03228e259e44',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 84}},
#     {'stage': 'tts:send_frames',
#      'start': 514834.2846383,
#      'end': 514834.2993531,
#      'dur': 0.014714799995999783,
#      'meta': {'run_id': '03228e259e44', 'mode': 'acs', 'frames': 84}},
#     {'stage': 'tts',
#      'start': 514833.5422622,
#      'end': 514834.3309917,
#      'dur': 0.7887295000255108,
#      'meta': {'run_id': '03228e259e44',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'auth_agent',
#      'start': 514831.5075169,
#      'end': 514834.3742102,
#      'dur': 2.8666932999622077,
#      'meta': {'agent': 'AutoAuth'}}]},
#   'cf80c12a08d5': {'run_id': 'cf80c12a08d5',
#    'label': 'turn',
#    'created_at': 514861.9414129,
#    'samples': [{'stage': 'tts:synthesis',
#      'start': 514862.9698493,
#      'end': 514863.6644592,
#      'dur': 0.6946099000051618,
#      'meta': {'run_id': 'cf80c12a08d5',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 58}},
#     {'stage': 'tts:send_frames',
#      'start': 514863.6932878,
#      'end': 514863.6983691,
#      'dur': 0.005081299983430654,
#      'meta': {'run_id': 'cf80c12a08d5', 'mode': 'acs', 'frames': 58}},
#     {'stage': 'tts',
#      'start': 514862.9698454,
#      'end': 514863.7313274,
#      'dur': 0.7614820000017062,
#      'meta': {'run_id': 'cf80c12a08d5',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514863.7696394,
#      'end': 514865.1602905,
#      'dur': 1.3906510999659076,
#      'meta': {'run_id': 'cf80c12a08d5',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 235}},
#     {'stage': 'tts:send_frames',
#      'start': 514865.194658,
#      'end': 514865.2119305,
#      'dur': 0.01727249997202307,
#      'meta': {'run_id': 'cf80c12a08d5', 'mode': 'acs', 'frames': 235}},
#     {'stage': 'tts',
#      'start': 514863.7696351,
#      'end': 514865.2474737,
#      'dur': 1.4778385999961756,
#      'meta': {'run_id': 'cf80c12a08d5',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514865.3109587,
#      'end': 514866.1602012,
#      'dur': 0.8492424999712966,
#      'meta': {'run_id': 'cf80c12a08d5',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 116}},
#     {'stage': 'tts:send_frames',
#      'start': 514866.1905003,
#      'end': 514866.1985125,
#      'dur': 0.008012199949007481,
#      'meta': {'run_id': 'cf80c12a08d5', 'mode': 'acs', 'frames': 116}},
#     {'stage': 'tts',
#      'start': 514865.3109544,
#      'end': 514866.2350958,
#      'dur': 0.9241414000280201,
#      'meta': {'run_id': 'cf80c12a08d5',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'auth_agent',
#      'start': 514861.9425227,
#      'end': 514866.2675987,
#      'dur': 4.325076000008266,
#      'meta': {'agent': 'AutoAuth'}}]},
#   '3ed6953552a7': {'run_id': '3ed6953552a7',
#    'label': 'turn',
#    'created_at': 514872.8644427,
#    'samples': [{'stage': 'tts:synthesis',
#      'start': 514873.9066845,
#      'end': 514874.9129143,
#      'dur': 1.0062297999975272,
#      'meta': {'run_id': '3ed6953552a7',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 130}},
#     {'stage': 'tts:send_frames',
#      'start': 514874.9485067,
#      'end': 514874.9574424,
#      'dur': 0.008935699996072799,
#      'meta': {'run_id': '3ed6953552a7', 'mode': 'acs', 'frames': 130}},
#     {'stage': 'tts',
#      'start': 514873.9066754,
#      'end': 514874.9922786,
#      'dur': 1.085603200015612,
#      'meta': {'run_id': '3ed6953552a7',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514875.0284024,
#      'end': 514876.8246943,
#      'dur': 1.7962918999837711,
#      'meta': {'run_id': '3ed6953552a7',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 298}},
#     {'stage': 'tts:send_frames',
#      'start': 514876.8619519,
#      'end': 514876.8780068,
#      'dur': 0.01605490001384169,
#      'meta': {'run_id': '3ed6953552a7', 'mode': 'acs', 'frames': 298}},
#     {'stage': 'tts',
#      'start': 514875.0283981,
#      'end': 514876.9182431,
#      'dur': 1.8898449999978766,
#      'meta': {'run_id': '3ed6953552a7',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514876.9477508,
#      'end': 514877.7907363,
#      'dur': 0.8429854999994859,
#      'meta': {'run_id': '3ed6953552a7',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 118}},
#     {'stage': 'tts:send_frames',
#      'start': 514877.8253503,
#      'end': 514877.8288024,
#      'dur': 0.00345209997612983,
#      'meta': {'run_id': '3ed6953552a7', 'mode': 'acs', 'frames': 118}},
#     {'stage': 'tts',
#      'start': 514876.9477485,
#      'end': 514877.8673799,
#      'dur': 0.919631400029175,
#      'meta': {'run_id': '3ed6953552a7',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'auth_agent',
#      'start': 514872.8654398,
#      'end': 514877.8993802,
#      'dur': 5.033940399996936,
#      'meta': {'agent': 'AutoAuth'}}]},
#   '3fb483d3aa07': {'run_id': '3fb483d3aa07',
#    'label': 'turn',
#    'created_at': 514883.7660581,
#    'samples': [{'stage': 'tts:synthesis',
#      'start': 514885.6391962,
#      'end': 514886.4141516,
#      'dur': 0.774955399974715,
#      'meta': {'run_id': '3fb483d3aa07',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 53}},
#     {'stage': 'tts:send_frames',
#      'start': 514886.4517793,
#      'end': 514886.4561338,
#      'dur': 0.004354499978944659,
#      'meta': {'run_id': '3fb483d3aa07', 'mode': 'acs', 'frames': 53}},
#     {'stage': 'tts',
#      'start': 514885.6391925,
#      'end': 514886.4941109,
#      'dur': 0.8549184000003152,
#      'meta': {'run_id': '3fb483d3aa07',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514886.5279555,
#      'end': 514887.0576245,
#      'dur': 0.5296690000104718,
#      'meta': {'run_id': '3fb483d3aa07',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 50}},
#     {'stage': 'tts:send_frames',
#      'start': 514887.0973957,
#      'end': 514887.1008471,
#      'dur': 0.0034514000290073454,
#      'meta': {'run_id': '3fb483d3aa07', 'mode': 'acs', 'frames': 50}},
#     {'stage': 'tts',
#      'start': 514886.5279534,
#      'end': 514887.1373611,
#      'dur': 0.6094077000161633,
#      'meta': {'run_id': '3fb483d3aa07',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514887.1933352,
#      'end': 514888.0601653,
#      'dur': 0.8668300999561325,
#      'meta': {'run_id': '3fb483d3aa07',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 133}},
#     {'stage': 'tts:send_frames',
#      'start': 514888.0954696,
#      'end': 514888.1102681,
#      'dur': 0.014798499993048608,
#      'meta': {'run_id': '3fb483d3aa07', 'mode': 'acs', 'frames': 133}},
#     {'stage': 'tts',
#      'start': 514887.1933324,
#      'end': 514888.152152,
#      'dur': 0.9588195999967866,
#      'meta': {'run_id': '3fb483d3aa07',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514888.1914412,
#      'end': 514888.7835397,
#      'dur': 0.592098499997519,
#      'meta': {'run_id': '3fb483d3aa07',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+3%',
#       'frames': 53}},
#     {'stage': 'tts:send_frames',
#      'start': 514888.8221316,
#      'end': 514888.8271583,
#      'dur': 0.005026699975132942,
#      'meta': {'run_id': '3fb483d3aa07', 'mode': 'acs', 'frames': 53}},
#     {'stage': 'tts',
#      'start': 514888.1914378,
#      'end': 514888.8631354,
#      'dur': 0.6716975999879651,
#      'meta': {'run_id': '3fb483d3aa07',
#       'mode': 'acs',
#       'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#     {'stage': 'auth_agent',
#      'start': 514883.767056,
#      'end': 514888.9015961,
#      'dur': 5.134540099999867,
#      'meta': {'agent': 'AutoAuth'}},
#     {'stage': 'tts:synthesis',
#      'start': 514888.9401055,
#      'end': 514891.3709761,
#      'dur': 2.4308705999865197,
#      'meta': {'run_id': '3fb483d3aa07',
#       'mode': 'acs',
#       'voice': 'en-US-Andrew2:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+10%',
#       'frames': 356}},
#     {'stage': 'tts:send_frames',
#      'start': 514891.409855,
#      'end': 514891.431155,
#      'dur': 0.021300000022165477,
#      'meta': {'run_id': '3fb483d3aa07', 'mode': 'acs', 'frames': 356}},
#     {'stage': 'tts',
#      'start': 514888.9401013,
#      'end': 514891.4830548,
#      'dur': 2.5429535000002943,
#      'meta': {'run_id': '3fb483d3aa07',
#       'mode': 'acs',
#       'voice': 'en-US-Andrew2:DragonHDLatestNeural'}}]},
#   'c5bb4f3794bb': {'run_id': 'c5bb4f3794bb',
#    'label': 'turn',
#    'created_at': 514908.2253456,
#    'samples': [{'stage': 'tts:synthesis',
#      'start': 514909.0952195,
#      'end': 514909.6359587,
#      'dur': 0.5407391999615356,
#      'meta': {'run_id': 'c5bb4f3794bb',
#       'mode': 'acs',
#       'voice': 'en-US-Andrew2:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+10%',
#       'frames': 51}},
#     {'stage': 'tts:send_frames',
#      'start': 514909.6780455,
#      'end': 514909.6817645,
#      'dur': 0.0037189999711699784,
#      'meta': {'run_id': 'c5bb4f3794bb', 'mode': 'acs', 'frames': 51}},
#     {'stage': 'tts',
#      'start': 514909.0952156,
#      'end': 514909.7213124,
#      'dur': 0.6260968000278808,
#      'meta': {'run_id': 'c5bb4f3794bb',
#       'mode': 'acs',
#       'voice': 'en-US-Andrew2:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514909.7654465,
#      'end': 514911.0374607,
#      'dur': 1.2720142000471242,
#      'meta': {'run_id': 'c5bb4f3794bb',
#       'mode': 'acs',
#       'voice': 'en-US-Andrew2:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+10%',
#       'frames': 179}},
#     {'stage': 'tts:send_frames',
#      'start': 514911.0826946,
#      'end': 514911.0918653,
#      'dur': 0.009170700039248914,
#      'meta': {'run_id': 'c5bb4f3794bb', 'mode': 'acs', 'frames': 179}},
#     {'stage': 'tts',
#      'start': 514909.7654433,
#      'end': 514911.1474576,
#      'dur': 1.3820142999757081,
#      'meta': {'run_id': 'c5bb4f3794bb',
#       'mode': 'acs',
#       'voice': 'en-US-Andrew2:DragonHDLatestNeural'}},
#     {'stage': 'claim_agent',
#      'start': 514908.2262227,
#      'end': 514911.1847374,
#      'dur': 2.958514700003434,
#      'meta': {'agent': 'Claims'}}]},
#   '9d9ff4c74ca5': {'run_id': '9d9ff4c74ca5',
#    'label': 'turn',
#    'created_at': 514920.881821,
#    'samples': [{'stage': 'tts:synthesis',
#      'start': 514923.9831208,
#      'end': 514925.7125889,
#      'dur': 1.7294681000057608,
#      'meta': {'run_id': '9d9ff4c74ca5',
#       'mode': 'acs',
#       'voice': 'en-US-Andrew2:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+10%',
#       'frames': 242}},
#     {'stage': 'tts:send_frames',
#      'start': 514925.774996,
#      'end': 514925.7814808,
#      'dur': 0.0064848000183701515,
#      'meta': {'run_id': '9d9ff4c74ca5', 'mode': 'acs', 'frames': 242}},
#     {'stage': 'tts',
#      'start': 514923.9831173,
#      'end': 514925.8517782,
#      'dur': 1.868660899985116,
#      'meta': {'run_id': '9d9ff4c74ca5',
#       'mode': 'acs',
#       'voice': 'en-US-Andrew2:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514925.8941397,
#      'end': 514926.616559,
#      'dur': 0.7224193000001833,
#      'meta': {'run_id': '9d9ff4c74ca5',
#       'mode': 'acs',
#       'voice': 'en-US-Andrew2:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+10%',
#       'frames': 70}},
#     {'stage': 'tts:send_frames',
#      'start': 514926.6661027,
#      'end': 514926.6712725,
#      'dur': 0.005169800017029047,
#      'meta': {'run_id': '9d9ff4c74ca5', 'mode': 'acs', 'frames': 70}},
#     {'stage': 'tts',
#      'start': 514925.8941364,
#      'end': 514926.7281046,
#      'dur': 0.8339681999641471,
#      'meta': {'run_id': '9d9ff4c74ca5',
#       'mode': 'acs',
#       'voice': 'en-US-Andrew2:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514926.7721129,
#      'end': 514927.2508917,
#      'dur': 0.47877879999578,
#      'meta': {'run_id': '9d9ff4c74ca5',
#       'mode': 'acs',
#       'voice': 'en-US-Andrew2:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+10%',
#       'frames': 40}},
#     {'stage': 'tts:send_frames',
#      'start': 514927.2925991,
#      'end': 514927.2948331,
#      'dur': 0.002234000014141202,
#      'meta': {'run_id': '9d9ff4c74ca5', 'mode': 'acs', 'frames': 40}},
#     {'stage': 'tts',
#      'start': 514926.7721096,
#      'end': 514927.3375498,
#      'dur': 0.565440199978184,
#      'meta': {'run_id': '9d9ff4c74ca5',
#       'mode': 'acs',
#       'voice': 'en-US-Andrew2:DragonHDLatestNeural'}},
#     {'stage': 'claim_agent',
#      'start': 514920.8827067,
#      'end': 514927.3802628,
#      'dur': 6.497556100017391,
#      'meta': {'agent': 'Claims'}},
#     {'stage': 'tts:synthesis',
#      'start': 514927.4244836,
#      'end': 514929.5721995,
#      'dur': 2.1477158999769017,
#      'meta': {'run_id': '9d9ff4c74ca5',
#       'mode': 'acs',
#       'voice': 'en-US-Emma2:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+15%',
#       'frames': 393}},
#     {'stage': 'tts:send_frames',
#      'start': 514929.6223589,
#      'end': 514929.6415894,
#      'dur': 0.019230500038247555,
#      'meta': {'run_id': '9d9ff4c74ca5', 'mode': 'acs', 'frames': 393}},
#     {'stage': 'tts',
#      'start': 514927.4244803,
#      'end': 514929.717248,
#      'dur': 2.2927676999825053,
#      'meta': {'run_id': '9d9ff4c74ca5',
#       'mode': 'acs',
#       'voice': 'en-US-Emma2:DragonHDLatestNeural'}}]},
#   '6010b2d0d74f': {'run_id': '6010b2d0d74f',
#    'label': 'turn',
#    'created_at': 514946.1616524,
#    'samples': [{'stage': 'tts:synthesis',
#      'start': 514947.2730949,
#      'end': 514949.3152314,
#      'dur': 2.042136500007473,
#      'meta': {'run_id': '6010b2d0d74f',
#       'mode': 'acs',
#       'voice': 'en-US-Emma2:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+15%',
#       'frames': 369}},
#     {'stage': 'tts:send_frames',
#      'start': 514949.3606717,
#      'end': 514949.3792914,
#      'dur': 0.018619700043927878,
#      'meta': {'run_id': '6010b2d0d74f', 'mode': 'acs', 'frames': 369}},
#     {'stage': 'tts',
#      'start': 514947.2730913,
#      'end': 514949.4304087,
#      'dur': 2.1573174000368454,
#      'meta': {'run_id': '6010b2d0d74f',
#       'mode': 'acs',
#       'voice': 'en-US-Emma2:DragonHDLatestNeural'}},
#     {'stage': 'general_agent',
#      'start': 514946.1624087,
#      'end': 514949.4741633,
#      'dur': 3.3117546000285074,
#      'meta': {'agent': 'General'}}]},
#   '7d8507b903bf': {'run_id': '7d8507b903bf',
#    'label': 'turn',
#    'created_at': 514957.7263143,
#    'samples': [{'stage': 'tts:synthesis',
#      'start': 514959.9210737,
#      'end': 514961.4971514,
#      'dur': 1.5760777000105008,
#      'meta': {'run_id': '7d8507b903bf',
#       'mode': 'acs',
#       'voice': 'en-US-Emma2:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+15%',
#       'frames': 234}},
#     {'stage': 'tts:send_frames',
#      'start': 514961.5439967,
#      'end': 514961.5507639,
#      'dur': 0.0067671999568119645,
#      'meta': {'run_id': '7d8507b903bf', 'mode': 'acs', 'frames': 234}},
#     {'stage': 'tts',
#      'start': 514959.9210703,
#      'end': 514961.6045892,
#      'dur': 1.6835189000121318,
#      'meta': {'run_id': '7d8507b903bf',
#       'mode': 'acs',
#       'voice': 'en-US-Emma2:DragonHDLatestNeural'}},
#     {'stage': 'tts:synthesis',
#      'start': 514961.6476839,
#      'end': 514962.314069,
#      'dur': 0.6663850999902934,
#      'meta': {'run_id': '7d8507b903bf',
#       'mode': 'acs',
#       'voice': 'en-US-Emma2:DragonHDLatestNeural',
#       'style': 'chat',
#       'rate': '+15%',
#       'frames': 82}},
#     {'stage': 'tts:send_frames',
#      'start': 514962.3620337,
#      'end': 514962.3650371,
#      'dur': 0.0030033999937586486,
#      'meta': {'run_id': '7d8507b903bf', 'mode': 'acs', 'frames': 82}},
#     {'stage': 'tts',
#      'start': 514961.6476813,
#      'end': 514962.411684,
#      'dur': 0.7640026999870315,
#      'meta': {'run_id': '7d8507b903bf',
#       'mode': 'acs',
#       'voice': 'en-US-Emma2:DragonHDLatestNeural'}},
#     {'stage': 'general_agent',
#      'start': 514957.7269247,
#      'end': 514962.469808,
#      'dur': 4.742883300001267,
#      'meta': {'agent': 'General'}}]}},
#  'order': ['d6661666bdc1',
#   '627bf5aa19ab',
#   '12240627bf93',
#   '0038837dc30d',
#   '1931769bfaf1',
#   '0565d2a22d31',
#   '03228e259e44',
#   'cf80c12a08d5',
#   '3ed6953552a7',
#   '3fb483d3aa07',
#   'c5bb4f3794bb',
#   '9d9ff4c74ca5',
#   '6010b2d0d74f',
#   '7d8507b903bf'],
#  'current_run_id': '7d8507b903bf'}

# %%
# summary per run
rid = pl.current_run_id()  # or any run_id from CoreMemory["latency"]["order"]
print(pl.run_summary(rid))
print(cm.get_context("latency"))
# Out:
# {'tts:synthesis': {'count': 2, 'avg': 1.1212314000003971, 'min': 0.6663850999902934, 'max': 1.5760777000105008, 'total': 2.2424628000007942}, 'tts:send_frames': {'count': 2, 'avg': 0.004885299975285307, 'min': 0.0030033999937586486, 'max': 0.0067671999568119645, 'total': 0.009770599950570613}, 'tts': {'count': 2, 'avg': 1.2237607999995816, 'min': 0.7640026999870315, 'max': 1.6835189000121318, 'total': 2.4475215999991633}, 'general_agent': {'count': 1, 'avg': 4.742883300001267, 'min': 4.742883300001267, 'max': 4.742883300001267, 'total': 4.742883300001267}}
# {'runs': {'d6661666bdc1': {'run_id': 'd6661666bdc1', 'label': 'turn', 'created_at': 514771.2507663, 'samples': [{'stage': 'tts:synthesis', 'start': 514771.3433764, 'end': 514772.5951931, 'dur': 1.2518166999798268, 'meta': {'run_id': 'd6661666bdc1', 'mode': 'acs', 'voice': 'en-US-Ava:DragonHDLatestNeural', 'style': 'chat', 'rate': '+3%', 'frames': 188}}, {'stage': 'greeting_ttfb', 'start': 514771.2508285, 'end': 514772.6268811, 'dur': 1.3760525999823585, 'meta': {}}, {'stage': 'tts:send_frames', 'start': 514772.6268615, 'end': 514772.6639884, 'dur': 0.037126900046132505, 'meta': {'run_id': 'd6661666bdc1', 'mode': 'acs', 'frames': 188}}, {'stage': 'tts', 'start': 514771.3433726, 'end': 514774.4818586, 'dur': 3.1384860000107437, 'meta': {'run_id': 'd6661666bdc1', 'mode': 'acs', 'voice': 'en-US-Ava:DragonHDLatestNeural'}}]}, '627bf5aa19ab': {'run_id': '627bf5aa19ab', 'label': 'turn', 'created_at': 514780.5611783, 'samples': [{'stage': 'tts:synthesis', 'start': 514782.4973139, 'end': 514783.0769132, 'dur': 0.5795993000501767, 'meta': {'run_id': '627bf5aa19ab', 'mode': 'acs', 'voice': 'en-US-Ava:DragonHDLatestNeural', 'style': 'chat', 'rate': '+3%', 'frames': 52}}, {'stage': 'tts:send_frames', 'start': 514783.114172, 'end': 514783.1158764, 'dur': 0.0017044000560417771, 'meta': {'run_id': '627bf5aa19ab', 'mode': 'acs', 'frames': 52}}, {'stage': 'tts', 'start': 514782.4973104, 'end': 514783.1656713, 'dur': 0.6683609000174329, 'meta': {'run_id': '627bf5aa19ab', 'mode': 'acs', 'voice': 'en-US-Ava:DragonHDLatestNeural'}}, {'stage': 'tts:synthesis', 'start': 514783.2055897, 'end': 514784.0915258, 'dur': 0.8859360999776982, 'meta': {'run_id': '627bf5aa19ab', 'mode': 'acs', 'voice': 'en-US-Ava:DragonHDLatestNeural', 'style': 'chat', 'rate': '+3%', 'frames': 116}}, {'stage': 'tts:send_frames', 'start': 514784.1315161, 'end': 514784.1471569, 'dur': 0.015640800003893673, 'meta': {'run_id': '627bf5aa19ab', 'mode': 'acs', 'frames': 116}}, {'stage': 'tts', 'start': 514783.2055861, 'end': 514784.1858195, 'dur': 0.9802334000123665, 'meta': {'run_id': '627bf5aa19ab', 'mode': 'acs', 'voice': 'en-US-Ava:DragonHDLatestNeural'}}, {'stage': 'tts:synthesis', 'start': 514784.2288247, 'end': 514784.9959203, 'dur': 0.767095600022003, 'meta': {'run_id': '627bf5aa19ab', 'mode': 'acs', 'voice': 'en-US-Ava:DragonHDLatestNeural', 'style': 'chat', 'rate': '+3%', 'frames': 65}}, {'stage': 'tts:send_frames', 'start': 514785.0276246, 'end': 514785.0324141, 'dur': 0.004789500031620264, 'meta': {'run_id': '627bf5aa19ab', 'mode': 'acs', 'frames': 65}}, {'stage': 'tts', 'start': 514784.2288204, 'end': 514785.0660372, 'dur': 0.8372167999623343, 'meta': {'run_id': '627bf5aa19ab', 'mode': 'acs', 'voice': 'en-US-Ava:DragonHDLatestNeural'}}, {'stage': 'auth_agent', 'start': 514780.5620817, 'end': 514785.1007776, 'dur': 4.5386959000024945, 'meta': {'agent': 'AutoAuth'}}]}, '12240627bf93': {'run_id': '12240627bf93', 'label': 'turn', 'created_at': 514793.664052, 'samples': [{'stage': 'tts:synthesis', 'start': 514794.8042193, 'end': 514795.6138137, 'dur': 0.8095943999942392, 'meta': {'run_id': '12240627bf93', 'mode': 'acs', 'voice': 'en-US-Ava:DragonHDLatestNeural', 'style': 'chat', 'rate': '+3%', 'frames': 82}}, {'stage': 'tts:send_frames', 'start': 514795.6426995, 'end': 514795.6465877, 'dur': 0.0038881999789737165, 'meta': {'run_id': '12240627bf93', 'mode': 'acs', 'frames': 82}}, {'stage': 'tts', 'start': 514794.8042162, 'end': 514795.6851219, 'dur': 0.8809056999743916, 'meta': {'run_id': '12240627bf93', 'mode': 'acs', 'voice': 'en-US-Ava:DragonHDLatestNeural'}}, {'stage': 'tts:synthesis', 'start': 514795.7150147, 'end': 514796.5809175, 'dur': 0.8659027999965474, 'meta': {'run_id': '12240627bf93', 'mode': 'acs', 'voice': 'en-US-Ava:DragonHDLatestNeural', 'style': 'chat', 'rate': '+3%', 'frames': 60}}, {'stage': 'tts:send_frames', 'start': 514796.6095511, 'end': 514796.6181907, 'dur': 0.008639600011520088, 'meta': {'run_id': '12240627bf93', 'mode': 'acs', 'frames': 60}}, {'stag ...

# %%
cm.context
# Out:
# {'call_initiated_via': 'api',
#  'api_version': 'v1',
#  'call_direction': 'outbound',
#  'target_number': '+18165019907',
#  'latency': {'runs': {'d6661666bdc1': {'run_id': 'd6661666bdc1',
#     'label': 'turn',
#     'created_at': 514771.2507663,
#     'samples': [{'stage': 'tts:synthesis',
#       'start': 514771.3433764,
#       'end': 514772.5951931,
#       'dur': 1.2518166999798268,
#       'meta': {'run_id': 'd6661666bdc1',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 188}},
#      {'stage': 'greeting_ttfb',
#       'start': 514771.2508285,
#       'end': 514772.6268811,
#       'dur': 1.3760525999823585,
#       'meta': {}},
#      {'stage': 'tts:send_frames',
#       'start': 514772.6268615,
#       'end': 514772.6639884,
#       'dur': 0.037126900046132505,
#       'meta': {'run_id': 'd6661666bdc1', 'mode': 'acs', 'frames': 188}},
#      {'stage': 'tts',
#       'start': 514771.3433726,
#       'end': 514774.4818586,
#       'dur': 3.1384860000107437,
#       'meta': {'run_id': 'd6661666bdc1',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}}]},
#    '627bf5aa19ab': {'run_id': '627bf5aa19ab',
#     'label': 'turn',
#     'created_at': 514780.5611783,
#     'samples': [{'stage': 'tts:synthesis',
#       'start': 514782.4973139,
#       'end': 514783.0769132,
#       'dur': 0.5795993000501767,
#       'meta': {'run_id': '627bf5aa19ab',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 52}},
#      {'stage': 'tts:send_frames',
#       'start': 514783.114172,
#       'end': 514783.1158764,
#       'dur': 0.0017044000560417771,
#       'meta': {'run_id': '627bf5aa19ab', 'mode': 'acs', 'frames': 52}},
#      {'stage': 'tts',
#       'start': 514782.4973104,
#       'end': 514783.1656713,
#       'dur': 0.6683609000174329,
#       'meta': {'run_id': '627bf5aa19ab',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514783.2055897,
#       'end': 514784.0915258,
#       'dur': 0.8859360999776982,
#       'meta': {'run_id': '627bf5aa19ab',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 116}},
#      {'stage': 'tts:send_frames',
#       'start': 514784.1315161,
#       'end': 514784.1471569,
#       'dur': 0.015640800003893673,
#       'meta': {'run_id': '627bf5aa19ab', 'mode': 'acs', 'frames': 116}},
#      {'stage': 'tts',
#       'start': 514783.2055861,
#       'end': 514784.1858195,
#       'dur': 0.9802334000123665,
#       'meta': {'run_id': '627bf5aa19ab',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514784.2288247,
#       'end': 514784.9959203,
#       'dur': 0.767095600022003,
#       'meta': {'run_id': '627bf5aa19ab',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 65}},
#      {'stage': 'tts:send_frames',
#       'start': 514785.0276246,
#       'end': 514785.0324141,
#       'dur': 0.004789500031620264,
#       'meta': {'run_id': '627bf5aa19ab', 'mode': 'acs', 'frames': 65}},
#      {'stage': 'tts',
#       'start': 514784.2288204,
#       'end': 514785.0660372,
#       'dur': 0.8372167999623343,
#       'meta': {'run_id': '627bf5aa19ab',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'auth_agent',
#       'start': 514780.5620817,
#       'end': 514785.1007776,
#       'dur': 4.5386959000024945,
#       'meta': {'agent': 'AutoAuth'}}]},
#    '12240627bf93': {'run_id': '12240627bf93',
#     'label': 'turn',
#     'created_at': 514793.664052,
#     'samples': [{'stage': 'tts:synthesis',
#       'start': 514794.8042193,
#       'end': 514795.6138137,
#       'dur': 0.8095943999942392,
#       'meta': {'run_id': '12240627bf93',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 82}},
#      {'stage': 'tts:send_frames',
#       'start': 514795.6426995,
#       'end': 514795.6465877,
#       'dur': 0.0038881999789737165,
#       'meta': {'run_id': '12240627bf93', 'mode': 'acs', 'frames': 82}},
#      {'stage': 'tts',
#       'start': 514794.8042162,
#       'end': 514795.6851219,
#       'dur': 0.8809056999743916,
#       'meta': {'run_id': '12240627bf93',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514795.7150147,
#       'end': 514796.5809175,
#       'dur': 0.8659027999965474,
#       'meta': {'run_id': '12240627bf93',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 60}},
#      {'stage': 'tts:send_frames',
#       'start': 514796.6095511,
#       'end': 514796.6181907,
#       'dur': 0.008639600011520088,
#       'meta': {'run_id': '12240627bf93', 'mode': 'acs', 'frames': 60}},
#      {'stage': 'tts',
#       'start': 514795.7150108,
#       'end': 514796.6480184,
#       'dur': 0.9330076000187546,
#       'meta': {'run_id': '12240627bf93',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514796.6808005,
#       'end': 514797.3696359,
#       'dur': 0.6888354000402614,
#       'meta': {'run_id': '12240627bf93',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 67}},
#      {'stage': 'tts:send_frames',
#       'start': 514797.3965823,
#       'end': 514797.4073334,
#       'dur': 0.010751099966000766,
#       'meta': {'run_id': '12240627bf93', 'mode': 'acs', 'frames': 67}},
#      {'stage': 'tts',
#       'start': 514796.6807972,
#       'end': 514797.4374184,
#       'dur': 0.7566212000092492,
#       'meta': {'run_id': '12240627bf93',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'auth_agent',
#       'start': 514793.6652909,
#       'end': 514797.4704046,
#       'dur': 3.8051137000438757,
#       'meta': {'agent': 'AutoAuth'}}]},
#    '0038837dc30d': {'run_id': '0038837dc30d',
#     'label': 'turn',
#     'created_at': 514803.7446325,
#     'samples': [{'stage': 'tts:synthesis',
#       'start': 514804.4773112,
#       'end': 514805.1994997,
#       'dur': 0.722188499988988,
#       'meta': {'run_id': '0038837dc30d',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 55}},
#      {'stage': 'tts:send_frames',
#       'start': 514805.2327294,
#       'end': 514805.2472198,
#       'dur': 0.014490400033537298,
#       'meta': {'run_id': '0038837dc30d', 'mode': 'acs', 'frames': 55}},
#      {'stage': 'tts',
#       'start': 514804.4772928,
#       'end': 514805.2810664,
#       'dur': 0.8037736000260338,
#       'meta': {'run_id': '0038837dc30d',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514805.316613,
#       'end': 514806.2165664,
#       'dur': 0.8999534000176936,
#       'meta': {'run_id': '0038837dc30d',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 94}},
#      {'stage': 'tts:send_frames',
#       'start': 514806.2493363,
#       'end': 514806.2762946,
#       'dur': 0.026958299975376576,
#       'meta': {'run_id': '0038837dc30d', 'mode': 'acs', 'frames': 94}},
#      {'stage': 'tts',
#       'start': 514805.3166042,
#       'end': 514806.3108599,
#       'dur': 0.9942557000322267,
#       'meta': {'run_id': '0038837dc30d',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'auth_agent',
#       'start': 514803.7461504,
#       'end': 514806.3591564,
#       'dur': 2.6130059999995865,
#       'meta': {'agent': 'AutoAuth'}}]},
#    '1931769bfaf1': {'run_id': '1931769bfaf1',
#     'label': 'turn',
#     'created_at': 514811.465381,
#     'samples': [{'stage': 'tts:synthesis',
#       'start': 514812.624116,
#       'end': 514813.230577,
#       'dur': 0.6064609999884851,
#       'meta': {'run_id': '1931769bfaf1',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 48}},
#      {'stage': 'tts:send_frames',
#       'start': 514813.2692522,
#       'end': 514813.2800161,
#       'dur': 0.010763899947050959,
#       'meta': {'run_id': '1931769bfaf1', 'mode': 'acs', 'frames': 48}},
#      {'stage': 'tts',
#       'start': 514812.6241071,
#       'end': 514813.3143169,
#       'dur': 0.6902097999700345,
#       'meta': {'run_id': '1931769bfaf1',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514813.3792814,
#       'end': 514815.1719658,
#       'dur': 1.7926843999885023,
#       'meta': {'run_id': '1931769bfaf1',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 232}},
#      {'stage': 'tts:send_frames',
#       'start': 514815.2079882,
#       'end': 514815.270388,
#       'dur': 0.062399799993727356,
#       'meta': {'run_id': '1931769bfaf1', 'mode': 'acs', 'frames': 232}},
#      {'stage': 'tts',
#       'start': 514813.3792726,
#       'end': 514815.324363,
#       'dur': 1.9450903999968432,
#       'meta': {'run_id': '1931769bfaf1',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514815.3737605,
#       'end': 514816.2631769,
#       'dur': 0.8894163999939337,
#       'meta': {'run_id': '1931769bfaf1',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 111}},
#      {'stage': 'tts:send_frames',
#       'start': 514816.2943071,
#       'end': 514816.3258789,
#       'dur': 0.03157180000562221,
#       'meta': {'run_id': '1931769bfaf1', 'mode': 'acs', 'frames': 111}},
#      {'stage': 'tts',
#       'start': 514815.3737515,
#       'end': 514816.3617164,
#       'dur': 0.9879649000358768,
#       'meta': {'run_id': '1931769bfaf1',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'auth_agent',
#       'start': 514811.4685184,
#       'end': 514816.402961,
#       'dur': 4.934442600002512,
#       'meta': {'agent': 'AutoAuth'}}]},
#    '0565d2a22d31': {'run_id': '0565d2a22d31',
#     'label': 'turn',
#     'created_at': 514827.690354,
#     'samples': [{'stage': 'tts:synthesis',
#       'start': 514828.8629627,
#       'end': 514829.8786918,
#       'dur': 1.0157290999777615,
#       'meta': {'run_id': '0565d2a22d31',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 133}},
#      {'stage': 'tts:send_frames',
#       'start': 514829.943167,
#       'end': 514829.9876812,
#       'dur': 0.04451419995166361,
#       'meta': {'run_id': '0565d2a22d31', 'mode': 'acs', 'frames': 133}},
#      {'stage': 'tts',
#       'start': 514828.8629529,
#       'end': 514830.0199708,
#       'dur': 1.1570178999681957,
#       'meta': {'run_id': '0565d2a22d31',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514830.0676891,
#       'end': 514830.9366984,
#       'dur': 0.8690093000186607,
#       'meta': {'run_id': '0565d2a22d31',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 111}},
#      {'stage': 'tts:send_frames',
#       'start': 514830.9676062,
#       'end': 514830.9928665,
#       'dur': 0.025260299968067557,
#       'meta': {'run_id': '0565d2a22d31', 'mode': 'acs', 'frames': 111}},
#      {'stage': 'tts',
#       'start': 514830.0676797,
#       'end': 514831.0228092,
#       'dur': 0.9551295000128448,
#       'meta': {'run_id': '0565d2a22d31',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'auth_agent',
#       'start': 514827.693431,
#       'end': 514831.0612715,
#       'dur': 3.367840500024613,
#       'meta': {'agent': 'AutoAuth'}}]},
#    '03228e259e44': {'run_id': '03228e259e44',
#     'label': 'turn',
#     'created_at': 514831.5051532,
#     'samples': [{'stage': 'tts:synthesis',
#       'start': 514832.2907057,
#       'end': 514833.3935855,
#       'dur': 1.1028798000188544,
#       'meta': {'run_id': '03228e259e44',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 164}},
#      {'stage': 'tts:send_frames',
#       'start': 514833.4255455,
#       'end': 514833.4671106,
#       'dur': 0.04156509996391833,
#       'meta': {'run_id': '03228e259e44', 'mode': 'acs', 'frames': 164}},
#      {'stage': 'tts',
#       'start': 514832.2906977,
#       'end': 514833.5004116,
#       'dur': 1.2097138999961317,
#       'meta': {'run_id': '03228e259e44',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514833.5422703,
#       'end': 514834.2491714,
#       'dur': 0.7069010999985039,
#       'meta': {'run_id': '03228e259e44',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 84}},
#      {'stage': 'tts:send_frames',
#       'start': 514834.2846383,
#       'end': 514834.2993531,
#       'dur': 0.014714799995999783,
#       'meta': {'run_id': '03228e259e44', 'mode': 'acs', 'frames': 84}},
#      {'stage': 'tts',
#       'start': 514833.5422622,
#       'end': 514834.3309917,
#       'dur': 0.7887295000255108,
#       'meta': {'run_id': '03228e259e44',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'auth_agent',
#       'start': 514831.5075169,
#       'end': 514834.3742102,
#       'dur': 2.8666932999622077,
#       'meta': {'agent': 'AutoAuth'}}]},
#    'cf80c12a08d5': {'run_id': 'cf80c12a08d5',
#     'label': 'turn',
#     'created_at': 514861.9414129,
#     'samples': [{'stage': 'tts:synthesis',
#       'start': 514862.9698493,
#       'end': 514863.6644592,
#       'dur': 0.6946099000051618,
#       'meta': {'run_id': 'cf80c12a08d5',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 58}},
#      {'stage': 'tts:send_frames',
#       'start': 514863.6932878,
#       'end': 514863.6983691,
#       'dur': 0.005081299983430654,
#       'meta': {'run_id': 'cf80c12a08d5', 'mode': 'acs', 'frames': 58}},
#      {'stage': 'tts',
#       'start': 514862.9698454,
#       'end': 514863.7313274,
#       'dur': 0.7614820000017062,
#       'meta': {'run_id': 'cf80c12a08d5',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514863.7696394,
#       'end': 514865.1602905,
#       'dur': 1.3906510999659076,
#       'meta': {'run_id': 'cf80c12a08d5',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 235}},
#      {'stage': 'tts:send_frames',
#       'start': 514865.194658,
#       'end': 514865.2119305,
#       'dur': 0.01727249997202307,
#       'meta': {'run_id': 'cf80c12a08d5', 'mode': 'acs', 'frames': 235}},
#      {'stage': 'tts',
#       'start': 514863.7696351,
#       'end': 514865.2474737,
#       'dur': 1.4778385999961756,
#       'meta': {'run_id': 'cf80c12a08d5',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514865.3109587,
#       'end': 514866.1602012,
#       'dur': 0.8492424999712966,
#       'meta': {'run_id': 'cf80c12a08d5',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 116}},
#      {'stage': 'tts:send_frames',
#       'start': 514866.1905003,
#       'end': 514866.1985125,
#       'dur': 0.008012199949007481,
#       'meta': {'run_id': 'cf80c12a08d5', 'mode': 'acs', 'frames': 116}},
#      {'stage': 'tts',
#       'start': 514865.3109544,
#       'end': 514866.2350958,
#       'dur': 0.9241414000280201,
#       'meta': {'run_id': 'cf80c12a08d5',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'auth_agent',
#       'start': 514861.9425227,
#       'end': 514866.2675987,
#       'dur': 4.325076000008266,
#       'meta': {'agent': 'AutoAuth'}}]},
#    '3ed6953552a7': {'run_id': '3ed6953552a7',
#     'label': 'turn',
#     'created_at': 514872.8644427,
#     'samples': [{'stage': 'tts:synthesis',
#       'start': 514873.9066845,
#       'end': 514874.9129143,
#       'dur': 1.0062297999975272,
#       'meta': {'run_id': '3ed6953552a7',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 130}},
#      {'stage': 'tts:send_frames',
#       'start': 514874.9485067,
#       'end': 514874.9574424,
#       'dur': 0.008935699996072799,
#       'meta': {'run_id': '3ed6953552a7', 'mode': 'acs', 'frames': 130}},
#      {'stage': 'tts',
#       'start': 514873.9066754,
#       'end': 514874.9922786,
#       'dur': 1.085603200015612,
#       'meta': {'run_id': '3ed6953552a7',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514875.0284024,
#       'end': 514876.8246943,
#       'dur': 1.7962918999837711,
#       'meta': {'run_id': '3ed6953552a7',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 298}},
#      {'stage': 'tts:send_frames',
#       'start': 514876.8619519,
#       'end': 514876.8780068,
#       'dur': 0.01605490001384169,
#       'meta': {'run_id': '3ed6953552a7', 'mode': 'acs', 'frames': 298}},
#      {'stage': 'tts',
#       'start': 514875.0283981,
#       'end': 514876.9182431,
#       'dur': 1.8898449999978766,
#       'meta': {'run_id': '3ed6953552a7',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514876.9477508,
#       'end': 514877.7907363,
#       'dur': 0.8429854999994859,
#       'meta': {'run_id': '3ed6953552a7',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 118}},
#      {'stage': 'tts:send_frames',
#       'start': 514877.8253503,
#       'end': 514877.8288024,
#       'dur': 0.00345209997612983,
#       'meta': {'run_id': '3ed6953552a7', 'mode': 'acs', 'frames': 118}},
#      {'stage': 'tts',
#       'start': 514876.9477485,
#       'end': 514877.8673799,
#       'dur': 0.919631400029175,
#       'meta': {'run_id': '3ed6953552a7',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'auth_agent',
#       'start': 514872.8654398,
#       'end': 514877.8993802,
#       'dur': 5.033940399996936,
#       'meta': {'agent': 'AutoAuth'}}]},
#    '3fb483d3aa07': {'run_id': '3fb483d3aa07',
#     'label': 'turn',
#     'created_at': 514883.7660581,
#     'samples': [{'stage': 'tts:synthesis',
#       'start': 514885.6391962,
#       'end': 514886.4141516,
#       'dur': 0.774955399974715,
#       'meta': {'run_id': '3fb483d3aa07',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 53}},
#      {'stage': 'tts:send_frames',
#       'start': 514886.4517793,
#       'end': 514886.4561338,
#       'dur': 0.004354499978944659,
#       'meta': {'run_id': '3fb483d3aa07', 'mode': 'acs', 'frames': 53}},
#      {'stage': 'tts',
#       'start': 514885.6391925,
#       'end': 514886.4941109,
#       'dur': 0.8549184000003152,
#       'meta': {'run_id': '3fb483d3aa07',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514886.5279555,
#       'end': 514887.0576245,
#       'dur': 0.5296690000104718,
#       'meta': {'run_id': '3fb483d3aa07',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 50}},
#      {'stage': 'tts:send_frames',
#       'start': 514887.0973957,
#       'end': 514887.1008471,
#       'dur': 0.0034514000290073454,
#       'meta': {'run_id': '3fb483d3aa07', 'mode': 'acs', 'frames': 50}},
#      {'stage': 'tts',
#       'start': 514886.5279534,
#       'end': 514887.1373611,
#       'dur': 0.6094077000161633,
#       'meta': {'run_id': '3fb483d3aa07',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514887.1933352,
#       'end': 514888.0601653,
#       'dur': 0.8668300999561325,
#       'meta': {'run_id': '3fb483d3aa07',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 133}},
#      {'stage': 'tts:send_frames',
#       'start': 514888.0954696,
#       'end': 514888.1102681,
#       'dur': 0.014798499993048608,
#       'meta': {'run_id': '3fb483d3aa07', 'mode': 'acs', 'frames': 133}},
#      {'stage': 'tts',
#       'start': 514887.1933324,
#       'end': 514888.152152,
#       'dur': 0.9588195999967866,
#       'meta': {'run_id': '3fb483d3aa07',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514888.1914412,
#       'end': 514888.7835397,
#       'dur': 0.592098499997519,
#       'meta': {'run_id': '3fb483d3aa07',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+3%',
#        'frames': 53}},
#      {'stage': 'tts:send_frames',
#       'start': 514888.8221316,
#       'end': 514888.8271583,
#       'dur': 0.005026699975132942,
#       'meta': {'run_id': '3fb483d3aa07', 'mode': 'acs', 'frames': 53}},
#      {'stage': 'tts',
#       'start': 514888.1914378,
#       'end': 514888.8631354,
#       'dur': 0.6716975999879651,
#       'meta': {'run_id': '3fb483d3aa07',
#        'mode': 'acs',
#        'voice': 'en-US-Ava:DragonHDLatestNeural'}},
#      {'stage': 'auth_agent',
#       'start': 514883.767056,
#       'end': 514888.9015961,
#       'dur': 5.134540099999867,
#       'meta': {'agent': 'AutoAuth'}},
#      {'stage': 'tts:synthesis',
#       'start': 514888.9401055,
#       'end': 514891.3709761,
#       'dur': 2.4308705999865197,
#       'meta': {'run_id': '3fb483d3aa07',
#        'mode': 'acs',
#        'voice': 'en-US-Andrew2:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+10%',
#        'frames': 356}},
#      {'stage': 'tts:send_frames',
#       'start': 514891.409855,
#       'end': 514891.431155,
#       'dur': 0.021300000022165477,
#       'meta': {'run_id': '3fb483d3aa07', 'mode': 'acs', 'frames': 356}},
#      {'stage': 'tts',
#       'start': 514888.9401013,
#       'end': 514891.4830548,
#       'dur': 2.5429535000002943,
#       'meta': {'run_id': '3fb483d3aa07',
#        'mode': 'acs',
#        'voice': 'en-US-Andrew2:DragonHDLatestNeural'}}]},
#    'c5bb4f3794bb': {'run_id': 'c5bb4f3794bb',
#     'label': 'turn',
#     'created_at': 514908.2253456,
#     'samples': [{'stage': 'tts:synthesis',
#       'start': 514909.0952195,
#       'end': 514909.6359587,
#       'dur': 0.5407391999615356,
#       'meta': {'run_id': 'c5bb4f3794bb',
#        'mode': 'acs',
#        'voice': 'en-US-Andrew2:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+10%',
#        'frames': 51}},
#      {'stage': 'tts:send_frames',
#       'start': 514909.6780455,
#       'end': 514909.6817645,
#       'dur': 0.0037189999711699784,
#       'meta': {'run_id': 'c5bb4f3794bb', 'mode': 'acs', 'frames': 51}},
#      {'stage': 'tts',
#       'start': 514909.0952156,
#       'end': 514909.7213124,
#       'dur': 0.6260968000278808,
#       'meta': {'run_id': 'c5bb4f3794bb',
#        'mode': 'acs',
#        'voice': 'en-US-Andrew2:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514909.7654465,
#       'end': 514911.0374607,
#       'dur': 1.2720142000471242,
#       'meta': {'run_id': 'c5bb4f3794bb',
#        'mode': 'acs',
#        'voice': 'en-US-Andrew2:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+10%',
#        'frames': 179}},
#      {'stage': 'tts:send_frames',
#       'start': 514911.0826946,
#       'end': 514911.0918653,
#       'dur': 0.009170700039248914,
#       'meta': {'run_id': 'c5bb4f3794bb', 'mode': 'acs', 'frames': 179}},
#      {'stage': 'tts',
#       'start': 514909.7654433,
#       'end': 514911.1474576,
#       'dur': 1.3820142999757081,
#       'meta': {'run_id': 'c5bb4f3794bb',
#        'mode': 'acs',
#        'voice': 'en-US-Andrew2:DragonHDLatestNeural'}},
#      {'stage': 'claim_agent',
#       'start': 514908.2262227,
#       'end': 514911.1847374,
#       'dur': 2.958514700003434,
#       'meta': {'agent': 'Claims'}}]},
#    '9d9ff4c74ca5': {'run_id': '9d9ff4c74ca5',
#     'label': 'turn',
#     'created_at': 514920.881821,
#     'samples': [{'stage': 'tts:synthesis',
#       'start': 514923.9831208,
#       'end': 514925.7125889,
#       'dur': 1.7294681000057608,
#       'meta': {'run_id': '9d9ff4c74ca5',
#        'mode': 'acs',
#        'voice': 'en-US-Andrew2:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+10%',
#        'frames': 242}},
#      {'stage': 'tts:send_frames',
#       'start': 514925.774996,
#       'end': 514925.7814808,
#       'dur': 0.0064848000183701515,
#       'meta': {'run_id': '9d9ff4c74ca5', 'mode': 'acs', 'frames': 242}},
#      {'stage': 'tts',
#       'start': 514923.9831173,
#       'end': 514925.8517782,
#       'dur': 1.868660899985116,
#       'meta': {'run_id': '9d9ff4c74ca5',
#        'mode': 'acs',
#        'voice': 'en-US-Andrew2:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514925.8941397,
#       'end': 514926.616559,
#       'dur': 0.7224193000001833,
#       'meta': {'run_id': '9d9ff4c74ca5',
#        'mode': 'acs',
#        'voice': 'en-US-Andrew2:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+10%',
#        'frames': 70}},
#      {'stage': 'tts:send_frames',
#       'start': 514926.6661027,
#       'end': 514926.6712725,
#       'dur': 0.005169800017029047,
#       'meta': {'run_id': '9d9ff4c74ca5', 'mode': 'acs', 'frames': 70}},
#      {'stage': 'tts',
#       'start': 514925.8941364,
#       'end': 514926.7281046,
#       'dur': 0.8339681999641471,
#       'meta': {'run_id': '9d9ff4c74ca5',
#        'mode': 'acs',
#        'voice': 'en-US-Andrew2:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514926.7721129,
#       'end': 514927.2508917,
#       'dur': 0.47877879999578,
#       'meta': {'run_id': '9d9ff4c74ca5',
#        'mode': 'acs',
#        'voice': 'en-US-Andrew2:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+10%',
#        'frames': 40}},
#      {'stage': 'tts:send_frames',
#       'start': 514927.2925991,
#       'end': 514927.2948331,
#       'dur': 0.002234000014141202,
#       'meta': {'run_id': '9d9ff4c74ca5', 'mode': 'acs', 'frames': 40}},
#      {'stage': 'tts',
#       'start': 514926.7721096,
#       'end': 514927.3375498,
#       'dur': 0.565440199978184,
#       'meta': {'run_id': '9d9ff4c74ca5',
#        'mode': 'acs',
#        'voice': 'en-US-Andrew2:DragonHDLatestNeural'}},
#      {'stage': 'claim_agent',
#       'start': 514920.8827067,
#       'end': 514927.3802628,
#       'dur': 6.497556100017391,
#       'meta': {'agent': 'Claims'}},
#      {'stage': 'tts:synthesis',
#       'start': 514927.4244836,
#       'end': 514929.5721995,
#       'dur': 2.1477158999769017,
#       'meta': {'run_id': '9d9ff4c74ca5',
#        'mode': 'acs',
#        'voice': 'en-US-Emma2:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+15%',
#        'frames': 393}},
#      {'stage': 'tts:send_frames',
#       'start': 514929.6223589,
#       'end': 514929.6415894,
#       'dur': 0.019230500038247555,
#       'meta': {'run_id': '9d9ff4c74ca5', 'mode': 'acs', 'frames': 393}},
#      {'stage': 'tts',
#       'start': 514927.4244803,
#       'end': 514929.717248,
#       'dur': 2.2927676999825053,
#       'meta': {'run_id': '9d9ff4c74ca5',
#        'mode': 'acs',
#        'voice': 'en-US-Emma2:DragonHDLatestNeural'}}]},
#    '6010b2d0d74f': {'run_id': '6010b2d0d74f',
#     'label': 'turn',
#     'created_at': 514946.1616524,
#     'samples': [{'stage': 'tts:synthesis',
#       'start': 514947.2730949,
#       'end': 514949.3152314,
#       'dur': 2.042136500007473,
#       'meta': {'run_id': '6010b2d0d74f',
#        'mode': 'acs',
#        'voice': 'en-US-Emma2:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+15%',
#        'frames': 369}},
#      {'stage': 'tts:send_frames',
#       'start': 514949.3606717,
#       'end': 514949.3792914,
#       'dur': 0.018619700043927878,
#       'meta': {'run_id': '6010b2d0d74f', 'mode': 'acs', 'frames': 369}},
#      {'stage': 'tts',
#       'start': 514947.2730913,
#       'end': 514949.4304087,
#       'dur': 2.1573174000368454,
#       'meta': {'run_id': '6010b2d0d74f',
#        'mode': 'acs',
#        'voice': 'en-US-Emma2:DragonHDLatestNeural'}},
#      {'stage': 'general_agent',
#       'start': 514946.1624087,
#       'end': 514949.4741633,
#       'dur': 3.3117546000285074,
#       'meta': {'agent': 'General'}}]},
#    '7d8507b903bf': {'run_id': '7d8507b903bf',
#     'label': 'turn',
#     'created_at': 514957.7263143,
#     'samples': [{'stage': 'tts:synthesis',
#       'start': 514959.9210737,
#       'end': 514961.4971514,
#       'dur': 1.5760777000105008,
#       'meta': {'run_id': '7d8507b903bf',
#        'mode': 'acs',
#        'voice': 'en-US-Emma2:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+15%',
#        'frames': 234}},
#      {'stage': 'tts:send_frames',
#       'start': 514961.5439967,
#       'end': 514961.5507639,
#       'dur': 0.0067671999568119645,
#       'meta': {'run_id': '7d8507b903bf', 'mode': 'acs', 'frames': 234}},
#      {'stage': 'tts',
#       'start': 514959.9210703,
#       'end': 514961.6045892,
#       'dur': 1.6835189000121318,
#       'meta': {'run_id': '7d8507b903bf',
#        'mode': 'acs',
#        'voice': 'en-US-Emma2:DragonHDLatestNeural'}},
#      {'stage': 'tts:synthesis',
#       'start': 514961.6476839,
#       'end': 514962.314069,
#       'dur': 0.6663850999902934,
#       'meta': {'run_id': '7d8507b903bf',
#        'mode': 'acs',
#        'voice': 'en-US-Emma2:DragonHDLatestNeural',
#        'style': 'chat',
#        'rate': '+15%',
#        'frames': 82}},
#      {'stage': 'tts:send_frames',
#       'start': 514962.3620337,
#       'end': 514962.3650371,
#       'dur': 0.0030033999937586486,
#       'meta': {'run_id': '7d8507b903bf', 'mode': 'acs', 'frames': 82}},
#      {'stage': 'tts',
#       'start': 514961.6476813,
#       'end': 514962.411684,
#       'dur': 0.7640026999870315,
#       'meta': {'run_id': '7d8507b903bf',
#        'mode': 'acs',
#        'voice': 'en-US-Emma2:DragonHDLatestNeural'}},
#      {'stage': 'general_agent',
#       'start': 514957.7269247,
#       'end': 514962.469808,
#       'dur': 4.742883300001267,
#       'meta': {'agent': 'General'}}]}},
#   'order': ['d6661666bdc1',
#    '627bf5aa19ab',
#    '12240627bf93',
#    '0038837dc30d',
#    '1931769bfaf1',
#    '0565d2a22d31',
#    '03228e259e44',
#    'cf80c12a08d5',
#    '3ed6953552a7',
#    '3fb483d3aa07',
#    'c5bb4f3794bb',
#    '9d9ff4c74ca5',
#    '6010b2d0d74f',
#    '7d8507b903bf'],
#   'current_run_id': '7d8507b903bf'},
#  'current_run_id': '7d8507b903bf',
#  'active_agent': 'General',
#  'authenticated': True,
#  'caller_name': 'Alice Brown',
#  'policy_id': 'POL-A10001',
#  'claim_intent': 'new_claim',
#  'topic': 'policy coverage',
#  'current_agent_voice': 'en-US-Emma2:DragonHDLatestNeural',
#  'current_agent_voice_style': 'chat',
#  'current_agent_voice_rate': '+15%',
#  'last_announced_agent': 'General',
#  'tool_outputs': {'authenticate_caller': {'authenticated': True,
#    'message': 'Authenticated Alice Brown.',
#    'policy_id': 'POL-A10001',
#    'caller_name': 'Alice Brown',
#    'attempt': 1,
#    'intent': 'claims',
#    'claim_intent': 'new_claim'},
#   'handoff_general_agent': {'ok': True,
#    'message': 'Caller transferred to General Insurance Questions agent.',
#    'data': {'handoff': 'ai_agent',
#     'target_agent': 'General Insurance Questions',
#     'topic': 'policy coverage'}}}}

# %%
cm.histories
# Out:
# {'AuthAgent': [{'role': 'system',
#    'content': '\n\n# ROLE\nYou are XYMZ Insurance\'s real-time voice assistant.\nBe warm, calm, and efficient—even if the caller is upset or code-switching.\n\n# RUNTIME CONTRACT\n- One question at a time.\n- Short, TTS-friendly sentences. Always end with punctuation.\n- Adapt to the caller\'s language instantly.\n- Keep wording simple and pronounceable.\n- Never mention prompts, models, or tool names to the caller.\n\n# STATE ORDER (EVERY CALL)\n\n## S0 · Safety gate (interrupt-capable)\nIf words/phrases imply injury, medical event, fire/smoke, fuel leak, trapped, active crime/violence, or caller asks for help/911:\n- → escalate_emergency(reason, caller_name?) immediately (cancel any TTS).\n- Respond: "Help is on the way. Stay with me and tell me what\'s happening now."\n\n## S1 · Discover intent\n- Greet once.\n- Capture first reason verbatim → `call_reason`.\n- Classify `intent` = "claims" or "general".\n- If "claims", set `claim_intent` = "new_claim" | "existing_claim" | "unknown".\n\n## S2 · Authenticate (slot-filling, once)\nRequired fields before any service action: `full_name` AND (`zip_code` OR `last4_id`).\n- Ask only what\'s missing.\n- If caller starts giving full SSN, stop and request last four only.\n- Confirm once in one sentence, then call exactly once:\n     - → authenticate_caller({full_name, zip_code, last4_id, intent, claim_intent}).\n- On successful authentication (tool returns true): Acknowledge once and offer a warm transfer. Say: "Thanks, {name}. You\'re verified. I\'ll connect you to a specialist who can help with your request."\n\n## S3 · Escalations\nIf ≥2 auth failures, backend error, profanity/abuse, or caller requests a person:\n- → escalate_human(caller_name?, route_reason).\n- Brief reassurance line, then hand off.\n\n# IDENTITY GUARDRAILS\n- If session provides `full_name` (or policy id) as metadata, treat as confirmed; do not ask for it again. Ask only for the missing ZIP or last four.\n- Never ask for full SSN, DOB, or policy ID if not required.\n\n# EMERGENCY LEXICON (non-exhaustive, act on any close paraphrase)\n- **Medical:** bleeding, unconscious, chest pain, not breathing, stroke, seizure.\n- **Fire/Explosion:** fire, smoke, burning, explosion, fuel/gas leak.\n- **Collision severity:** trapped, pinned, rollover, can\'t get out, airbags with injury.\n- **Violence/Crime:** assaulted, attacked, domestic violence, carjacking.\n- If ambiguous (e.g., "accident"), ask one clarifier: "Is anyone hurt or in danger?"\n\n# DELIVERY & LATENCY\n- Keep turns sub-3s.\n- If a tool call will take longer, say a short progress line.\n- Do not repeat confirmed data.\n- Acknowledge and move forward.\n\n# TOOL SIGNATURES\n- Do not repeat confirmed data.\n- Acknowledge and move forward.\n\n# TOOL SIGNATURES\n\n- authenticate_caller(full_name, zip_code, last4_id, intent, claim_intent)\n- escalate_emergency(reason, caller_name?)\n- escalate_human(caller_name?, route_reason)\n\n# Noise & Barge-In Control (STT/VAD-aware)\n\n- **Barge-in:** If the caller starts speaking (partial STT text appears or VAD says “speech”), stop TTS immediately and listen. Do not resume TTS until end-of-speech + ~300 ms.\n- **Background noise tolerance:** Expect crowd noise, sirens, wind, TV, kids, traffic, music. Ignore these as content unless words clearly map to an intent or emergency.\n- **Uncertain STT:** If low confidence or masked by noise, ask one short clarifier. Prefer teach-back:\n     - “I caught ‘…’. Is that right?” or “Just the last four digits, please.”\n- **Digits under noise:** Read numbers digit-by-digit with short pauses: “6-0-6-1-1.” Confirm once, then move on.\n- **Name spelling under noise:** Offer a brief spell-back if needed: “I heard Chris Lee—C-H-R-I-S L-E-E. Correct?”\n- **Emergency vs noise:** If you hear words like “help,” “bleeding,” or “can’t breathe” inside noise, clarify once: “Is anyone hurt or in danger?” If yes → escalate_emergency(...) immediately.\n\n# Delivery & Latency (amended)\n\n- Keep turns sub- ...
#   {'role': 'user', 'content': 'Hi there, My name is Pablo. How are you?'},
#   {'role': 'assistant',
#    'content': "Hello Pablo! I'm just a program, but I'm here to help you. How can I assist you today?"},
#   {'role': 'user',
#    'content': "I'm doing good. Thank you so much. Are you all good?"},
#   {'role': 'assistant',
#    'content': "I'm glad to hear you're doing well! I'm here to assist you. What can I help you with today?"},
#   {'role': 'user', 'content': "Yes, I'm trying to fill a claim."},
#   {'role': 'assistant',
#    'content': "I'm sorry to hear that. Is anyone hurt or in danger?"},
#   {'role': 'user', 'content': 'No, we are all good.'},
#   {'role': 'assistant',
#    'content': "That's good to hear. Please share your full name and either your ZIP code or the last four digits of your SSN. For your security, just the last four."},
#   {'role': 'user', 'content': 'Yes, SOS My chico y Six Zero.'},
#   {'role': 'assistant',
#    'content': 'I heard "Six Zero" as your last four digits. Just to confirm, can you please repeat your full name?'},
#   {'role': 'user', 'content': 'You should have one of my SSN is 1234.'},
#   {'role': 'assistant',
#    'content': 'For your security, I only need the last four digits. Could you please provide just those?'},
#   {'role': 'user',
#    'content': 'Yes, sorry, my name is Alice Ram. My zip code is 60601. My SSN is 1234.'},
#   {'role': 'assistant',
#    'content': 'Thanks, Alice Ram. I have your ZIP code as 60601 and the last four digits as 1234. One moment while I verify your information.'},
#   {'role': 'user',
#    'content': 'No, my name is Alice Brown. Brown like the color.'},
#   {'role': 'assistant',
#    'content': 'Thank you for the correction, Alice Brown. I have your ZIP code as 60601 and the last four digits as 1234. One moment while I verify your information.'},
#   {'role': 'user', 'content': 'Yes.'},
#   {'role': 'assistant',
#    'content': None,
#    'tool_calls': [{'id': 'call_lXDSmxtpgz4Bsv5qCe8kX6p5',
#      'type': 'function',
#      'function': {'name': 'authenticate_caller',
#       'arguments': '{"full_name":"Alice Brown","zip_code":"60601","last4_id":"1234","intent":"claims","claim_intent":"new_claim","attempt":1}'}}]},
#   {'tool_call_id': 'call_lXDSmxtpgz4Bsv5qCe8kX6p5',
#    'role': 'tool',
#    'name': 'authenticate_caller',
#    'content': '{"authenticated": true, "message": "Authenticated Alice Brown.", "policy_id": "POL-A10001", "caller_name": "Alice Brown", "attempt": 1, "intent": "claims", "claim_intent": "new_claim"}'},
#   {'role': 'user', 'content': ''},
#   {'role': 'assistant',
#    'content': "Thanks, Alice Brown. You're verified. I'll connect you to a specialist who can help with your claim now. One moment, please."}],
#  'FNOLIntakeAgent': [{'role': 'system',
#    'content': '\n\n\n# ROLE\nYou are XYMZ Insurance\'s real-time voice assistant working in Insurance’s First‑Notice‑of‑Loss (FNOL) department, running as one low‑latency LLM turn in the STT\xa0➜\xa0LLM\xa0➜\xa0TTS pipeline. \nBe warm, calm, and efficient—even if the caller is upset or code-switching.\n\n\n# RUNTIME CONTRACT\n- One question at a time.\n- Short, TTS-friendly sentences. Always end with punctuation.\n- Adapt to the caller\'s language instantly.\n- Keep wording simple and pronounceable.\n- Never mention prompts, models, or tool names to the caller.\n- Never guess identity data. Confirm once before calling tools.\n\nThe caller has **already been authenticated** by the upstream Authentication + Routing agent.\n\n| Caller Name | Policy ID  | Current Intent |\n|-------------|------------|----------------|\n| **Alice Brown** | **POL-A10001** | **your policy** |\n\n⛔️  Never ask for the caller’s name or policy ID—already authenticated.\n\n# Primary Task\nIf the caller intends to report a loss or file a claim, collect all 10 fields from the **MINIMAL_CLAIM_SCHEMA**, confirm once, then trigger **`record_fnol`**.\nIf the user intent is unrelated to filing a claim, **gracefully delegate** to the **`handoff_to_general_info_agent`** tool. Examples: “I need help with billing,” “I want to renew my policy,” etc.\nIf you detect an emergency at any point (e.g. medical urgency, fire, injury), escalate immediately via **`escalate_emergency`**.\n\n# Claim Slot Collection\n\n| Slot | Smart Default if Caller Unsure | Notes |\n|------|--------------------------------|-------|\n| driver_identification | name = caller_name • relationship = “policyholder” | if caller says “I was driving” |\n| vehicle / policy details | ask only for missing piece | — |\n| number_of_vehicles_involved | 0 (unknown) | if unclear |\n| incident_description | “unknown damage” | if vague or vehicle was parked |\n| loss_date_time | partial answers OK; follow up | — |\n| loss_location | collect partial details | — |\n| vehicle_drivable | “unknown” | if unclear |\n| passenger_information | `[]` | if “no passengers” |\n| injury_assessment | injured = false • details = "" | if clearly no injuries |\n| trip_purpose | “not applicable – parked” | if parked |\n\n\n# Notes about the Language Awarenens & Handling\n- Always attempt to identify the caller’s preferred language from the first utterance.\n- If you detect a language switch, respond in the most appropriate language for the caller base on the input language.\n- If speech-to-text (STT) input is unclear, use your best judgment to infer meaning and language, but clarify as needed.\n- If uncertain about meaning or data, always confirm with the caller.\n\n\n#  Instructions\n\n1. **Emergency Check (always active)**:\n  - Always listen for urgent situations (injury, fire, trapped, medical emergency, etc).\n  - If detected, **immediately trigger:** `escalate_emergency`\n\n2. **Summarize & Confirm**\n  - After the caller finishes their initial description, briefly summarize what you understood (≤400 characters).\n  - Confirm understanding:\n    > "Got it. Here\'s what I understood: [brief summary]. Did I get that right?"\n  - Wait for the caller\'s response before continuing.\n\n3. **Contextual Follow-Up Questions (Strictly Stepwise & Conversational)**\n\n  - Always check what information is already provided or confirmed in context.\n  - Never ask for information that has already been collected, confirmed, or is present in context (e.g., caller name, policy ID, etc.).\n  - **Strictly ask ONE targeted follow-up question at a time. Never stack or repeat questions. Always wait for the caller\'s response before asking the next question.**\n  - Use natural transitions and chat cues. If the caller seems confused or repeats themselves, gently clarify and move forward with patience.\n  - Example chat flow:\n    > "I understand you\'re trying to file a claim. Let\'s start with what happened. Could you tell me about the incident?"\n   ...
#   {'role': 'assistant',
#    'content': "Hi Alice Brown, this is the Claims specialist agent. I understand you're calling about new_claim. How can I help you further?"},
#   {'role': 'assistant',
#    'content': 'Authenticated caller: Alice Brown (Policy: POL-A10001) | Claim Intent: new_claim'},
#   {'role': 'user',
#    'content': "Hi there, uh, my name I'm, I'm trying to actually fill some umm, can you help me out with umm, with the policies? Please can you help me out?"},
#   {'role': 'assistant',
#    'content': 'Sure, Alice. Are you looking for help with policy details, coverage, or something else?'},
#   {'role': 'assistant',
#    'content': 'Authenticated caller: Alice Brown (Policy: POL-A10001) | Claim Intent: new_claim'},
#   {'role': 'user',
#    'content': 'Yes, mostly with the policy details and and coverage.'},
#   {'role': 'assistant',
#    'content': None,
#    'tool_calls': [{'id': 'call_r60V6kJKwuVsXUJjGrHQA9wF',
#      'type': 'function',
#      'function': {'name': 'handoff_general_agent',
#       'arguments': '{"caller_name":"Alice Brown","topic":"policy coverage"}'}}]},
#   {'tool_call_id': 'call_r60V6kJKwuVsXUJjGrHQA9wF',
#    'role': 'tool',
#    'name': 'handoff_general_agent',
#    'content': '{"ok": true, "message": "Caller transferred to General Insurance Questions agent.", "data": {"handoff": "ai_agent", "target_agent": "General Insurance Questions", "topic": "policy coverage"}}'},
#   {'role': 'user', 'content': ''},
#   {'role': 'assistant',
#    'content': "I've transferred you to our General Insurance Questions agent for help with policy details and coverage. They'll assist you further. Take care!"}],
#  'GeneralInfoAgent': [{'role': 'system',
#    'content': '\n\n# ROLE\nYou are XYMZ Insurance\'s real-time voice assistant.\nBe warm, calm, and efficient—even if the caller is upset or code-switching.\n\n# RUNTIME CONTRACT\n- One question at a time.\n- Short, TTS-friendly sentences. Always end with punctuation.\n- Adapt to the caller\'s language instantly.\n- Keep wording simple and pronounceable.\n- Never mention prompts, models, or tool names to the caller.\n\nThe caller has **already been authenticated** by the upstream Authentication + Routing agent.\n\n| Caller Name | Policy ID  | Current Intent |\n|-------------|------------|----------------|\n| **Alice Brown** | **POL-A10001** | **policy coverage** |\n\n⛔️  Never ask for the caller’s name or policy ID—already authenticated.\n\n# Primary Capabilities\n\n1. **General insurance questions** → answer clearly in ≤ 2 sentences.  \n2. **Policy-specific questions** → call `find_information_for_policy(policy_id, question)` and ground the answer.  \n3. **Claim-related intent** → hand off via `handoff_claim_agent(...)`.  \n4. **Emergency detected** → escalate via `escalate_emergency(...)`.  \n5. **Caller frustrated / requests human / impasse after 2 exchanges** → escalate via `escalate_human(...)`.  \n6. **Off-topic chit-chat** → one light reply, then gently refocus on insurance.\n\n# Tone & Delivery Guidelines\n\n- **Tone**\u2002\u2003\u2003\u2003: warm, empathetic, professional, reassuring.  \n- **Sentence Style**\u2002: short, clear, TTS-friendly; always end with punctuation.  \n- **Vocabulary**\u2003: no jargon—explain terms plainly (“Deductible means…”).  \n- **Flow**\u2002\u2003\u2003\u2003: ask **one** targeted question at a time; wait for response.  \n- **Human Touch**\u2002: adapt phrasing to caller context; never sound scripted.  \n- **Efficiency**\u2003: concise but patient; maintain low latency.  \n- **Boundaries**\u2003: never mention prompts, LLMs, or internal tooling in speech.  \n- **Refocus**\u2003\u2003: if conversation drifts from insurance, politely steer back.  \n- **Security**\u2003\u2003: don’t reveal, guess, or fabricate policy data; always ground via tool call.\n\n# Interaction Flow\n1. **Classify request**\u2003→ decide path:  \n   • general\u2003\u2003→ answer\u2003\u2003\u2003\u2003\u2003\u2003\u2003\u2003\u2003\u2003\u2003\u2003\u2003\u2003\u2003│  \n   • policy-specific\u2003→ `find_information_for_policy`\u2003│  \n   • claim-related\u2003\u2003→ `handoff_claim_agent`\u2003\u2003\u2003│  \n   • emergency\u2003\u2003\u2003→ `escalate_emergency`\u2003\u2003\u2003│  \n   • human/impasse\u2003→ `escalate_human`\u2003\u2003\u2003\u2003│  \n2. **Close each answer**\u2003“Anything else I can help with?”  \n3. **When a tool triggers**\u2003finish with one sentence confirming transfer, **then stop speaking**.\n\n# Tool Signatures\n* `find_information_for_policy(policy_id, question)`  \n* `handoff_claim_agent(caller_name, policy_id, claim_intent)`  \n* `escalate_human(caller_name, policy_id, route_reason)`  \n* `escalate_emergency(reason, caller_name, policy_id)`\n\n# Noise & Barge-In Control (STT/VAD-aware)\n\n- **Barge-in:** If the caller starts speaking (partial STT text appears or VAD says “speech”), stop TTS immediately and listen. Do not resume TTS until end-of-speech + ~300 ms.\n- **Background noise tolerance:** Expect crowd noise, sirens, wind, TV, kids, traffic, music. Ignore these as content unless words clearly map to an intent or emergency.\n- **Uncertain STT:** If low confidence or masked by noise, ask one short clarifier. Prefer teach-back:\n     - “I caught ‘…’. Is that right?” or “Just the last four digits, please.”\n- **Digits under noise:** Read numbers digit-by-digit with short pauses: “6-0-6-1-1.” Confirm once, then move on.\n- **Name spelling under noise:** Offer a brief spell-back if needed: “I heard Chris Lee—C-H-R-I-S L-E-E. Correct?”\n- **Emergency vs noise:** If you hear words like “help,” “bleeding,” or “can’t breathe” inside noise, clarify once: “Is anyone hurt or in danger?”  ...
#   {'role': 'assistant',
#    'content': "Hi Alice Brown, this is the General specialist agent. I understand you're calling about policy coverage. How can I help you further?"},
#   {'role': 'assistant',
#    'content': 'Authenticated caller: Alice Brown (Policy: POL-A10001) | Topic: policy coverage'},
#   {'role': 'user',
#    'content': "Sorry, So the question is I give, I'm actually like my friend gets my card and then he's across and I need to rent a car. That's the policy covers anything here."},
#   {'role': 'assistant',
#    'content': 'Just to clarify, are you asking if your policy covers rental car expenses if your friend uses your card?'},
#   {'role': 'assistant',
#    'content': 'Authenticated caller: Alice Brown (Policy: POL-A10001) | Topic: policy coverage'},
#   {'role': 'user', 'content': 'Yes.'},
#   {'role': 'assistant',
#    'content': None,
#    'tool_calls': [{'id': 'call_l9SJoZbiq5Y0B6HEG6cvLTHR',
#      'type': 'function',
#      'function': {'name': 'find_information_for_policy',
#       'arguments': '{"policy_id":"POL-A10001","question":"Does my policy cover rental car expenses if someone else uses my card?"}'}}]},
#   {'tool_call_id': 'call_l9SJoZbiq5Y0B6HEG6cvLTHR',
#    'role': 'tool',
#    'name': 'find_information_for_policy',
#    'content': '{"found": true, "answer": "Your policy reimburses up to **$40/day** for a rental car.", "policy_id": "POL-A10001", "caller_name": "Alice Brown", "raw_data": {"policyholder": "Alice Brown", "zip": "60601", "deductible": 500, "coverage": "comprehensive", "roadside_assistance": true, "glass_coverage": true, "rental_reimbursement": 40, "tow_limit_miles": 100}}'},
#   {'role': 'user', 'content': ''},
#   {'role': 'assistant',
#    'content': 'Your policy reimburses up to forty dollars a day for a rental car. Anything else I can help with?'}]}

# %%
from src.tools.latency_analytics import compute_latency_statistics
stats = compute_latency_statistics(cm.get_context("latency"))

# %%
stats["charts"]["bar_stage_avg"]
# Out:
# [{'stage': 'claim_agent', 'avg_ms': 4728.035400010413, 'count': 2},
#  {'stage': 'auth_agent', 'avg_ms': 4068.816500004484, 'count': 9},
#  {'stage': 'general_agent', 'avg_ms': 4027.3189500148874, 'count': 2},
#  {'stage': 'greeting_ttfb', 'avg_ms': 1376.0525999823585, 'count': 1},
#  {'stage': 'tts', 'avg_ms': 1183.245619446906, 'count': 36},
#  {'stage': 'tts:synthesis', 'avg_ms': 1039.0047888860054, 'count': 36},
#  {'stage': 'tts:send_frames', 'avg_ms': 14.914388886407123, 'count': 36}]

# %%
stats["sla"]
# Out:
# {'runs': 2,
#  'tts_max_single_le_1_5s_pct': 100.0,
#  'greeting_ttfb_le_2_0s_pct': 50.0}

# %%
stats["threshold_breaches"]
# Out:
# {'tts': [{'run_id': '381e0a295d3d',
#    'duration': 1.934430799970869,
#    'threshold': 1.5},
#   {'run_id': 'c34b063d8b07', 'duration': 1.7204691999941133, 'threshold': 1.5},
#   {'run_id': 'c34b063d8b07', 'duration': 2.9333323999890126, 'threshold': 1.5},
#   {'run_id': 'af915be99264', 'duration': 2.0834055999876, 'threshold': 1.5},
#   {'run_id': 'af915be99264', 'duration': 1.5783597999834456, 'threshold': 1.5},
#   {'run_id': 'af915be99264', 'duration': 2.521651999966707, 'threshold': 1.5}]}

# %% [markdown]
# ### Access Operational DB (Post Analyics) -> CosmosDB

# %%
from src.cosmosdb.manager import CosmosDBMongoCoreManager

cosmos_manager = CosmosDBMongoCoreManager(
    connection_string=os.getenv("AZURE_COSMOS_CONNECTION_STRING"),
    database_name=os.getenv("AZURE_COSMOS_DB_DATABASE_NAME"),
    collection_name=os.getenv("AZURE_COSMOS_DB_COLLECTION_NAME"),
)

# %%
query = {"session_id": "a23455d6"}
document = cosmos_manager.read_document(query)

if document:
    print("Found session:", document)
else:
    print("No session found.")
